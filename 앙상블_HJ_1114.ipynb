# %% [markdown]
# # 팀원들의 예측 파일을 평균 내는 등과 같이 앙상블을 할 경우
# - 팀원들에게 csv 파일 만들때 1에 대한 확률로 예측할 것을 요구해야 함

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

DATA_PATH = '/content/drive/MyDrive/데이터/'

train_tr = pd.read_csv(f"{DATA_PATH}store_train_transactions.csv") # 학습용 구매기록 데이터
train_target = pd.read_csv(f"{DATA_PATH}store_train.csv") # 학습용 정답 데이터
test_tr = pd.read_csv(f"{DATA_PATH}store_test_transactions.csv") # 테스트용 구매기록 데이터
submit = pd.read_csv(f"{DATA_PATH}store_submission.csv") # 제출 양식 데이터

train_tr.shape , train_target.shape , test_tr.shape , submit.shape
# Out:
# ((523105, 7), (14940, 2), (441196, 7), (12225, 2))

# %%
import pandas as pd
import numpy as np

proba_1 = pd.read_csv(f"{DATA_PATH}multi_layer_ensemble_06_1112_proba.csv")         # 0.732630
proba_5 = pd.read_csv(f"{DATA_PATH}voting5_logiadd_fs_logi_proba_V3.3_1111.csv")    # 0.732346
proba_3 = pd.read_csv(f"{DATA_PATH}ensemble_07_proba.csv")                          # 0.735396

proba_5 = pd.read_csv(f"{DATA_PATH}voting10_mlpadd_fs_V3.3_proba_1113.csv")         # 0.729686
proba_3 = pd.read_csv(f"{DATA_PATH}voting2_V3.3_proba_1111.csv")                    # 0.728752(0.42)
proba_1 = pd.read_csv(f"{DATA_PATH}ens_voting_proba_1111.csv")                      # 0.728546(0.42)
proba_4 = pd.read_csv(f"{DATA_PATH}voting4_logiadd_fs_logi_proba_V3.3_1111.csv")    # 0.728035(0.42)

proba_2 = pd.read_csv(f"{DATA_PATH}ensemble_03_proba.csv")                          # 0.727173
    # proba_1 = pd.read_csv(f"{DATA_PATH}6조_v3.2_1108_cluster_O_proba.csv")  # 현설_ 군집_스케일링O (0.723658)
    # proba_2 = pd.read_csv(f"{DATA_PATH}v3.2_XGB_cluster_proba.csv")         # 현설_v3.2_optuna_XGB (0.724409)
    # proba_3 = pd.read_csv(f"{DATA_PATH}6조_v3.0_proba.csv")                 # 공통피처 v3.0 (0.725006)
    # proba_4 = pd.read_csv(f"{DATA_PATH}v3.0_XGB_cluster_proba.csv")         # 현설_v3.2_optuna_XGB (0.725341)
proba_8 = pd.read_csv(f"{DATA_PATH}ensemble_05_proba.csv")                          # 0.726927
    # proba_1 = pd.read_csv(f"{DATA_PATH}ens_voting_proba_1111.csv")                      # 0.728546
    # proba_2 = pd.read_csv(f"{DATA_PATH}ensemble_03_proba.csv")                          # 0.727173
    # proba_3 = pd.read_csv(f"{DATA_PATH}ensemble_04_proba.csv")                          # 0.725729
    # proba_4 = pd.read_csv(f"{DATA_PATH}v3.0_XGB_cluster_proba.csv")                     # 0.725341
    # proba_5 = pd.read_csv(f"{DATA_PATH}v3.2_XGB_cluster_proba.csv")                     # 0.724409
    # proba_6 = pd.read_csv(f"{DATA_PATH}voting2_V3.3_proba_1111.csv")                    # 0.728752
    # proba_7 = pd.read_csv(f"{DATA_PATH}voting4_logiadd_fs_logi_proba_V3.3_1111.csv")    # 0.728035
    # proba_8 = pd.read_csv(f"{DATA_PATH}voting5_logiadd_fs_logi_proba_V3.3_1111.csv")    # 0.732346
proba_3 = pd.read_csv(f"{DATA_PATH}ensemble_04_proba.csv")                          # 0.725729
    # proba_1 = pd.read_csv(f"{DATA_PATH}6조_v3.2_1108_cluster_O_proba.csv")  # 현설_ 군집_스케일링O (0.723658)
    # proba_2 = pd.read_csv(f"{DATA_PATH}6조_v3.2_1108_cluster_X_proba.csv")  # 현설_ 군집_스케일링X (0.723658)
    # proba_3 = pd.read_csv(f"{DATA_PATH}6조_v3.0_proba.csv")                 # 공통피처 v3.0 (0.725006)
    # proba_4 = pd.read_csv(f"{DATA_PATH}v3.2_XGB_cluster_proba.csv")         # 현설_v3.2_optuna_XGB (0.724409)
    # proba_5 = pd.read_csv(f"{DATA_PATH}v3.0_XGB_cluster_proba.csv")         # 현설_v3.2_optuna_XGB (0.725341)
    # proba_6 = pd.read_csv(f"{DATA_PATH}XGB_fs_proba_1108.csv")              # 서진_XGB (0.722212)
    # proba_7 = pd.read_csv(f"{DATA_PATH}LGBM_fs_logi_proba_1108.csv")        # 서진_LGBM_logi (0.717365)
    # proba_8 = pd.read_csv(f"{DATA_PATH}LGBM_fs_xgb_proba_1108.csv")         # 서진_LGBM_xgb (0.719888)
proba_4 = pd.read_csv(f"{DATA_PATH}v3.0_XGB_cluster_proba.csv")                     # 0.725341
proba_2 = pd.read_csv(f"{DATA_PATH}v3.2_XGB_cluster_proba.csv")                     # 0.724409


proba_1 = pd.read_csv(f"{DATA_PATH}fs_xgb_LDA.csv")                                 # 0.718366
proba_2 = pd.read_csv(f"{DATA_PATH}fs_xgb_logistic.csv")                            # 0.717932
proba_3 = pd.read_csv(f"{DATA_PATH}log_sqrt_LGBM.csv")                              # 0.723536



proba_3 = pd.read_csv(f"{DATA_PATH}voting6_logiadd_fs_logi_proba_V3.3_1113.csv")    # 0.722278
proba_4 = pd.read_csv(f"{DATA_PATH}voting7_logiadd_fs_logi_proba_log_1113.csv")     # 0.716628

# %% [markdown]
# # 01
# - 0.728 ~ 0.732 사이의 값을 가진 csv
# - 임계값 0.42로 조절 / 안 조절 버전도 있음

# %%
DATA_PATH = '/content/drive/MyDrive/데이터/'

proba_1 = pd.read_csv(f"{DATA_PATH}multi_layer_ensemble_06_1112_proba.csv")         # 0.732630
proba_2 = pd.read_csv(f"{DATA_PATH}voting5_logiadd_fs_logi_proba_V3.3_1111.csv")    # 0.732346
proba_3 = pd.read_csv(f"{DATA_PATH}ensemble_07_proba.csv")                          # 0.735396
proba_4 = pd.read_csv(f"{DATA_PATH}voting2_V3.3_proba_1111.csv")                    # 0.728752
proba_5 = pd.read_csv(f"{DATA_PATH}voting4_logiadd_fs_logi_proba_V3.3_1111.csv")    # 0.728035
proba_6 = pd.read_csv(f"{DATA_PATH}voting5_logiadd_fs_logi_proba_V3.3_1111.csv")    # 0.732346
proba_7 = pd.read_csv(f"{DATA_PATH}voting10_mlpadd_fs_V3.3_proba_1113.csv")         # 0.729686
proba_8 = pd.read_csv(f"{DATA_PATH}voting2_V3.3_proba_1111.csv")                    # 0.728752(0.42)
proba_9 = pd.read_csv(f"{DATA_PATH}ens_voting_proba_1111.csv")                      # 0.728546(0.42)
proba_10 = pd.read_csv(f"{DATA_PATH}voting4_logiadd_fs_logi_proba_V3.3_1111.csv")    # 0.728035(0.42)

# %%
pred = np.mean(
        [
            proba_1["target"].to_numpy(),
            proba_2["target"].to_numpy(),

        ],axis=0)

submit["target"] = pred
proba_ensemble = submit
proba_ensemble.shape
# Out:
# (12225, 2)

# %%
pred = np.mean(
        [
            proba_1["target"].to_numpy(),
            proba_2["target"].to_numpy(),
            proba_3["target"].to_numpy(),
            proba_4["target"].to_numpy(),
            proba_5["target"].to_numpy(),
            proba_6["target"].to_numpy(),
            proba_7["target"].to_numpy(),
            proba_8["target"].to_numpy(),
            proba_9["target"].to_numpy(),
            proba_10["target"].to_numpy()

        ],axis=0)
pred.shape
# Out:
# (12225,)

# %%
pred = (pred >= 0.5).astype(int)
submit["target"] = pred
submit.head
# Out:
# <bound method NDFrame.head of                ID  target
# 0          test_0       0
# 1          test_1       0
# 2          test_2       0
# 3          test_3       1
# 4          test_4       1
# ...           ...     ...
# 12220  test_12220       1
# 12221  test_12221       0
# 12222  test_12222       0
# 12223  test_12223       0
# 12224  test_12224       0
#
# [12225 rows x 2 columns]>

# %%
submit.to_csv(f"{DATA_PATH}ensemble_01.csv",index=False)

# %% [markdown]
# #02 모델 다양성 기반

# %%
DATA_PATH = '/content/drive/MyDrive/데이터/'

proba1 = pd.read_csv(f"{DATA_PATH}ensemble_07_proba.csv")          # 0.735396
proba2 = pd.read_csv(f"{DATA_PATH}voting2_V3.3_proba_1111.csv")    # 0.728752
proba3 = pd.read_csv(f"{DATA_PATH}ens_voting_proba_1111.csv")      # 0.728546
proba4 = pd.read_csv(f"{DATA_PATH}fs_xgb_LDA.csv")                 # 0.718366
proba5 = pd.read_csv(f"{DATA_PATH}log_sqrt_LGBM.csv")              # 0.723536

# %%
pred = np.mean(
        [
            proba_1["target"].to_numpy(),
            proba_2["target"].to_numpy(),
            proba_3["target"].to_numpy(),
            proba_4["target"].to_numpy(),
            proba_5["target"].to_numpy()
        ],axis=0)
pred.shape
# Out:
# (12225,)

# %%
pred = (pred >= 0.5).astype(int)
submit["target"] = pred
submit.head
# Out:
# <bound method NDFrame.head of                ID  target
# 0          test_0       0
# 1          test_1       1
# 2          test_2       0
# 3          test_3       1
# 4          test_4       1
# ...           ...     ...
# 12220  test_12220       1
# 12221  test_12221       0
# 12222  test_12222       0
# 12223  test_12223       0
# 12224  test_12224       0
#
# [12225 rows x 2 columns]>

# %%
submit.to_csv(f"{DATA_PATH}ensemble_02.csv",index=False)

# %% [markdown]
# #03 XGB 기반 + 다양한 앙상블

# %%
proba_1 = pd.read_csv(f"{DATA_PATH}v3.2_XGB_cluster_proba.csv")         # 0.724409
proba_2 = pd.read_csv(f"{DATA_PATH}ensemble_03_proba.csv")              # 0.727173
proba_3 = pd.read_csv(f"{DATA_PATH}voting6_logiadd_fs_logi_proba_V3.3_1113.csv")    # 0.722278
proba_4 = pd.read_csv(f"{DATA_PATH}voting7_logiadd_fs_logi_proba_log_1113.csv")     # 0.716628
proba_5 = pd.read_csv(f"{DATA_PATH}v3.0_XGB_cluster_proba.csv")         # 0.725341

# %%
# 평균 앙상블 계산
pred = np.mean(
    [
        proba_1["target"].to_numpy(),
        proba_2["target"].to_numpy(),
        proba_3["target"].to_numpy(),
        proba_4["target"].to_numpy(),
        proba_5["target"].to_numpy()
    ],
    axis=0
)

# %%
pred = (pred >= 0.5).astype(int)
submit["target"] = pred
submit.head
# Out:
# <bound method NDFrame.head of                ID  target
# 0          test_0       0
# 1          test_1       1
# 2          test_2       0
# 3          test_3       1
# 4          test_4       1
# ...           ...     ...
# 12220  test_12220       1
# 12221  test_12221       0
# 12222  test_12222       0
# 12223  test_12223       0
# 12224  test_12224       0
#
# [12225 rows x 2 columns]>

# %%
submit.to_csv(f"{DATA_PATH}ensemble_03.csv",index=False)

# %% [markdown]
# # 04 GPT 추천픽..

# %%
proba_1 = pd.read_csv(f"{DATA_PATH}v3.2_XGB_cluster_proba.csv")             #0.724409
proba_2 = pd.read_csv(f"{DATA_PATH}v3.0_XGB_cluster_proba.csv")             #0.725341
proba_3 = pd.read_csv(f"{DATA_PATH}log_sqrt_LGBM.csv")                      # 0.723536
proba_4 = pd.read_csv(f"{DATA_PATH}voting6_logiadd_fs_logi_proba_V3.3_1113.csv")    #0.722278
proba_5 = pd.read_csv(f"{DATA_PATH}multi_layer_ensemble_06_1112_proba.csv") # 0.732630
proba_6 = pd.read_csv(f"{DATA_PATH}ensemble_07_proba.csv")                  #0.735396

# %%
pred = np.mean(
    [
        proba_1["target"].to_numpy(),
        proba_2["target"].to_numpy(),
        proba_3["target"].to_numpy(),
        proba_4["target"].to_numpy(),
        proba_5["target"].to_numpy(),
        proba_6["target"].to_numpy()
    ],
    axis=0
)

# %%
pred = (pred >= 0.42).astype(int)
submit["target"] = pred
submit.head
# Out:
# <bound method NDFrame.head of                ID  target
# 0          test_0       0
# 1          test_1       1
# 2          test_2       0
# 3          test_3       1
# 4          test_4       1
# ...           ...     ...
# 12220  test_12220       1
# 12221  test_12221       0
# 12222  test_12222       0
# 12223  test_12223       0
# 12224  test_12224       0
#
# [12225 rows x 2 columns]>

# %%
submit.to_csv(f"{DATA_PATH}ensemble_04_threshold.csv",index=False)

# %% [markdown]
# #05 군집화 + 앙상블 + XGboost

# %%
proba_1 = pd.read_csv(f"{DATA_PATH}6조_v3.2_1108_cluster_O_proba.csv")        # 군집화 O (0.723658)
proba_2 = pd.read_csv(f"{DATA_PATH}multi_layer_ensemble_06_1112_proba.csv")    # 앙상블 모델 1 (0.732630)
proba_3 = pd.read_csv(f"{DATA_PATH}voting5_logiadd_fs_logi_proba_V3.3_1111.csv") # 앙상블 모델 2 (0.732346)
proba_4 = pd.read_csv(f"{DATA_PATH}ensemble_07_proba.csv")                    # 앙상블 모델 3 (0.735396)
proba_5 = pd.read_csv(f"{DATA_PATH}voting10_mlpadd_fs_V3.3_proba_1113.csv")    # 앙상블 모델 4 (0.729686)
proba_6 = pd.read_csv(f"{DATA_PATH}voting2_V3.3_proba_1111.csv")               # 앙상블 모델 5 (0.728752)
proba_7 = pd.read_csv(f"{DATA_PATH}ens_voting_proba_1111.csv")                 # 앙상블 모델 6 (0.728546)
proba_8 = pd.read_csv(f"{DATA_PATH}XGB_fs_proba_1108.csv")                    # XGBoost 모델 1 (0.722212)
proba_9 = pd.read_csv(f"{DATA_PATH}v3.2_XGB_cluster_proba.csv")              # XGBoost 모델 2 (0.724409)
proba_10 = pd.read_csv(f"{DATA_PATH}v3.0_XGB_cluster_proba.csv")              # XGBoost 모델 3 (0.725006)

# %%
pred = np.mean(
    [
        proba_1["target"].to_numpy(),
        proba_2["target"].to_numpy(),
        proba_3["target"].to_numpy(),
        proba_4["target"].to_numpy(),
        proba_5["target"].to_numpy(),
        proba_6["target"].to_numpy(),
        proba_7["target"].to_numpy(),
        proba_8["target"].to_numpy(),
        proba_9["target"].to_numpy(),
        proba_10["target"].to_numpy()
    ],
    axis=0
)

# %%
pred = (pred >= 0.5).astype(int)
submit["target"] = pred
submit.head
# Out:
# <bound method NDFrame.head of                ID  target
# 0          test_0       0
# 1          test_1       0
# 2          test_2       0
# 3          test_3       1
# 4          test_4       1
# ...           ...     ...
# 12220  test_12220       1
# 12221  test_12221       0
# 12222  test_12222       0
# 12223  test_12223       0
# 12224  test_12224       0
#
# [12225 rows x 2 columns]>

# %%
submit.to_csv(f"{DATA_PATH}ensemble_05.csv",index=False)
