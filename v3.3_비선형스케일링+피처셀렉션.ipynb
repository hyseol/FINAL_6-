# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 데이터 불러오기

# %%
DATA_PATH = "/content/drive/MyDrive/멋쟁이사자처럼/Final_Project/dataset/"
SEED = 42

# %%
import pandas as pd
import numpy as np

# %%
train_tr = pd.read_csv(f"{DATA_PATH}store_train_transactions.csv") # 학습용 구매기록 데이터
train_target = pd.read_csv(f"{DATA_PATH}store_train.csv") # 학습용 정답 데이터
test_tr = pd.read_csv(f"{DATA_PATH}store_test_transactions.csv") # 테스트용 구매기록 데이터
submit = pd.read_csv(f"{DATA_PATH}store_submission.csv") # 제출 양식 데이터

train_tr.shape , train_target.shape , test_tr.shape , submit.shape
# Out:
# ((523105, 7), (14940, 2), (441196, 7), (12225, 2))

# %%
train_ft = pd.read_csv(f"{DATA_PATH}train_common_v3.3_피처삭제X_1111.csv")
test_ft = pd.read_csv(f"{DATA_PATH}test_common_v3.3_피처삭제X_1111.csv")

train_ft.shape, test_ft.shape
# Out:
# ((14940, 1470), (12225, 1470))

# %% [markdown]
# # 로그 변환 (Log Transformation):
#
# - 주로 값의 범위가 넓을 때 사용하는 방법입니다. 값이 큰 쪽에 치우쳐 있거나 비대칭적인 분포를 가진 데이터를 변환해 분포를 균등하게 만듭니다.
#
# - 예를 들어, 수입이나 소득처럼 큰 값들이 분포에 영향을 미치는 경우, 로그 변환을 하면 값의 스케일을 줄이고 분포를 더 대칭적으로 만들 수 있습니다.
#
# - 사용법:
# 𝑥
# x의 값이 0보다 커야 로그를 사용할 수 있습니다. 예를 들어, np.log(x) 또는 10을 밑으로 사용하고 싶다면 np.log10(x)를 사용합니다.

# %% [markdown]
# - 문제 정의: 데이터가 단순하고 예측력이 낮을 때.
#
# - 비선형 변환:
#     - log, sqrt, exp 등의 비선형 변환으로 데이터 스케일링.

# %%
# 수치형 피처만 필터링
numeric_df = train_ft.select_dtypes(include=['number'])

# 이상치 개수와 왜도를 저장할 딕셔너리
outlier_stats = {}

# 각 수치형 피처에서 이상치 개수와 왜도를 계산하여 딕셔너리에 저장
for column in numeric_df.columns:
    # IQR (Interquartile Range) 계산
    Q1 = numeric_df[column].quantile(0.25)
    Q3 = numeric_df[column].quantile(0.75)
    IQR = Q3 - Q1

    # 이상치의 기준점 설정 (IQR의 1.5배 초과/미만으로 간주)
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # 이상치 개수 계산
    outliers = numeric_df[(numeric_df[column] < lower_bound) | (numeric_df[column] > upper_bound)][column]
    outlier_count = len(outliers)

    # 왜도 계산
    skewness = numeric_df[column].skew()

    # 딕셔너리에 이상치 개수와 왜도 저장
    outlier_stats[column] = {'outlier_count': outlier_count, 'skewness': skewness}

# 이상치 개수가 747개 이상인 피처들만 필터링 --> 전체 데이터의 5% 이상
filtered_outliers = {k: v for k, v in outlier_stats.items() if v['outlier_count'] >= 747}

# 이상치 개수가 많은 피처를 내림차순으로 정렬
sorted_outliers = sorted(filtered_outliers.items(), key=lambda x: x[1]['outlier_count'], reverse=True)

# 결과 출력
for feature, stats in sorted_outliers:
    print(f"Feature: {feature}, Outlier Count: {stats['outlier_count']}, Skewness: {stats['skewness']:.2f}")
# Out:
# Feature: A202000지점_구매금액, Outlier Count: 3738, Skewness: 11.05
# Feature: pv_대분류_여성정장_구매횟수, Outlier Count: 3704, Skewness: 9.54
# Feature: pv_대분류_아동_스포츠_구입금액비중, Outlier Count: 3667, Skewness: 4.91
# Feature: 대분류_여성캐쥬얼_구매주기, Outlier Count: 3655, Skewness: 2.74
# Feature: pv_대분류_골프_유니캐쥬얼_구매횟수, Outlier Count: 3642, Skewness: 5.33
# Feature: pv_대분류_골프_유니캐쥬얼_총구매금액, Outlier Count: 3586, Skewness: 11.53
# Feature: pv_대분류_골프_유니캐쥬얼_평균구매금액, Outlier Count: 3586, Skewness: 5.70
# Feature: pv_중분류_야채_구매횟수, Outlier Count: 2999, Skewness: 7.66
# Feature: pv_중분류_스타킹_구매횟수, Outlier Count: 2997, Skewness: 4.27
# Feature: pv_중분류_야채_총구매금액, Outlier Count: 2987, Skewness: 12.82
# Feature: pv_중분류_야채_구입금액비중, Outlier Count: 2987, Skewness: 6.08
# Feature: pv_중분류_스타킹_총구매금액, Outlier Count: 2967, Skewness: 12.64
# Feature: pv_중분류_스타킹_구입금액비중, Outlier Count: 2967, Skewness: 16.82
# Feature: A202000_구매브랜드_갯수, Outlier Count: 2939, Skewness: 4.14
# Feature: pv_대분류_스포츠캐쥬얼_구입금액비중, Outlier Count: 2870, Skewness: 4.28
# Feature: 주구매_년, Outlier Count: 2818, Skewness: 1.59
# Feature: pv_대분류_여성의류파트_구매횟수, Outlier Count: 2818, Skewness: 11.56
# Feature: 연말_구매유무, Outlier Count: 2796, Skewness: -1.60
# Feature: pv_중분류_상품군미지정_총구매금액, Outlier Count: 2743, Skewness: 13.42
# Feature: pv_대분류_여성의류파트_총구매금액, Outlier Count: 2730, Skewness: 15.36
# Feature: pv_대분류_여성의류파트_평균구매금액, Outlier Count: 2730, Skewness: -9.63
# Feature: pv_대분류_여성의류파트_구입금액비중, Outlier Count: 2730, Skewness: -26.73
# Feature: 중분류_진캐쥬얼_구매주기, Outlier Count: 2729, Skewness: 3.26
# Feature: pv_중분류_상품군미지정_구입금액비중, Outlier Count: 2720, Skewness: 6.37
# Feature: 대분류_남성의류_구매주기, Outlier Count: 2718, Skewness: 3.25
# Feature: pv_중분류_욕실용품_구매횟수, Outlier Count: 2681, Skewness: 5.76
# Feature: pv_대분류_스포츠캐쥬얼_총구매금액, Outlier Count: 2676, Skewness: 20.72
# Feature: pv_중분류_욕실용품_총구매금액, Outlier Count: 2653, Skewness: 10.46
# Feature: pv_중분류_욕실용품_구입금액비중, Outlier Count: 2653, Skewness: 20.49
# Feature: 대분류_명품잡화_구매주기, Outlier Count: 2598, Skewness: 2.61
# Feature: 대분류_스포츠캐쥬얼_구매주기, Outlier Count: 2484, Skewness: 3.52
# Feature: pv_중분류_청과_구매횟수, Outlier Count: 2463, Skewness: 9.64
# Feature: pv_중분류_청과_총구매금액, Outlier Count: 2452, Skewness: 39.47
# Feature: pv_중분류_청과_구입금액비중, Outlier Count: 2452, Skewness: 8.30
# Feature: A112000지점_구매금액, Outlier Count: 2447, Skewness: 13.18
# Feature: pv_대분류_케주얼_구두_아동_구입금액비중, Outlier Count: 2446, Skewness: 3.14
# Feature: pv_대분류_케주얼_구두_아동_총구매금액, Outlier Count: 2413, Skewness: 6.32
# Feature: pv_중분류_영캐주얼_구매횟수, Outlier Count: 2409, Skewness: 14.80
# Feature: pv_대분류_남성의류_총구매금액, Outlier Count: 2397, Skewness: 20.04
# Feature: pv_중분류_일반조리_구매횟수, Outlier Count: 2366, Skewness: 10.51
# Feature: pv_중분류_일반조리_총구매금액, Outlier Count: 2352, Skewness: 30.16
# Feature: pv_중분류_일반조리_구입금액비중, Outlier Count: 2352, Skewness: 13.88
# Feature: pv_대분류_남성의류_구입금액비중, Outlier Count: 2348, Skewness: 3.57
# Feature: 대분류_영플라자_구매주기, Outlier Count: 2283, Skewness: 3.76
# Feature: pv_중분류_진캐쥬얼_구입금액비중, Outlier Count: 2270, Skewness: 4.77
# Feature: A144000지점_구매금액, Outlier Count: 2252, Skewness: 7.15
# Feature: pv_중분류_영캐주얼_구입금액비중, Outlier Count: 2242, Skewness: 3.85
# Feature: A112000_구매브랜드_갯수, Outlier Count: 2239, Skewness: 3.69
# Feature: pv_대분류_남성의류_구매횟수, Outlier Count: 2225, Skewness: 4.55
# Feature: pv_대분류_가정용품_총구매금액, Outlier Count: 2209, Skewness: 8.10
# Feature: pv_중분류_색조화장품_구매횟수, Outlier Count: 2194, Skewness: 4.56
# Feature: pv_중분류_색조화장품_총구매금액, Outlier Count: 2182, Skewness: 6.86
# Feature: pv_중분류_색조화장품_구입금액비중, Outlier Count: 2182, Skewness: 14.17
# Feature: pv_중분류_양말_구매횟수, Outlier Count: 2179, Skewness: 4.33
# Feature: pv_중분류_양말_총구매금액, Outlier Count: 2164, Skewness: 7.01
# Feature: pv_중분류_양말_구입금액비중, Outlier Count: 2164, Skewness: 24.01
# Feature: pv_대분류_생식품_총구매금액, Outlier Count: 2160, Skewness: 15.87
# Feature: pv_중분류_영캐주얼_총구매금액, Outlier Count: 2160, Skewness: 12.70
# Feature: pv_중분류_영트랜드_구매횟수, Outlier Count: 2150, Skewness: 12.76
# Feature: pv_중분류_진캐쥬얼_구매횟수, Outlier Count: 2150, Skewness: 5.16
# Feature: pv_중분류_아동복_구매횟수, Outlier Count: 2143, Skewness: 8.59
# Feature: pv_중분류_스포츠웨어_구매횟수, Outlier Count: 2138, Skewness: 7.10
# Feature: pv_중분류_진캐쥬얼_총구매금액, Outlier Count: 2136, Skewness: 5.64
# Feature: pv_대분류_명품잡화_총구매금액, Outlier Count: 2121, Skewness: 10.29
# Feature: pv_대분류_스포츠캐쥬얼_평균구매금액, Outlier Count: 2118, Skewness: 54.93
# Feature: pv_중분류_용기보증_총구매금액, Outlier Count: 2114, Skewness: 9.42
# Feature: 중분류_상품군미지정_구매주기, Outlier Count: 2114, Skewness: 4.04
# Feature: pv_중분류_아동복_총구매금액, Outlier Count: 2113, Skewness: 16.08
# Feature: pv_중분류_아동_구매횟수, Outlier Count: 2113, Skewness: 8.41
# Feature: pv_중분류_아동복_구입금액비중, Outlier Count: 2113, Skewness: 6.42
# Feature: A373000지점_구매금액, Outlier Count: 2096, Skewness: 6.54
# Feature: pv_대분류_스포츠캐쥬얼_구매횟수, Outlier Count: 2092, Skewness: 5.63
# Feature: pv_대분류_명품잡화_구매횟수, Outlier Count: 2088, Skewness: 5.65
# Feature: 대분류_아동_스포츠_구매주기, Outlier Count: 2084, Skewness: 4.02
# Feature: pv_대분류_아동문화_구매횟수, Outlier Count: 2080, Skewness: 9.84
# Feature: pv_중분류_아동_총구매금액, Outlier Count: 2078, Skewness: 9.45
# Feature: pv_중분류_아동_구입금액비중, Outlier Count: 2078, Skewness: 7.82
# Feature: pv_중분류_스포츠웨어_총구매금액, Outlier Count: 2075, Skewness: 14.90
# Feature: pv_중분류_영트랜드_총구매금액, Outlier Count: 2075, Skewness: 12.69
# Feature: pv_중분류_영트랜드_구입금액비중, Outlier Count: 2075, Skewness: 7.16
# Feature: pv_중분류_스포츠웨어_구입금액비중, Outlier Count: 2075, Skewness: 11.59
# Feature: pv_대분류_아동문화_총구매금액, Outlier Count: 2065, Skewness: 12.81
# Feature: pv_대분류_아동문화_평균구매금액, Outlier Count: 2065, Skewness: 48.09
# Feature: pv_대분류_아동문화_구입금액비중, Outlier Count: 2065, Skewness: 6.39
# Feature: 대분류_골프_유니캐쥬얼_구매주기, Outlier Count: 2053, Skewness: 4.02
# Feature: pv_중분류_골프웨어_구매횟수, Outlier Count: 2049, Skewness: 11.63
# Feature: pv_대분류_영캐릭터_구매횟수, Outlier Count: 2042, Skewness: 10.49
# Feature: pv_대분류_패션잡화_구입금액비중, Outlier Count: 2035, Skewness: 2.99
# Feature: pv_중분류_과자류_구매횟수, Outlier Count: 2020, Skewness: 16.57
# Feature: 최근구매일, Outlier Count: 2015, Skewness: 3.47
# Feature: pv_대분류_여성캐쥬얼_총구매금액, Outlier Count: 2015, Skewness: 7.19
# Feature: pv_중분류_과자류_총구매금액, Outlier Count: 2012, Skewness: 100.48
# Feature: pv_중분류_과자류_구입금액비중, Outlier Count: 2012, Skewness: 14.36
# Feature: pv_중분류_골프웨어_총구매금액, Outlier Count: 1996, Skewness: 15.76
# Feature: pv_중분류_헤어ACC_구매횟수, Outlier Count: 1996, Skewness: 6.33
# Feature: pv_중분류_골프웨어_구입금액비중, Outlier Count: 1996, Skewness: 3.97
# Feature: pv_대분류_로얄부틱_구매횟수, Outlier Count: 1993, Skewness: 18.89
# Feature: pv_대분류_영캐릭터_총구매금액, Outlier Count: 1971, Skewness: 13.72
# Feature: pv_대분류_영캐릭터_평균구매금액, Outlier Count: 1971, Skewness: 10.42
# Feature: pv_대분류_영캐릭터_구입금액비중, Outlier Count: 1971, Skewness: 5.49
# Feature: pv_중분류_완구_구매횟수, Outlier Count: 1969, Skewness: 7.27
# Feature: pv_중분류_진케주얼_구매횟수, Outlier Count: 1964, Skewness: 8.40
# Feature: pv_중분류_생선_구매횟수, Outlier Count: 1956, Skewness: 6.02
# Feature: pv_중분류_생선_총구매금액, Outlier Count: 1955, Skewness: 33.37
# Feature: pv_중분류_생선_구입금액비중, Outlier Count: 1955, Skewness: 16.54
# Feature: pv_중분류_완구_총구매금액, Outlier Count: 1952, Skewness: 16.01
# Feature: pv_중분류_완구_구입금액비중, Outlier Count: 1952, Skewness: 14.43
# Feature: pv_대분류_케주얼_구두_아동_구매횟수, Outlier Count: 1946, Skewness: 6.00
# Feature: pv_대분류_생식품_구입금액비중, Outlier Count: 1935, Skewness: 3.78
# Feature: pv_중분류_헤어ACC_총구매금액, Outlier Count: 1935, Skewness: 11.98
# Feature: pv_중분류_헤어ACC_구입금액비중, Outlier Count: 1935, Skewness: 12.23
# Feature: pv_대분류_영어덜트캐쥬얼_구매횟수, Outlier Count: 1925, Skewness: 9.14
# Feature: pv_중분류_진케주얼_총구매금액, Outlier Count: 1918, Skewness: 10.78
# Feature: pv_중분류_진케주얼_구입금액비중, Outlier Count: 1918, Skewness: 9.67
# Feature: pv_대분류_로얄부틱_총구매금액, Outlier Count: 1914, Skewness: 16.79
# Feature: pv_대분류_로얄부틱_평균구매금액, Outlier Count: 1914, Skewness: 7.22
# Feature: pv_대분류_로얄부틱_구입금액비중, Outlier Count: 1914, Skewness: 5.86
# Feature: 공휴일_총구매금액, Outlier Count: 1911, Skewness: 14.17
# Feature: pv_대분류_여성캐쥬얼_구입금액비중, Outlier Count: 1908, Skewness: 2.78
# Feature: pv_중분류_용기보증_구입금액비중, Outlier Count: 1901, Skewness: 3.83
# Feature: 공휴일_대분류_공산품_구매횟수, Outlier Count: 1895, Skewness: 5.29
# Feature: 공휴일_대분류_공산품_총구매금액, Outlier Count: 1894, Skewness: 8.81
# Feature: pv_대분류_패션잡화_총구매금액, Outlier Count: 1885, Skewness: 9.73
# Feature: pv_대분류_영어덜트캐쥬얼_총구매금액, Outlier Count: 1881, Skewness: 16.89
# Feature: pv_대분류_영어덜트캐쥬얼_평균구매금액, Outlier Count: 1881, Skewness: 5.64
# Feature: pv_대분류_영어덜트캐쥬얼_구입금액비중, Outlier Count: 1881, Skewness: 6.41
# Feature: 환불금액, Outlier Count: 1871, Skewness: -15.73
# Feature: pv_대분류_영라이브_구매횟수, Outlier Count: 1864, Skewness: 17.64
# Feature: pv_대분류_가정용품_구입금액비중, Outlier Count: 1863, Skewness: 2.94
# Feature: pv_중분류_트래디셔널캐쥬얼_구매횟수, Outlier Count: 1859, Skewness: 7.09
# Feature: pv_대분류_명품잡화_구입금액비중, Outlier Count: 1849, Skewness: 2.75
# Feature: pv_대분류_영라이브_총구매금액, Outlier Count: 1837, Skewness: 19.28
# Feature: pv_대분류_영라이브_평균구매금액, Outlier Count: 1837, Skewness: 6.35
# Feature: pv_대분류_영라이브_구입금액비중, Outlier Count: 1837, Skewness: 6.47
# Feature: pv_중분류_건강식품_구매횟수, Outlier Count: 1834, Skewness: 8.05
# Feature: 대분류_여성정장_구매주기, Outlier Count: 1830, Skewness: 4.60
# Feature: pv_대분류_공산품_총구매금액, Outlier Count: 1828, Skewness: 27.23
# Feature: pv_중분류_건강식품_총구매금액, Outlier Count: 1821, Skewness: 18.86
# Feature: pv_중분류_건강식품_구입금액비중, Outlier Count: 1821, Skewness: 16.59
# Feature: 8월_총구매금액, Outlier Count: 1814, Skewness: 9.69
# Feature: pv_대분류_생식품_구매횟수, Outlier Count: 1814, Skewness: 6.23
# Feature: pv_중분류_트래디셔널캐쥬얼_총구매금액, Outlier Count: 1807, Skewness: 8.32
# Feature: pv_중분류_트래디셔널캐쥬얼_구입금액비중, Outlier Count: 1807, Skewness: 7.88
# Feature: 대분류_가정용품_구매주기, Outlier Count: 1805, Skewness: 2.33
# Feature: 2월_총구매금액, Outlier Count: 1802, Skewness: 3.94
# Feature: pv_중분류_유아복_구매횟수, Outlier Count: 1800, Skewness: 9.79
# Feature: 대분류_남성정장스포츠_구매주기, Outlier Count: 1792, Skewness: 4.39
# Feature: pv_중분류_냉장식품_구매횟수, Outlier Count: 1792, Skewness: 8.48
# Feature: pv_중분류_냉장식품_총구매금액, Outlier Count: 1791, Skewness: 34.41
# Feature: pv_중분류_냉장식품_구입금액비중, Outlier Count: 1791, Skewness: 23.30
# Feature: pv_중분류_유아복_총구매금액, Outlier Count: 1780, Skewness: 11.33
# Feature: pv_중분류_유아복_구입금액비중, Outlier Count: 1780, Skewness: 10.19
# Feature: pv_중분류_정육_구매횟수, Outlier Count: 1779, Skewness: 68.05
# Feature: pv_중분류_정육_총구매금액, Outlier Count: 1771, Skewness: 73.19
# Feature: pv_중분류_정육_구입금액비중, Outlier Count: 1771, Skewness: 16.00
# Feature: pv_중분류_스카프_구매횟수, Outlier Count: 1767, Skewness: 10.66
# Feature: pv_대분류_아동_스포츠_구매횟수, Outlier Count: 1742, Skewness: 8.46
# Feature: pv_중분류_아동_트래디셔널_구매횟수, Outlier Count: 1742, Skewness: 8.19
# Feature: pv_중분류_스포츠슈즈_구매횟수, Outlier Count: 1735, Skewness: 5.69
# Feature: 11월_총구매금액, Outlier Count: 1730, Skewness: 6.13
# Feature: 중분류_야채_구매주기, Outlier Count: 1716, Skewness: 4.55
# Feature: pv_중분류_스카프_총구매금액, Outlier Count: 1709, Skewness: 14.17
# Feature: pv_중분류_스카프_구입금액비중, Outlier Count: 1709, Skewness: 14.99
# Feature: 대분류_생식품_구매주기, Outlier Count: 1704, Skewness: 2.61
# Feature: pv_중분류_아동_트래디셔널_총구매금액, Outlier Count: 1704, Skewness: 8.39
# Feature: pv_중분류_아동_트래디셔널_구입금액비중, Outlier Count: 1704, Skewness: 9.64
# Feature: pv_대분류_남성의류_평균구매금액, Outlier Count: 1702, Skewness: 4.02
# Feature: pv_중분류_여성구두_구매횟수, Outlier Count: 1698, Skewness: 13.08
# Feature: pv_중분류_스포츠슈즈_총구매금액, Outlier Count: 1694, Skewness: 113.91
# Feature: pv_중분류_트래디셔널_구매횟수, Outlier Count: 1694, Skewness: 8.22
# Feature: pv_중분류_스포츠슈즈_구입금액비중, Outlier Count: 1694, Skewness: 12.96
# Feature: 3월_총구매금액, Outlier Count: 1693, Skewness: 9.70
# Feature: pv_중분류_용기보증_구매횟수, Outlier Count: 1684, Skewness: 7.06
# Feature: pv_대분류_잡화_총구매금액, Outlier Count: 1683, Skewness: 12.42
# Feature: pv_중분류_소형취사가전_구매횟수, Outlier Count: 1672, Skewness: 5.25
# Feature: pv_대분류_패션잡화_구매횟수, Outlier Count: 1670, Skewness: 5.66
# Feature: pv_중분류_트래디셔널_총구매금액, Outlier Count: 1659, Skewness: 9.49
# Feature: pv_중분류_트래디셔널_구입금액비중, Outlier Count: 1659, Skewness: 8.12
# Feature: 공휴일_대분류_잡화_구매횟수, Outlier Count: 1654, Skewness: 5.11
# Feature: pv_중분류_여성구두_총구매금액, Outlier Count: 1653, Skewness: 18.29
# Feature: pv_중분류_여성구두_구입금액비중, Outlier Count: 1653, Skewness: 8.25
# Feature: pv_대분류_가정용품_평균구매금액, Outlier Count: 1650, Skewness: 6.61
# Feature: pv_중분류_아동_란제리_구매횟수, Outlier Count: 1642, Skewness: 6.57
# Feature: pv_중분류_소형취사가전_총구매금액, Outlier Count: 1639, Skewness: 13.21
# Feature: pv_중분류_소형취사가전_구입금액비중, Outlier Count: 1639, Skewness: 11.77
# Feature: 공휴일_대분류_잡화_총구매금액, Outlier Count: 1637, Skewness: 71.19
# Feature: A1440000_구매브랜드_갯수, Outlier Count: 1622, Skewness: 3.31
# Feature: pv_중분류_건식품_구매횟수, Outlier Count: 1622, Skewness: 9.82
# Feature: 중분류_란제리_구매주기, Outlier Count: 1620, Skewness: 4.43
# Feature: pv_중분류_건식품_총구매금액, Outlier Count: 1619, Skewness: 45.03
# Feature: pv_중분류_건식품_구입금액비중, Outlier Count: 1619, Skewness: 19.86
# Feature: 중분류_용기보증_구매주기, Outlier Count: 1619, Skewness: 2.55
# Feature: pv_중분류_수입ACC_구매횟수, Outlier Count: 1617, Skewness: 8.01
# Feature: 9월_총구매금액, Outlier Count: 1612, Skewness: 6.73
# Feature: pv_중분류_아동_란제리_총구매금액, Outlier Count: 1611, Skewness: 9.62
# Feature: pv_중분류_아동_란제리_구입금액비중, Outlier Count: 1611, Skewness: 12.96
# Feature: A373000_구매브랜드_갯수, Outlier Count: 1602, Skewness: 3.47
# Feature: 12월_총구매금액, Outlier Count: 1601, Skewness: 6.66
# Feature: 6월_총구매금액, Outlier Count: 1596, Skewness: 6.20
# Feature: 1월_총구매금액, Outlier Count: 1585, Skewness: 8.37
# Feature: 10월_총구매금액, Outlier Count: 1581, Skewness: 5.60
# Feature: pv_중분류_차류_구매횟수, Outlier Count: 1577, Skewness: 10.87
# Feature: pv_중분류_차류_총구매금액, Outlier Count: 1570, Skewness: 11.57
# Feature: pv_중분류_차류_구입금액비중, Outlier Count: 1570, Skewness: 18.44
# Feature: pv_중분류_수입ACC_총구매금액, Outlier Count: 1569, Skewness: 12.86
# Feature: pv_중분류_수입ACC_구입금액비중, Outlier Count: 1569, Skewness: 11.61
# Feature: pv_중분류_단품_구매횟수, Outlier Count: 1553, Skewness: 6.54
# Feature: 7월_총구매금액, Outlier Count: 1543, Skewness: 7.94
# Feature: 대분류_여성의류파트_구매주기, Outlier Count: 1543, Skewness: 4.92
# Feature: pv_중분류_타운웨어_구매횟수, Outlier Count: 1539, Skewness: 12.73
# Feature: 5월_총구매금액, Outlier Count: 1531, Skewness: 5.92
# Feature: pv_대분류_공산품_구입금액비중, Outlier Count: 1524, Skewness: 3.14
# Feature: 4월_총구매금액, Outlier Count: 1513, Skewness: 15.77
# Feature: pv_중분류_수입도자기_구매횟수, Outlier Count: 1511, Skewness: 12.07
# Feature: 중분류_캐릭터_구매주기, Outlier Count: 1482, Skewness: 5.18
# Feature: pv_중분류_수입도자기_총구매금액, Outlier Count: 1481, Skewness: 36.57
# Feature: pv_중분류_수입도자기_구입금액비중, Outlier Count: 1481, Skewness: 16.37
# Feature: pv_중분류_단품_총구매금액, Outlier Count: 1475, Skewness: 7.32
# Feature: pv_중분류_단품_구입금액비중, Outlier Count: 1475, Skewness: 13.49
# Feature: pv_중분류_상품군미지정_구매횟수, Outlier Count: 1465, Skewness: 7.12
# Feature: pv_중분류_수영복_구매횟수, Outlier Count: 1462, Skewness: 7.81
# Feature: pv_중분류_타운웨어_총구매금액, Outlier Count: 1460, Skewness: 23.50
# Feature: pv_중분류_타운웨어_구입금액비중, Outlier Count: 1460, Skewness: 7.92
# Feature: pv_대분류_공산품_구매횟수, Outlier Count: 1456, Skewness: 6.03
# Feature: pv_중분류_수입종합화장품_총구매금액, Outlier Count: 1456, Skewness: 6.33
# Feature: pv_중분류_캐쥬얼구두_구매횟수, Outlier Count: 1453, Skewness: 6.83
# Feature: pv_중분류_싸롱화_구매횟수, Outlier Count: 1448, Skewness: 6.75
# Feature: pv_중분류_수입종합화장품_구입금액비중, Outlier Count: 1430, Skewness: 2.33
# Feature: pv_중분류_즉석조리_총구매금액, Outlier Count: 1423, Skewness: 12.14
# Feature: pv_중분류_즉석조리_구매횟수, Outlier Count: 1423, Skewness: 19.85
# Feature: pv_중분류_즉석조리_구입금액비중, Outlier Count: 1423, Skewness: 37.06
# Feature: 등급, Outlier Count: 1419, Skewness: -0.73
# Feature: pv_중분류_싸롱화_총구매금액, Outlier Count: 1417, Skewness: 7.02
# Feature: pv_중분류_싸롱화_구입금액비중, Outlier Count: 1417, Skewness: 8.05
# Feature: pv_중분류_수영복_총구매금액, Outlier Count: 1414, Skewness: 7.79
# Feature: pv_중분류_수영복_구입금액비중, Outlier Count: 1414, Skewness: 14.45
# Feature: pv_중분류_캐쥬얼구두_총구매금액, Outlier Count: 1413, Skewness: 6.30
# Feature: pv_중분류_캐쥬얼구두_구입금액비중, Outlier Count: 1413, Skewness: 8.61
# Feature: 11월_구매횟수, Outlier Count: 1412, Skewness: 3.53
# Feature: pv_중분류_수입종합화장품_구매횟수, Outlier Count: 1411, Skewness: 4.10
# Feature: pv_대분류_여성캐쥬얼_구매횟수, Outlier Count: 1399, Skewness: 5.12
# Feature: 저가_구매횟수, Outlier Count: 1390, Skewness: 5.34
# Feature: pv_대분류_아동_구매횟수, Outlier Count: 1378, Skewness: 10.56
# Feature: pv_중분류_내셔날_구매횟수, Outlier Count: 1373, Skewness: 8.06
# Feature: pv_대분류_아동_총구매금액, Outlier Count: 1371, Skewness: 16.44
# Feature: pv_대분류_아동_평균구매금액, Outlier Count: 1371, Skewness: 6.99
# Feature: pv_대분류_아동_구입금액비중, Outlier Count: 1371, Skewness: 7.35
# Feature: pv_중분류_하이캐쥬얼_구매횟수, Outlier Count: 1371, Skewness: 10.67
# Feature: 8월_구매횟수, Outlier Count: 1368, Skewness: 3.27
# Feature: 총구매액, Outlier Count: 1351, Skewness: 5.37
# Feature: 최대구매액, Outlier Count: 1350, Skewness: 8.56
# Feature: 여름휴가_총구매금액, Outlier Count: 1342, Skewness: 8.01
# Feature: 공휴일_구매횟수, Outlier Count: 1341, Skewness: 2.93
# Feature: pv_중분류_골프(국내)_구매횟수, Outlier Count: 1333, Skewness: 8.92
# Feature: pv_중분류_수입의류_구매횟수, Outlier Count: 1331, Skewness: 11.86
# Feature: 연말_총구매금액, Outlier Count: 1328, Skewness: 5.08
# Feature: 지점다양성_비율, Outlier Count: 1319, Skewness: 2.88
# Feature: pv_중분류_내셔날_총구매금액, Outlier Count: 1317, Skewness: 48.66
# Feature: pv_중분류_내셔날_구입금액비중, Outlier Count: 1317, Skewness: 6.82
# Feature: 공휴일_대분류_생식품_구매횟수, Outlier Count: 1308, Skewness: 6.34
# Feature: 공휴일_대분류_생식품_총구매금액, Outlier Count: 1305, Skewness: 9.65
# Feature: pv_중분류_하이캐쥬얼_총구매금액, Outlier Count: 1296, Skewness: 13.76
# Feature: pv_중분류_하이캐쥬얼_구입금액비중, Outlier Count: 1296, Skewness: 7.57
# Feature: pv_중분류_가정잡화_구매횟수, Outlier Count: 1286, Skewness: 6.83
# Feature: pv_중분류_캐릭터캐주얼_구매횟수, Outlier Count: 1283, Skewness: 14.02
# Feature: pv_중분류_골프(국내)_총구매금액, Outlier Count: 1282, Skewness: 31.54
# Feature: pv_중분류_골프(국내)_구입금액비중, Outlier Count: 1282, Skewness: 9.26
# Feature: 중분류_주방용품_구매주기, Outlier Count: 1280, Skewness: 5.06
# Feature: pv_중분류_가정잡화_총구매금액, Outlier Count: 1279, Skewness: 10.97
# Feature: pv_중분류_가정잡화_구입금액비중, Outlier Count: 1279, Skewness: 10.78
# Feature: pv_중분류_수입의류_총구매금액, Outlier Count: 1275, Skewness: 24.60
# Feature: pv_중분류_수입의류_구입금액비중, Outlier Count: 1275, Skewness: 6.99
# Feature: pv_대분류_잡화_구입금액비중, Outlier Count: 1252, Skewness: 2.32
# Feature: pv_대분류_여성캐쥬얼_평균구매금액, Outlier Count: 1248, Skewness: 4.18
# Feature: 2월_구매횟수, Outlier Count: 1244, Skewness: 3.18
# Feature: pv_중분류_조미료_총구매금액, Outlier Count: 1244, Skewness: 27.49
# Feature: pv_중분류_조미료_구매횟수, Outlier Count: 1244, Skewness: 8.79
# Feature: pv_중분류_조미료_구입금액비중, Outlier Count: 1244, Skewness: 22.89
# Feature: pv_대분류_케주얼_구두_아동_평균구매금액, Outlier Count: 1235, Skewness: 8.79
# Feature: pv_중분류_캐릭터캐주얼_총구매금액, Outlier Count: 1231, Skewness: 14.64
# Feature: pv_중분류_캐릭터캐주얼_구입금액비중, Outlier Count: 1231, Skewness: 9.93
# Feature: 대분류_영라이브_구매주기, Outlier Count: 1224, Skewness: 5.31
# Feature: 10월_구매횟수, Outlier Count: 1222, Skewness: 3.10
# Feature: pv_중분류_스포츠캐주얼_구매횟수, Outlier Count: 1217, Skewness: 10.95
# Feature: pv_중분류_신생아_구매횟수, Outlier Count: 1214, Skewness: 13.59
# Feature: pv_중분류_신생아_총구매금액, Outlier Count: 1202, Skewness: 22.35
# Feature: pv_중분류_신생아_구입금액비중, Outlier Count: 1202, Skewness: 11.55
# Feature: 11월_평균구매금액, Outlier Count: 1199, Skewness: 20.22
# Feature: 구매금액표준편차, Outlier Count: 1199, Skewness: 12.07
# Feature: pv_중분류_우산_장갑_구매횟수, Outlier Count: 1198, Skewness: 5.19
# Feature: pv_대분류_가정용품_구매횟수, Outlier Count: 1196, Skewness: 4.76
# Feature: pv_중분류_스포츠캐주얼_총구매금액, Outlier Count: 1192, Skewness: 12.83
# Feature: pv_중분류_스포츠캐주얼_구입금액비중, Outlier Count: 1192, Skewness: 10.92
# Feature: 대분류_아동문화_구매주기, Outlier Count: 1190, Skewness: 5.44
# Feature: 2월_평균구매금액, Outlier Count: 1189, Skewness: 12.33
# Feature: 중분류_아동복_구매주기, Outlier Count: 1182, Skewness: 5.39
# Feature: 중분류_셔츠_구매주기, Outlier Count: 1174, Skewness: 5.21
# Feature: pv_대분류_잡화_구매횟수, Outlier Count: 1169, Skewness: 3.91
# Feature: pv_중분류_우산_장갑_총구매금액, Outlier Count: 1169, Skewness: 22.31
# Feature: pv_중분류_우산_장갑_구입금액비중, Outlier Count: 1169, Skewness: 26.63
# Feature: 환불건수, Outlier Count: 1168, Skewness: 5.97
# Feature: 9시_12시_구매비율, Outlier Count: 1166, Skewness: 3.02
# Feature: 9시_12시_구매횟수, Outlier Count: 1166, Skewness: 3.02
# Feature: 중분류_청과_구매주기, Outlier Count: 1162, Skewness: 5.39
# Feature: 고가_구매횟수, Outlier Count: 1156, Skewness: 4.01
# Feature: pv_중분류_수입부띠끄_구매횟수, Outlier Count: 1147, Skewness: 25.41
# Feature: 최소구매액, Outlier Count: 1146, Skewness: 10.84
# Feature: 공휴일_대분류_명품잡화_구매횟수, Outlier Count: 1143, Skewness: 9.62
# Feature: 8월_평균구매금액, Outlier Count: 1137, Skewness: 7.34
# Feature: 공휴일_대분류_명품잡화_총구매금액, Outlier Count: 1128, Skewness: 13.16
# Feature: 대분류_영어덜트캐쥬얼_구매주기, Outlier Count: 1125, Skewness: 5.24
# Feature: pv_중분류_초도자기_구매횟수, Outlier Count: 1120, Skewness: 7.41
# Feature: 중분류_아동_구매주기, Outlier Count: 1119, Skewness: 5.48
# Feature: 중분류_일용잡화_구매주기, Outlier Count: 1119, Skewness: 5.23
# Feature: 중저가_구매횟수, Outlier Count: 1115, Skewness: 3.26
# Feature: 웨딩성수기_구매횟수, Outlier Count: 1111, Skewness: 3.01
# Feature: 웨딩성수기_전체_구매횟수, Outlier Count: 1111, Skewness: 3.01
# Feature: pv_중분류_란제리_구매횟수, Outlier Count: 1108, Skewness: 4.61
# Feature: 중고가_구매횟수, Outlier Count: 1105, Skewness: 3.02
# Feature: pv_중분류_영커리어캐주얼_구매횟수, Outlier Count: 1102, Skewness: 8.77
# Feature: pv_중분류_초도자기_총구매금액, Outlier Count: 1101, Skewness: 14.18
# Feature: pv_중분류_초도자기_구입금액비중, Outlier Count: 1101, Skewness: 20.37
# Feature: pv_중분류_어덜트_구매횟수, Outlier Count: 1095, Skewness: 12.08
# Feature: 12월_평균구매금액, Outlier Count: 1092, Skewness: 14.14
# Feature: pv_중분류_수입부띠끄_총구매금액, Outlier Count: 1088, Skewness: 18.68
# Feature: pv_중분류_수입부띠끄_구입금액비중, Outlier Count: 1088, Skewness: 8.37
# Feature: pv_중분류_곡물_구매횟수, Outlier Count: 1083, Skewness: 9.78
# Feature: pv_중분류_곡물_총구매금액, Outlier Count: 1080, Skewness: 11.47
# Feature: pv_중분류_곡물_구입금액비중, Outlier Count: 1080, Skewness: 23.75
# Feature: pv_중분류_토탈_구매횟수, Outlier Count: 1075, Skewness: 16.65
# Feature: 1월_평균구매금액, Outlier Count: 1069, Skewness: 34.48
# Feature: 공휴일_구매비율, Outlier Count: 1065, Skewness: 4.41
# Feature: 공휴일_대분류_케주얼_구두_아동_구매횟수, Outlier Count: 1059, Skewness: 8.15
# Feature: pv_중분류_영커리어캐주얼_총구매금액, Outlier Count: 1057, Skewness: 38.10
# Feature: pv_중분류_영커리어캐주얼_구입금액비중, Outlier Count: 1057, Skewness: 10.57
# Feature: pv_중분류_어덜트_총구매금액, Outlier Count: 1054, Skewness: 10.29
# Feature: pv_중분류_어덜트_구입금액비중, Outlier Count: 1054, Skewness: 10.88
# Feature: 공휴일_대분류_케주얼_구두_아동_총구매금액, Outlier Count: 1051, Skewness: 9.14
# Feature: 3월_평균구매금액, Outlier Count: 1038, Skewness: 8.98
# Feature: 중분류_영트랜드_구매주기, Outlier Count: 1038, Skewness: 6.11
# Feature: pv_대분류_명품잡화_평균구매금액, Outlier Count: 1036, Skewness: 17.35
# Feature: pv_중분류_넥타이_구매횟수, Outlier Count: 1036, Skewness: 23.76
# Feature: 공휴일_대분류_가정용품_구매횟수, Outlier Count: 1034, Skewness: 6.98
# Feature: 월말_구매횟수, Outlier Count: 1031, Skewness: 3.19
# Feature: pv_중분류_토탈_총구매금액, Outlier Count: 1029, Skewness: 30.12
# Feature: pv_중분류_토탈_구입금액비중, Outlier Count: 1029, Skewness: 13.09
# Feature: 내점일수, Outlier Count: 1024, Skewness: 2.80
# Feature: 중분류_스타킹_구매주기, Outlier Count: 1023, Skewness: 6.14
# Feature: 9월_평균구매금액, Outlier Count: 1021, Skewness: 24.85
# Feature: 중분류_핸드백_구매주기, Outlier Count: 1020, Skewness: 6.07
# Feature: 10월_평균구매금액, Outlier Count: 1019, Skewness: 12.64
# Feature: 대분류_영캐릭터_구매주기, Outlier Count: 1019, Skewness: 5.98
# Feature: pv_중분류_명품_구매횟수, Outlier Count: 1016, Skewness: 11.63
# Feature: pv_중분류_넥타이_총구매금액, Outlier Count: 1014, Skewness: 48.93
# Feature: pv_중분류_넥타이_구입금액비중, Outlier Count: 1014, Skewness: 19.06
# Feature: 공휴일_대분류_가정용품_총구매금액, Outlier Count: 1011, Skewness: 22.82
# Feature: 총구매횟수, Outlier Count: 1005, Skewness: 3.14
# Feature: 4월_구매횟수, Outlier Count: 1004, Skewness: 3.15
# Feature: 주말방문횟수, Outlier Count: 995, Skewness: 3.36
# Feature: 평일방문횟수, Outlier Count: 993, Skewness: 3.14
# Feature: 웨딩성수기_저가_구매횟수, Outlier Count: 990, Skewness: 4.62
# Feature: 대분류_로얄부틱_구매주기, Outlier Count: 982, Skewness: 6.47
# Feature: 12월_구매횟수, Outlier Count: 976, Skewness: 2.93
# Feature: pv_중분류_명품_총구매금액, Outlier Count: 968, Skewness: 23.71
# Feature: pv_중분류_명품_구입금액비중, Outlier Count: 968, Skewness: 8.80
# Feature: 5월_구매횟수, Outlier Count: 965, Skewness: 2.82
# Feature: 3월_구매비율, Outlier Count: 959, Skewness: 3.35
# Feature: 5월_평균구매금액, Outlier Count: 950, Skewness: 11.81
# Feature: pv_중분류_캐릭터슈즈_구매횟수, Outlier Count: 950, Skewness: 9.96
# Feature: 2월_구매비율, Outlier Count: 948, Skewness: 3.96
# Feature: pv_중분류_아동_문화_구매횟수, Outlier Count: 944, Skewness: 14.59
# Feature: 공휴일_대분류_패션잡화_구매횟수, Outlier Count: 944, Skewness: 7.46
# Feature: pv_중분류_아동_문화_총구매금액, Outlier Count: 939, Skewness: 40.77
# Feature: pv_중분류_아동_문화_구입금액비중, Outlier Count: 939, Skewness: 21.68
# Feature: 공휴일_대분류_패션잡화_총구매금액, Outlier Count: 938, Skewness: 10.44
# Feature: 평균구매액, Outlier Count: 935, Skewness: 17.91
# Feature: 6월_평균구매금액, Outlier Count: 934, Skewness: 26.11
# Feature: 월초_구매횟수, Outlier Count: 928, Skewness: 3.18
# Feature: pv_중분류_캐릭터캐쥬얼_구매횟수, Outlier Count: 923, Skewness: 12.08
# Feature: 중분류_진케주얼_구매주기, Outlier Count: 919, Skewness: 6.20
# Feature: pv_중분류_캐릭터슈즈_총구매금액, Outlier Count: 914, Skewness: 10.04
# Feature: pv_중분류_캐릭터슈즈_구입금액비중, Outlier Count: 914, Skewness: 13.98
# Feature: 7월_구매횟수, Outlier Count: 905, Skewness: 3.05
# Feature: pv_중분류_준보석_구매횟수, Outlier Count: 905, Skewness: 9.45
# Feature: pv_중분류_수입향수_구매횟수, Outlier Count: 904, Skewness: 7.67
# Feature: pv_중분류_팬시_구매횟수, Outlier Count: 902, Skewness: 8.98
# Feature: 공휴일_대분류_여성캐쥬얼_구매횟수, Outlier Count: 902, Skewness: 6.90
# Feature: 웨딩성수기_고가_구매횟수, Outlier Count: 901, Skewness: 3.65
# Feature: 7월_평균구매금액, Outlier Count: 898, Skewness: 27.53
# Feature: pv_중분류_수입향수_총구매금액, Outlier Count: 898, Skewness: 11.43
# Feature: pv_중분류_팬시_총구매금액, Outlier Count: 898, Skewness: 12.96
# Feature: pv_중분류_수입향수_구입금액비중, Outlier Count: 898, Skewness: 19.57
# Feature: pv_중분류_팬시_구입금액비중, Outlier Count: 898, Skewness: 30.82
# Feature: 4월_평균구매금액, Outlier Count: 891, Skewness: 16.02
# Feature: 10월_방문횟수, Outlier Count: 890, Skewness: 2.31
# Feature: 연말_구매횟수, Outlier Count: 887, Skewness: 3.07
# Feature: 8월_구매비율, Outlier Count: 883, Skewness: 3.76
# Feature: 6월_구매횟수, Outlier Count: 882, Skewness: 2.94
# Feature: 공휴일_대분류_여성캐쥬얼_총구매금액, Outlier Count: 881, Skewness: 16.88
# Feature: pv_중분류_캐릭터캐쥬얼_총구매금액, Outlier Count: 880, Skewness: 30.99
# Feature: pv_중분류_라이센스_구매횟수, Outlier Count: 880, Skewness: 9.26
# Feature: pv_중분류_캐릭터캐쥬얼_구입금액비중, Outlier Count: 880, Skewness: 11.19
# Feature: pv_대분류_생식품_평균구매금액, Outlier Count: 877, Skewness: 90.16
# Feature: pv_중분류_뉴베이직캐주얼_구매횟수, Outlier Count: 872, Skewness: 13.81
# Feature: 중분류_골프웨어_구매주기, Outlier Count: 872, Skewness: 6.71
# Feature: 12월_방문횟수, Outlier Count: 869, Skewness: 2.39
# Feature: pv_중분류_준보석_총구매금액, Outlier Count: 869, Skewness: 31.91
# Feature: pv_중분류_준보석_구입금액비중, Outlier Count: 869, Skewness: 14.50
# Feature: 여름휴가_구매횟수, Outlier Count: 868, Skewness: 3.17
# Feature: pv_중분류_머플러_구매횟수, Outlier Count: 867, Skewness: 6.91
# Feature: 대분류_아동_구매주기, Outlier Count: 865, Skewness: 6.72
# Feature: 대분류_공산품_구매주기, Outlier Count: 864, Skewness: 2.13
# Feature: 1월_구매횟수, Outlier Count: 863, Skewness: 2.92
# Feature: 중분류_욕실용품_구매주기, Outlier Count: 862, Skewness: 6.49
# Feature: 3월_구매횟수, Outlier Count: 856, Skewness: 3.20
# Feature: 6월_구매비율, Outlier Count: 853, Skewness: 2.90
# Feature: 휴면회원, Outlier Count: 853, Skewness: 3.82
# Feature: 4월_구매비율, Outlier Count: 850, Skewness: 2.89
# Feature: 6월_방문횟수, Outlier Count: 850, Skewness: 2.26
# Feature: pv_중분류_라이센스_총구매금액, Outlier Count: 850, Skewness: 12.76
# Feature: pv_중분류_라이센스_구입금액비중, Outlier Count: 850, Skewness: 8.92
# Feature: 9월_구매횟수, Outlier Count: 843, Skewness: 2.95
# Feature: pv_중분류_머플러_총구매금액, Outlier Count: 839, Skewness: 30.51
# Feature: pv_중분류_머플러_구입금액비중, Outlier Count: 839, Skewness: 19.12
# Feature: 5월_구매비율, Outlier Count: 837, Skewness: 3.14
# Feature: 5월_방문횟수, Outlier Count: 832, Skewness: 2.37
# Feature: pv_중분류_미시케쥬얼_구매횟수, Outlier Count: 829, Skewness: 12.06
# Feature: pv_대분류_잡화_평균구매금액, Outlier Count: 826, Skewness: 12.81
# Feature: 3월_방문횟수, Outlier Count: 823, Skewness: 2.44
# Feature: 봄_구매비율, Outlier Count: 820, Skewness: 1.26
# Feature: 중분류_유아복_구매주기, Outlier Count: 814, Skewness: 6.50
# Feature: 1월_구매비율, Outlier Count: 811, Skewness: 3.40
# Feature: pv_중분류_뉴베이직캐주얼_총구매금액, Outlier Count: 809, Skewness: 14.24
# Feature: pv_중분류_뉴베이직캐주얼_구입금액비중, Outlier Count: 809, Skewness: 9.89
# Feature: 중분류_생선_구매주기, Outlier Count: 795, Skewness: 6.22
# Feature: 9월_구매비율, Outlier Count: 778, Skewness: 3.38
# Feature: 중분류_일반조리_구매주기, Outlier Count: 775, Skewness: 6.47
# Feature: pv_중분류_미시케쥬얼_총구매금액, Outlier Count: 772, Skewness: 12.62
# Feature: pv_중분류_미시케쥬얼_구입금액비중, Outlier Count: 772, Skewness: 12.50
# Feature: 중분류_완구_구매주기, Outlier Count: 772, Skewness: 6.55
# Feature: 중분류_트래디셔널캐쥬얼_구매주기, Outlier Count: 771, Skewness: 6.69
# Feature: pv_대분류_패션잡화_평균구매금액, Outlier Count: 763, Skewness: 7.26
# Feature: pv_중분류_패션란제리_구매횟수, Outlier Count: 755, Skewness: 9.63
# Feature: 중분류_헤어ACC_구매주기, Outlier Count: 751, Skewness: 7.00

# %%
# 이상치 개수가 747개 이상인 피처들만 필터링
filtered_outliers = {feature: stats for feature, stats in outlier_stats.items() if stats['outlier_count'] >= 747}

# 훈련 데이터에 대해 로그 변환
for feature in filtered_outliers:
    # 훈련 데이터에서 0 또는 음수 값 처리 후 로그 변환
    train_ft[feature] = train_ft[feature].apply(lambda x: np.log(x + 1e-9) if x >= 0 else np.log(np.abs(x) + 1e-9))

# 테스트 데이터에 대해서도 훈련 데이터에서 동일한 방식으로 로그 변환
for feature in filtered_outliers:
    # 테스트 데이터에 대해 훈련 데이터에서 계산된 방식대로 처리
    test_ft[feature] = test_ft[feature].apply(lambda x: np.log(x + 1e-9) if x >= 0 else np.log(np.abs(x) + 1e-9))

# %% [markdown]
# # 제곱근 변환 (Square Root Transformation):
#
# - 값이 큰 범위에 몰려 있을 때 이를 줄여주기 위해 사용됩니다. 로그보다는 덜 극단적인 변환으로, 데이터의 분포를 완만하게 만듭니다.
#
# - 예를 들어, 인구 수 같은 양수 데이터에서 제곱근을 적용하면 값의 분포를 균형 잡힌 형태로 만들 수 있습니다.
#
# - 사용법: 양수 데이터를 대상으로 하며, np.sqrt(x)를 통해 제곱근을 적용할 수 있습니다.

# %% [markdown]
# ## 제곱근 변환만 적용

# %%
# 이상치 개수가 747개 이상인 피처들만 필터링
filtered_outliers = {feature: stats for feature, stats in outlier_stats.items() if stats['outlier_count'] >= 747}

# 훈련 데이터에 대해 제곱근 변환 적용
for feature in filtered_outliers:
    # 피처가 양수로만 이루어져 있는지 확인
    if (train_ft[feature] > 0).all():  # 모든 값이 양수일 때
        # 양수로만 이루어진 피처에는 제곱근 변환
        train_ft[feature] = train_ft[feature].apply(np.sqrt)
    else:
        # 0 또는 음수 값이 포함된 피처에도 제곱근 변환
        train_ft[feature] = train_ft[feature].apply(lambda x: np.sqrt(np.abs(x)) if x >= 0 else 0)

# 테스트 데이터에 대해서도 동일한 방식으로 제곱근 변환 적용
for feature in filtered_outliers:
    # 피처가 양수로만 이루어져 있는지 확인
    if (test_ft[feature] > 0).all():  # 모든 값이 양수일 때
        # 양수로만 이루어진 피처에는 제곱근 변환
        test_ft[feature] = test_ft[feature].apply(np.sqrt)
    else:
        # 0 또는 음수 값이 포함된 피처에도 제곱근 변환
        test_ft[feature] = test_ft[feature].apply(lambda x: np.sqrt(np.abs(x)) if x >= 0 else 0)

# %% [markdown]
#  ## 양수로만 이루어진 피처는 제곱근 이외는 로그변환

# %%
# 이상치 개수가 747개 이상인 피처들만 필터링
filtered_outliers = {feature: stats for feature, stats in outlier_stats.items() if stats['outlier_count'] >= 747}

# 훈련 데이터에 대해 변환 적용
for feature in filtered_outliers:
    # 피처가 양수로만 이루어져 있는지 확인
    if (train_ft[feature] > 0).all():  # 모든 값이 양수일 때
        # 양수로만 이루어진 피처에는 제곱근 변환
        train_ft[feature] = train_ft[feature].apply(np.sqrt)
    else:
        # 0 또는 음수 값이 포함된 피처에는 로그 변환
        train_ft[feature] = train_ft[feature].apply(lambda x: np.log(x + 1e-9) if x >= 0 else np.log(np.abs(x) + 1e-9))

# 테스트 데이터에 대해서도 동일한 방식으로 변환 적용
for feature in filtered_outliers:
    # 피처가 양수로만 이루어져 있는지 확인
    if (test_ft[feature] > 0).all():  # 모든 값이 양수일 때
        # 양수로만 이루어진 피처에는 제곱근 변환
        test_ft[feature] = test_ft[feature].apply(np.sqrt)
    else:
        # 0 또는 음수 값이 포함된 피처에는 로그 변환
        test_ft[feature] = test_ft[feature].apply(lambda x: np.log(x + 1e-9) if x >= 0 else np.log(np.abs(x) + 1e-9))

# %% [markdown]
# ## 피처 값 중 양수는 제곱근 변환 이외에는 로그 변환

# %%
# 이상치 개수가 747개 이상인 피처들만 필터링
filtered_outliers = {feature: stats for feature, stats in outlier_stats.items() if stats['outlier_count'] >= 747}

# 훈련 데이터에 대해 변환 적용
for feature in filtered_outliers:
    # 양수인 값은 제곱근 변환, 0 이하의 값은 로그 변환
    train_ft[feature] = train_ft[feature].apply(
        lambda x: np.sqrt(x) if x > 0 else np.log(x + 1e-9)  # 0 이하의 값은 로그 변환
    )
    # 변환 후 NaN 값이 있을 경우 0으로 대체
    train_ft[feature] = train_ft[feature].fillna(0)

# 테스트 데이터에 대해서도 동일한 방식으로 변환 적용
for feature in filtered_outliers:
    # 양수인 값은 제곱근 변환, 0 이하의 값은 로그 변환
    test_ft[feature] = test_ft[feature].apply(
        lambda x: np.sqrt(x) if x > 0 else np.log(x + 1e-9)  # 0 이하의 값은 로그 변환
    )
    # 변환 후 NaN 값이 있을 경우 0으로 대체
    test_ft[feature] = test_ft[feature].fillna(0)
# Out:
# <ipython-input-11-93a17ec4e807>:8: RuntimeWarning: invalid value encountered in log
#   lambda x: np.sqrt(x) if x > 0 else np.log(x + 1e-9)  # 0 이하의 값은 로그 변환
# <ipython-input-11-93a17ec4e807>:17: RuntimeWarning: invalid value encountered in log
#   lambda x: np.sqrt(x) if x > 0 else np.log(x + 1e-9)  # 0 이하의 값은 로그 변환

# %% [markdown]
# # 지수 변환 (Exponential Transformation):
#
# - 주로 값을 확장해야 하는 경우 사용합니다. 예를 들어, 분포가 너무 작게 몰려 있을 때 지수 변환을 통해 데이터의 차이를 크게 만들어 모델이 차이를 더 잘 학습하게 할 수 있습니다.
#
# - 사용법: np.exp(x)로 변환합니다. 다만, 값이 너무 커질 수 있으니 주의가 필요합니다.

# %% [markdown]
# # Box-Cox 변환 (Box-Cox Transformation)
#
# - 데이터 분포가 치우쳐져 있는 경우, 특히 정규 분포에 가깝게 만들기 위해 사용하는 변환 방법입니다.
#
# - Box-Cox는 **람다(λ)**라는 파라미터를 사용해 최적의 변환을 찾습니다. 이 변환을 통해 데이터 분포를 정규에 가깝게 조정할 수 있습니다.
#
# - 사용법: SciPy의 boxcox 함수를 사용하며, 데이터는 양수여야 합니다.

# %% [markdown]
# # 역변환
#
# - 데이터의 값이 클수록 작은 값으로 줄어들게 만드는 방식으로, 비대칭 분포를 조정할 때 유용합니다.
#
# - 사용법: 역수를 취해 변환하며, 1/x 형태로 사용할 수 있습니다.

# %% [markdown]
# # 피처 공학 및 스케일링

# %%
# ID 제거
train_ft = train_ft.iloc[:,1:]
test_ft = test_ft.iloc[:,1:]
train_ft.shape, test_ft.shape
# Out:
# ((14940, 1469), (12225, 1469))

# %%
cols = train_ft.select_dtypes("object").columns.tolist()
train_ft[cols].nunique()
# Out:
# 주구매지점        4
# 주구매_대분류     22
# 주구매_중분류    238
# dtype: int64

# %%
# %pip install category_encoders
# Out:
# Collecting category_encoders
#   Downloading category_encoders-2.6.4-py2.py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (1.26.4)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (1.5.2)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (1.13.1)
# Requirement already satisfied: statsmodels>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (0.14.4)
# Requirement already satisfied: pandas>=1.0.5 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (2.2.2)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (0.5.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.5->category_encoders) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.5->category_encoders) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.5->category_encoders) (2024.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.1->category_encoders) (1.16.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->category_encoders) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->category_encoders) (3.5.0)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.9.0->category_encoders) (24.2)
# Downloading category_encoders-2.6.4-py2.py3-none-any.whl (82 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.0/82.0 kB 7.4 MB/s eta 0:00:00
# Installing collected packages: category_encoders
# Successfully installed category_encoders-2.6.4

# %%
import category_encoders as ce
from sklearn.preprocessing import StandardScaler

enc = ce.one_hot.OneHotEncoder()
tmp = enc.fit_transform(train_ft["주구매지점"])
train_ft = pd.concat([train_ft,tmp],axis =1)

tmp = enc.transform(test_ft["주구매지점"])
test_ft = pd.concat([test_ft,tmp],axis =1)

train_ft.shape, test_ft.shape
# Out:
# ((14940, 1473), (12225, 1473))

# %%
enc = ce.count.CountEncoder()
train_ft["주구매_중분류_cnt"] = enc.fit_transform(train_ft[["주구매_중분류"]])
test_ft["주구매_중분류_cnt"] = enc.transform(test_ft[["주구매_중분류"]])

train_ft["주구매_대분류_cnt"] = enc.fit_transform(train_ft[["주구매_대분류"]])
test_ft["주구매_대분류_cnt"] = enc.transform(test_ft[["주구매_대분류"]])

train_ft.shape, test_ft.shape
# Out:
# ((14940, 1475), (12225, 1475))

# %%
train_ft = train_ft.drop(columns=cols)
test_ft = test_ft.drop(columns=cols)
train_ft.shape, test_ft.shape
# Out:
# ((14940, 1472), (12225, 1472))

# %%
scaler = StandardScaler()

train_ft[train_ft.columns] = scaler.fit_transform(train_ft)
test_ft[test_ft.columns] = scaler.transform(test_ft)
train_ft.head()
# Out:
#        내점일수      구매주기    주말방문비율    평일방문비율    주말방문횟수    평일방문횟수    봄_구매비율  \
# 0 -0.255374  0.002987  0.257728 -0.257728  0.428635 -0.128919  0.346813
# 1  0.402970 -0.356452 -1.008554  1.008554  0.294145  0.554897  0.398608
# 2  1.911468 -0.869935  0.036742 -0.036742  0.718373  1.388325  0.410273
# 3  3.007893 -1.023980 -0.080558  0.080558  0.873482  2.358551  0.401120
# 4  0.722054 -0.613193  0.302875 -0.302875  0.620560  0.657384  0.362380
#
#     여름_구매비율   가을_구매비율   겨울_구매비율  ...  공휴일_대분류_영플라자_구매횟수  공휴일_대분류_잡화_구매횟수  \
# 0  0.001191  0.838272  0.338186  ...          -0.162079        -0.352780
# 1 -0.390607  0.620171 -0.552996  ...           2.389509        -0.352780
# 2 -0.514333 -0.304527 -0.059266  ...          -0.162079        -0.352780
# 3 -0.327474  0.008592 -0.135636  ...          10.044273        -0.352780
# 4  1.707410 -0.130285 -0.821561  ...          -0.162079         2.905522
#
#    공휴일_대분류_케주얼_구두_아동_구매횟수  공휴일_대분류_패션잡화_구매횟수   주구매지점_1   주구매지점_2   주구매지점_3  \
# 0               -0.276145          -0.259675  1.654066 -0.623175 -0.612523
# 1               -0.276145           3.890999 -0.604571  1.604686 -0.612523
# 2               -0.276145          -0.259675 -0.604571 -0.623175  1.632592
# 3                3.562547          -0.259675  1.654066 -0.623175 -0.612523
# 4                3.691907          -0.259675  1.654066 -0.623175 -0.612523
#
#     주구매지점_4  주구매_중분류_cnt  주구매_대분류_cnt
# 0 -0.468181    -0.741478    -1.315250
# 1 -0.468181    -0.448069    -0.626416
# 2 -0.468181    -0.869072     1.064726
# 3 -0.468181     1.515861    -0.248364
# 4 -0.468181    -0.847712     1.064726
#
# [5 rows x 1472 columns]

# %%
train_ft.isnull().sum().sum(), test_ft.isnull().sum().sum()
# Out:
# (0, 0)

# %%
target = train_target["target"]

# %% [markdown]
# # 점수 확인

# %%
import numpy as np
import xgboost as xgb
from xgboost import XGBClassifier
from sklearn.metrics import f1_score
from sklearn.model_selection import StratifiedKFold

params = {'n_estimators': 1000,
 'learning_rate': 0.027075406407767497,
 'max_depth': 5,
 'min_child_weight': 7,
 'subsample': 0.6789816859997232,
 'colsample_bytree': 0.6682531834544282,
 'gamma': 1.5046881781916308}

# F1 매크로 스코어와 모델을 저장할 리스트
scores = []
models = []

# Stratified K-Fold 교차 검증 설정
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# 교차 검증 루프
for tri, vai in cv.split(train_ft, target):
    # 학습 데이터와 검증 데이터 분리
    x_train = train_ft.iloc[tri]
    y_train = target.iloc[tri]
    x_valid = train_ft.iloc[vai]
    y_valid = target.iloc[vai]

    # 모델 초기화 및 학습
    model = XGBClassifier(**params)
    model.fit(x_train, y_train, eval_set=[(x_valid, y_valid)], verbose=False)

    # 모델 저장
    models.append(model)

    # 예측 및 F1 매크로 스코어 계산
    pred = model.predict(x_valid)
    score = f1_score(y_valid, pred, average='macro')
    scores.append(score)

# F1 매크로 스코어의 평균 출력
print("Mean F1 Macro Score:", np.mean(scores))

# 이상치 기준 상위 500개 피처 로그변환 -> 0.7227222269087612
# 전체 데이터 중 이상치가 5% 이상인 피처에 대한 로그변환 -> 0.7227222269087612
# 제곱근 변환 -> 0.7209092345457006
# 양수로만 이뤄진 수치형 데이터는 제곱근 변환 + 나머지는 로그 변환 -> 0.7227222269087612
# 각 피처의 값 중 양수는 제곱근 변환, 나머지 0과 음수일 경우 로그 변환 -> 0.7234808173962948
# Out:
# Mean F1 Macro Score: 0.7234808173962948

# %% [markdown]
# ----

# %%
model = XGBClassifier(random_state=SEED, **params)
model.fit(train_ft, target)

# %%
pred = model.predict(test_ft)
submit["target"] = pred
submit.to_csv("log_sqrt_transform.csv", index=False)

# %%
train_ft.to_csv("train_common_v3.3_피처삭제X_log_sqrt.csv",index=False)
test_ft.to_csv("test_common_v3.3_피처삭제X_log_sqrt.csv",index=False)

# %% [markdown]
# # Optuna

# %%
# %pip install optuna

# %%
import optuna
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# %% [markdown]
# ## XGBOOST

# %%
from sklearn.model_selection import StratifiedKFold, cross_val_score
import xgboost as xgb
from xgboost import XGBClassifier

# 목적함수를 클래스로 만들기
class Objective:
    # 변수 설정
    def __init__(self, x, y, seed):
        self.x = x
        self.y = y
        self.seed = seed
        self.cv = StratifiedKFold(5, shuffle= True, random_state= self.seed)

    def __call__(self, trial):  # 콜백함수 역할
        hp = {  "n_estimators": trial.suggest_int("n_estimators", 100, 1000, step=100),
                "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3, log=True),
                "max_depth": trial.suggest_int("max_depth", 3, 10),
                "min_child_weight": trial.suggest_int("min_child_weight", 1, 10),
                "subsample": trial.suggest_float("subsample", 0.5, 1.0),
                "colsample_bytree": trial.suggest_float("colsample_bytree", 0.5, 1.0),
                "gamma": trial.suggest_float("gamma", 0, 5)  }
        model = XGBClassifier(**hp, random_state= self.seed)
        score = cross_val_score(model, self.x, self.y, cv= self.cv, scoring= "f1_macro", n_jobs= -1).mean()
        return score

# Sampler 객체 생성(대체모델 역할)
sampler = optuna.samplers.TPESampler(seed= SEED)

# study 객체 생성
study = optuna.create_study(direction= "maximize", sampler= sampler)

# optimize 매서드 실행
objective_func = Objective(train_ft, target, SEED)
study.optimize(objective_func, n_trials= 100)
# Out:
# [I 2024-11-12 08:24:56,307] A new study created in memory with name: no-name-b533bcd4-7568-49f3-b0f1-564ac63a6a81
# [I 2024-11-12 08:33:12,712] Trial 0 finished with value: 0.6886174135705478 and parameters: {'n_estimators': 400, 'learning_rate': 0.2536999076681772, 'max_depth': 8, 'min_child_weight': 6, 'subsample': 0.5780093202212182, 'colsample_bytree': 0.5779972601681014, 'gamma': 0.2904180608409973}. Best is trial 0 with value: 0.6886174135705478.
# [I 2024-11-12 08:44:47,172] Trial 1 finished with value: 0.7115088283992492 and parameters: {'n_estimators': 900, 'learning_rate': 0.07725378389307355, 'max_depth': 8, 'min_child_weight': 1, 'subsample': 0.9849549260809971, 'colsample_bytree': 0.9162213204002109, 'gamma': 1.0616955533913808}. Best is trial 1 with value: 0.7115088283992492.
# [I 2024-11-12 08:48:33,829] Trial 2 finished with value: 0.706431646271415 and parameters: {'n_estimators': 200, 'learning_rate': 0.018659959624904916, 'max_depth': 5, 'min_child_weight': 6, 'subsample': 0.7159725093210578, 'colsample_bytree': 0.645614570099021, 'gamma': 3.0592644736118975}. Best is trial 1 with value: 0.7115088283992492.
# [I 2024-11-12 08:52:06,075] Trial 3 finished with value: 0.7101685929403544 and parameters: {'n_estimators': 200, 'learning_rate': 0.027010527749605478, 'max_depth': 5, 'min_child_weight': 5, 'subsample': 0.8925879806965068, 'colsample_bytree': 0.5998368910791798, 'gamma': 2.571172192068058}. Best is trial 1 with value: 0.7115088283992492.
# [I 2024-11-12 09:05:10,653] Trial 4 finished with value: 0.7181539607580094 and parameters: {'n_estimators': 600, 'learning_rate': 0.011711509955524094, 'max_depth': 7, 'min_child_weight': 2, 'subsample': 0.5325257964926398, 'colsample_bytree': 0.9744427686266666, 'gamma': 4.828160165372797}. Best is trial 4 with value: 0.7181539607580094.
# [I 2024-11-12 09:13:31,251] Trial 5 finished with value: 0.7201997603899725 and parameters: {'n_estimators': 900, 'learning_rate': 0.028180680291847244, 'max_depth': 3, 'min_child_weight': 7, 'subsample': 0.7200762468698007, 'colsample_bytree': 0.5610191174223894, 'gamma': 2.475884550556351}. Best is trial 5 with value: 0.7201997603899725.
# [I 2024-11-12 09:15:08,077] Trial 6 finished with value: 0.7085948917296543 and parameters: {'n_estimators': 100, 'learning_rate': 0.22038218939289875, 'max_depth': 5, 'min_child_weight': 7, 'subsample': 0.6558555380447055, 'colsample_bytree': 0.7600340105889054, 'gamma': 2.7335513967163982}. Best is trial 5 with value: 0.7201997603899725.
# [I 2024-11-12 09:17:23,845] Trial 7 finished with value: 0.7066481075876856 and parameters: {'n_estimators': 200, 'learning_rate': 0.27051668818999286, 'max_depth': 9, 'min_child_weight': 10, 'subsample': 0.9474136752138245, 'colsample_bytree': 0.7989499894055425, 'gamma': 4.609371175115584}. Best is trial 5 with value: 0.7201997603899725.
# [I 2024-11-12 09:19:11,220] Trial 8 finished with value: 0.665835272363746 and parameters: {'n_estimators': 100, 'learning_rate': 0.01947558230629543, 'max_depth': 3, 'min_child_weight': 4, 'subsample': 0.6943386448447411, 'colsample_bytree': 0.6356745158869479, 'gamma': 4.143687545759647}. Best is trial 5 with value: 0.7201997603899725.
# [I 2024-11-12 09:25:50,305] Trial 9 finished with value: 0.7184535184553407 and parameters: {'n_estimators': 400, 'learning_rate': 0.026000059117302653, 'max_depth': 7, 'min_child_weight': 2, 'subsample': 0.9010984903770198, 'colsample_bytree': 0.5372753218398854, 'gamma': 4.9344346830025865}. Best is trial 5 with value: 0.7201997603899725.
# [I 2024-11-12 09
. Best is trial 37 with value: 0.7231554675553863.
# [I 2024-11-12 13:52:36,010] Trial 38 finished with value: 0.7228076654802468 and parameters: {'n_estimators': 900, 'learning_rate': 0.022046821531260603, 'max_depth': 7, 'min_child_weight': 5, 'subsample': 0.6978407458116727, 'colsample_bytree': 0.5867945008351153, 'gamma': 2.223922260504907}. Best is trial 37 with value: 0.7231554675553863.
# [I 2024-11-12 14:07:02,910] Trial 39 finished with value: 0.7222289652625347 and parameters: {'n_estimators': 900, 'learning_rate': 0.019056335988497812, 'max_depth': 7, 'min_child_weight': 5, 'subsample': 0.6678662171528643, 'colsample_bytree': 0.5924354647849017, 'gamma': 1.0530297634027552}. Best is trial 37 with value: 0.7231554675553863.
# [I 2024-11-12 14:22:06,524] Trial 40 finished with value: 0.7195204142977488 and parameters: {'n_estimators': 800, 'learning_rate': 0.013496594582833872, 'max_depth': 8, 'min_child_weight': 4, 'subsample': 0.5876474386085778, 'colsample_bytree': 0.5264569553098105, 'gamma': 2.6279419786891336}. Best is trial 37 with value: 0.7231554675553863.
# [I 2024-11-12 14:35:54,419] Trial 41 finished with value: 0.7212723734418512 and parameters: {'n_estimators': 900, 'learning_rate': 0.02352352874416038, 'max_depth': 7, 'min_child_weight': 5, 'subsample': 0.7089535202388636, 'colsample_bytree': 0.5603880638875628, 'gamma': 2.2627508097723834}. Best is trial 37 with value: 0.7231554675553863.
# [I 2024-11-12 14:51:31,113] Trial 42 finished with value: 0.7212091895013597 and parameters: {'n_estimators': 900, 'learning_rate': 0.019405276699462147, 'max_depth': 8, 'min_child_weight': 6, 'subsample': 0.6992195667663831, 'colsample_bytree': 0.5834352560558488, 'gamma': 2.4167235648262313}. Best is trial 37 with value: 0.7231554675553863.
# [I 2024-11-12 15:05:31,816] Trial 43 finished with value: 0.7212640013477036 and parameters: {'n_estimators': 1000, 'learning_rate': 0.02510553775052193, 'max_depth': 6, 'min_child_weight': 3, 'subsample': 0.6485071534184823, 'colsample_bytree': 0.5438107514669936, 'gamma': 2.0184540429282007}. Best is trial 37 with value: 0.7231554675553863.

# %%
xgb_best_params = {'n_estimators': 900,
                   'learning_rate': 0.021734683976721573,
                   'max_depth': 6,
                   'min_child_weight': 5,
                   'subsample': 0.7039147285447092,
                   'colsample_bytree': 0.5823954097077503,
                   'gamma': 2.3107011128410493}
# 0.7231554675553863

# %%
print(study.best_trial.value)
print(study.best_trial.params)

# %% [markdown]
# ## LGBM

# %%
from lightgbm import LGBMClassifier
# Out:
# /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)

# %%
def objective(trial):
    hp = {
        "num_leaves": trial.suggest_int("num_leaves", 20, 150),               # 리프 노드의 수
        "max_depth": trial.suggest_int("max_depth", 3, 15),                   # 최대 트리 깊이
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3, log=True),  # 학습률
        "n_estimators": trial.suggest_int("n_estimators", 100, 1000, step=100),      # 부스팅 단계 수
        "min_child_samples": trial.suggest_int("min_child_samples", 5, 100),  # 최소 데이터 수
        "subsample": trial.suggest_float("subsample", 0.6, 1.0, step=0.1),    # 샘플링 비율
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.6, 1.0, step=0.1),  # 피처 샘플링 비율
        "reg_alpha": trial.suggest_float("reg_alpha", 1e-8, 10.0, log=True),  # L1 규제
        "reg_lambda": trial.suggest_float("reg_lambda", 1e-8, 10.0, log=True) # L2 규제
    }

    model = LGBMClassifier(**hp, random_state=SEED)
    score = cross_val_score(model, train_ft, target, cv=cv, scoring="f1_macro", n_jobs=-1).mean()
    return score

sampler = optuna.samplers.TPESampler(seed=SEED) # 대체 모델 역할은 sampler 객체

# study 객체
study = optuna.create_study(
    direction="maximize",
    sampler = sampler
)

study.optimize(objective, n_trials=50)   # optimze 메서드에 콜백 함수(objective) 전달
# Out:
# [I 2024-11-12 15:50:00,454] A new study created in memory with name: no-name-ad2e0a12-ea88-411c-8784-d3a8d3e953fb
# [I 2024-11-12 15:54:48,972] Trial 0 finished with value: 0.7108780019097494 and parameters: {'num_leaves': 69, 'max_depth': 15, 'learning_rate': 0.1205712628744377, 'n_estimators': 600, 'min_child_samples': 19, 'subsample': 0.6, 'colsample_bytree': 0.6, 'reg_alpha': 0.6245760287469893, 'reg_lambda': 0.002570603566117598}. Best is trial 0 with value: 0.7108780019097494.
# [I 2024-11-12 15:56:52,862] Trial 1 finished with value: 0.7039690030821333 and parameters: {'num_leaves': 112, 'max_depth': 3, 'learning_rate': 0.2708160864249968, 'n_estimators': 900, 'min_child_samples': 25, 'subsample': 0.6, 'colsample_bytree': 0.6, 'reg_alpha': 5.472429642032198e-06, 'reg_lambda': 0.00052821153945323}. Best is trial 0 with value: 0.7108780019097494.
# [I 2024-11-12 15:57:57,053] Trial 2 finished with value: 0.7142086215730521 and parameters: {'num_leaves': 76, 'max_depth': 6, 'learning_rate': 0.08012737503998542, 'n_estimators': 200, 'min_child_samples': 33, 'subsample': 0.7, 'colsample_bytree': 0.8, 'reg_alpha': 0.1165691561324743, 'reg_lambda':
. Best is trial 19 with value: 0.7252597292985927.
# [I 2024-11-12 18:56:12,657] Trial 48 finished with value: 0.7190477358432057 and parameters: {'num_leaves': 43, 'max_depth': 11, 'learning_rate': 0.03490935428293426, 'n_estimators': 1000, 'min_child_samples': 76, 'subsample': 0.9, 'colsample_bytree': 0.9, 'reg_alpha': 0.018854067017998136, 'reg_lambda': 0.0008552181206794726}. Best is trial 19 with value: 0.7252597292985927.
# [I 2024-11-12 18:59:46,059] Trial 49 finished with value: 0.7186429396282097 and parameters: {'num_leaves': 96, 'max_depth': 7, 'learning_rate': 0.01175064717129176, 'n_estimators': 900, 'min_child_samples': 67, 'subsample': 1.0, 'colsample_bytree': 0.7, 'reg_alpha': 4.9513015056531776e-08, 'reg_lambda': 2.868329686680271e-08}. Best is trial 19 with value: 0.7252597292985927.

# %%
lgbm_best_params = {'num_leaves': 33,
                    'max_depth': 11,
                    'learning_rate': 0.01944354088862471,
                    'n_estimators': 800,
                    'min_child_samples': 65,
                    'subsample': 0.8,
                    'colsample_bytree': 0.8,
                    'reg_alpha': 3.6529269182968447e-07,
                    'reg_lambda': 3.3190277841665685e-07}

# 0.7252597292985927

# %%
from lightgbm import LGBMClassifier

model = LGBMClassifier(**lgbm_best_params, random_state=SEED)
model.fit(train_ft, target)

pred = model.predict(test_ft)
submit["target"] = pred
submit.to_csv("log_sqrt_LGBM.csv", index=False)
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 5874, number of negative: 9066
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.284892 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 135303
# [LightGBM] [Info] Number of data points in the train set: 14940, number of used features: 1185
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.393173 -> initscore=-0.433995
# [LightGBM] [Info] Start training from score -0.433995
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf

# %%
# 최적의 하이퍼파라미터 출력
print(f"Best trial: {study.best_trial.value}")
print(f"Best hyperparameters: {study.best_trial.params}")

# %% [markdown]
# ## GBM

# %%
from sklearn.ensemble import GradientBoostingClassifier

# Objective function
def objective(trial):
    hp = {
        "max_depth": trial.suggest_int("max_depth", 3, 15),                       # 최대 트리 깊이
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3, log=True), # 학습률
        "n_estimators": trial.suggest_int("n_estimators", 100, 1000, step=100),    # 부스팅 단계 수
        "min_samples_split": trial.suggest_int("min_samples_split", 2, 100),       # 최소 분할 샘플 수
        "min_samples_leaf": trial.suggest_int("min_samples_leaf", 1, 100),         # 리프 노드의 최소 샘플 수
        "subsample": trial.suggest_float("subsample", 0.6, 1.0, step=0.1),         # 샘플링 비율
        "max_features": trial.suggest_float("max_features", 0.6, 1.0, step=0.1)    # 피처 샘플링 비율
    }

    model = GradientBoostingClassifier(**hp, random_state=SEED)
    score = cross_val_score(model, train_ft, target, cv=cv, scoring="f1_macro", n_jobs=-1).mean()
    return score

# Sampler
sampler = optuna.samplers.TPESampler(seed=SEED)

# Study 객체 생성
study = optuna.create_study(
    direction="maximize",
    sampler=sampler
)

study.optimize(objective, n_trials=50)  # objective 함수 전달
# Out:
# [I 2024-11-13 17:25:26,804] A new study created in memory with name: no-name-ff1f8c55-e18b-463f-88d8-f81997b49852
# [I 2024-11-13 18:01:40,565] Trial 0 finished with value: 0.6928428189461788 and parameters: {'max_depth': 7, 'learning_rate': 0.2536999076681772, 'n_estimators': 800, 'min_samples_split': 61, 'min_samples_leaf': 16, 'subsample': 0.6, 'max_features': 0.6}. Best is trial 0 with value: 0.6928428189461788.
# [W 2024-11-13 19:43:33,136] Trial 1 failed with parameters: {'max_depth': 14, 'learning_rate': 0.07725378389307355, 'n_estimators': 800, 'min_samples_split': 4, 'min_samples_leaf': 97, 'subsample': 1.0, 'max_features': 0.7} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/optuna/study/_optimize.py", line 197, in _run_trial
#     value_or_values = func(trial)
#   File "<ipython-input-28-2dbc0ce54c35>", line 16, in objective
#     score = cross_val_score(model, train_ft, target, cv=cv, scoring="f1_macro", n_jobs=-1).mean()
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 712, in cross_val_score
#     cv_results = cross_validate(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 423, in cross_validate
#     results = parallel(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py", line 74, in __call__
#     return super().__call__(iterable_with_config)
#   File "/usr/local/lib/python3.10/dist-packages/joblib/parallel.py", line 2007, in __call__
#     return output if self.return_generator else list(output)
#   File "/usr/local/lib/python3.10/dist-packages/joblib/parallel.py", line 1650, in _get_outputs
#     yield from self._retrieve()
#   File "/usr/local/lib/python3.10/dist-packages/joblib/parallel.py", line 1762, in _retrieve
#     time.sleep(0.01)
# KeyboardInterrupt
# [W 2024-11-13 19:43:33,177] Trial 1 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-2dbc0ce54c35> in <cell line: 28>()
#      26 )
#      27
# ---> 28 study.optimize(objective, n_trials=50)  # objective 함수 전달
#
# /usr/local/lib/python3.10/dist-packages/optuna/study/study.py in optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     473                 If nested invocation of this method occurs.
#     474         """
# --> 475         _optimize(
#     476             study=self,
#     477             func=func,
#
# /usr/local/lib/python3.10/dist-packages/optuna/study/_optimize.py in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      61     try:
#      62         if n_jobs == 1:
# ---> 63             _optimize_sequential(
#      64                 study,
#      65                 func,
#
# /usr/local/lib/python3.10/dist-packages/optuna/study/_optimize.py in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     158
#     159         try:
# --> 160             frozen_trial = _run_trial(study, func, catch)
#     161         finally:
#     162             # The following line mitigates memory problems that can be occurred in some
#
# /usr/local/lib/python3.10/dist-packages/optuna/study/_optimize.py in _run_trial(study, func, catch)
#     246         and not isinstance(func_err, catch)
#     247     ):
# --> 248         raise func_err
#     249     return frozen_trial
#     250
#
# /usr/local/lib/python3.10/dist-packages/optuna/study/_optimize.py in _run_trial(study, func, catch)
#     195     with get_heartbeat_thread(trial._trial_id, study._storage):
#     196         try:
# --> 197             value_or_values = func(trial)
#     198         except exceptions.TrialPruned as e:
#     199             # TODO(mamu): Handle multi-objective cases.
#
# <ipython-input-28-2dbc0ce54c35> in objective(trial)
#      14
#      15     model = GradientBoostingClassifier(**hp, random_state=SEED)
# ---> 16     score = cross_val_score(model, train_ft, target, cv=cv, scoring="f1_macro", n_jobs=-1).mean()
#      17     return score
#      18
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_param_validation.py in wrapper(*args, **kwargs)
#     211                     )
#     212                 ):
# --> 213                     return func(*args, **kwargs)
#     214             except InvalidParameterError as e:
#     215                 # When the function is just a wrapper around an estimator, we allow
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, params, pre_dispatch, error_score)
#     710     scorer = check_scoring(estimator, scoring=scoring)
#     711
# --> 712     cv_results = cross_validate(
#     713         estimator=estimator,
#     714         X=X,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_param_validation.py in wrapper(*args, **kwargs)
#     211                     )
#     212                 ):
# --> 213                     return func(*args, **kwargs)
#     214             except InvalidParameterError as e:
#     215                 # When the function is just a wrapper around an estimator, we allow
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, params, pre_dispatch, return_train_score, return_estimator, return_indices, error_score)
#     421     # independent, and that it is pickle-able.
#     422     parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
# --> 423     results = parallel(
#     424         delayed(_fit_and_score)(
#     425             clone(estimator),
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py in __call__(self, iterable)
#      72             for delayed_func, args, kwargs in iterable
#      73         )
# ---> 74         return super().__call__(iterable_with_config)
#      75
#      76
#
# /usr/local/lib/python3.10/dist-packages/joblib/parallel.py in __call__(self, iterable)
#    2005         next(output)
#    2006
# -> 2007         return output if self.return_generator else list(output)
#    2008
#    2009     def __repr__(self):
#
# /usr/local/lib/python3.10/dist-packages/joblib/parallel.py in _get_outputs(self, iterator, pre_dispatch)
#    1648
#    1649             with self._backend.retrieval_context():
# -> 1650                 yield from self._retrieve()
#    1651
#    1652         except GeneratorExit:
#
# /usr/local/lib/python3.10/dist-packages/joblib/parallel.py in _retrieve(self)
#    1760                 (self._jobs[0].get_status(
#    1761                     timeout=self.timeout) == TASK_PENDING)):
# -> 1762                 time.sleep(0.01)
#    1763                 continue
#    1764
#
# KeyboardInterrupt:

# %%
# 최적의 하이퍼파라미터 출력
print(f"Best trial: {study.best_trial.value}")
print(f"Best hyperparameters: {study.best_trial.params}")

# %% [markdown]
# - gradientboosting parameter

# %%
from sklearn.metrics import f1_score
from sklearn.model_selection import StratifiedKFold
from sklearn.ensemble import GradientBoostingClassifier

params = {
    'n_estimators': 306,
    'learning_rate': 0.04741755706638415,
    'max_depth': 5,
    'subsample': 0.9055240250602022
}

scores = []
models = []

# Stratified K-Fold 교차 검증 설정
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# 교차 검증 루프
for tri, vai in cv.split(train_ft, target):
    # 학습 데이터와 검증 데이터 분리
    x_train = train_ft.iloc[tri]
    y_train = target.iloc[tri]
    x_valid = train_ft.iloc[vai]
    y_valid = target.iloc[vai]

    # 모델 초기화 및 학습
    model = GradientBoostingClassifier(**params, random_state=SEED)
    model.fit(x_train, y_train)

    # 모델 저장
    models.append(model)

    # 예측 및 F1 매크로 스코어 계산
    pred = model.predict(x_valid)
    score = f1_score(y_valid, pred, average='macro')
    scores.append(score)

# F1 매크로 스코어의 평균 출력
print("Mean F1 Macro Score:", np.mean(scores))
# Out:
# Mean F1 Macro Score: 0.7140562733938418

# %% [markdown]
# ## Random Forest

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
import optuna

from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
import optuna

# Objective function
def objective(trial):
    # Penalty를 'l2'로 고정
    penalty = "l2"

    # Solver 선택: 'l2' penalty와 호환되는 옵션 중에서 선택
    solver = trial.suggest_categorical("solver", ["liblinear", "lbfgs", "sag", "saga"])

    # 하이퍼파라미터 설정
    hp = {
        "C": trial.suggest_float("C", 1e-4, 10.0, log=True),      # 정규화 강도 조절
        "penalty": penalty,                                       # 정규화 방식 고정
        "solver": solver,                                         # 최적화 알고리즘
        "max_iter": trial.suggest_int("max_iter", 100, 1000, step=100)  # 반복 횟수 조절
    }

    # Logistic Regression 모델 정의
    model = LogisticRegression(**hp, random_state=SEED)

    # 교차 검증 점수 계산
    score = cross_val_score(model, train_ft, target, cv=cv, scoring="f1_macro", n_jobs=-1).mean()
    return score

# Sampler 설정
sampler = optuna.samplers.TPESampler(seed=SEED)

# Study 객체 생성
study = optuna.create_study(
    direction="maximize",
    sampler=sampler
)

study.optimize(objective, n_trials=100)  # objective 함수 전달
# Out:
# [I 2024-11-13 15:17:50,891] A new study created in memory with name: no-name-a030b34a-677b-4c4d-a035-830150c80db4
# [I 2024-11-13 15:18:05,549] Trial 0 finished with value: 0.7125872317816507 and parameters: {'solver': 'lbfgs', 'C': 0.0006026889128682511, 'max_iter': 200}. Best is trial 0 with value: 0.7125872317816507.
# [I 2024-11-13 15:18:12,870] Trial 1 finished with value: 0.701861534546638 and parameters: {'solver': 'lbfgs', 'C': 0.00012674255898937226, 'max_iter': 1000}. Best is trial 0 with value: 0.7125872317816507.
# [I 2024-11-13 15:18:42,646] Trial 2 finished with value: 0.7092006291369471 and parameters: {'solver': 'liblinear', 'C': 0.0033205591037519565, 'max_iter': 600}. Best is trial 0 with value: 0.7125872317816507.
# [I 2024-11-13 15:22:25,156] Trial 3 finished with value: 0.70730700627386 and parameters: {'solver': 'sag', 'C': 0.0028888383623653178, 'max_iter': 400}. Best is trial 0 with value: 0.7125872317816507.
# [I 2024-11-13 15:22:48,088] Trial 4 finished with value: 0.6946168988391483 and parameters: {'solver': 'lbfgs', 'C': 0.09163741808778776, 'max_iter': 100}. Best is trial 0 with value: 0.7125872317816507.
# [I 2024-11-13 15:46:52,850] Trial 5 finished with value: 0.6940681925174252 and parameters: {'solver': 'saga', 'C': 6.732248920775331, 'max_iter': 900}. Best is trial 0 with value: 0.7125872317816507.
# [I 2024-11-13 15:47:52,299] Trial 6 finished with value: 0.7102931285034751 and parameters: {'solver': 'sag', 'C': 0.0004075596440072873, 'max_iter': 500}. Best is trial 0 with value: 0.7125872317816507.
# [I 2024-11-13
 'max_iter': 900}. Best is trial 71 with value: 0.7206239583520162.
# [I 2024-11-13 17:23:47,811] Trial 97 finished with value: 0.7189448250916055 and parameters: {'solver': 'liblinear', 'C': 0.00044871764024349, 'max_iter': 800}. Best is trial 71 with value: 0.7206239583520162.
# [I 2024-11-13 17:24:07,417] Trial 98 finished with value: 0.7191729172421849 and parameters: {'solver': 'liblinear', 'C': 0.00033305727858865474, 'max_iter': 1000}. Best is trial 71 with value: 0.7206239583520162.
# [I 2024-11-13 17:24:17,897] Trial 99 finished with value: 0.7125859801349279 and parameters: {'solver': 'lbfgs', 'C': 0.0006363229152784153, 'max_iter': 900}. Best is trial 71 with value: 0.7206239583520162.

# %%
# 최적의 하이퍼파라미터 출력
print(f"Best trial: {study.best_trial.value}")
print(f"Best hyperparameters: {study.best_trial.params}")
# Out:
# Best trial: 0.7206239583520162
# Best hyperparameters: {'solver': 'liblinear', 'C': 0.00028042459288154386, 'max_iter': 300}

# %% [markdown]
# # Feature Selection

# %%
from sklearn.feature_selection import SelectKBest, SelectPercentile, SelectFromModel
from sklearn.model_selection import KFold, StratifiedKFold, cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.metrics import f1_score
import optuna

# %%
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=SEED)

# %% [markdown]
# - XGB로 Feature Selection

# %%
xgb = XGBClassifier(random_state=SEED) # 특성 선택을 하기 위한 모델
model = LogisticRegression(random_state=SEED) # 학습용 모델

fs_xgb = SelectFromModel(xgb) # 특성 선택에 사용하기 위한 모델 객체를 전달해줘야함.
x = fs_xgb.fit_transform(train_ft, target) # 특성 선택이 완료된 입력 데이터가 ndarray 로 반환
scores = cross_val_score(model, x, target, cv=cv, scoring="f1_macro", n_jobs=-1)
scores.mean()
# Out:
# 0.7141481678146386

# %% [markdown]
# - RandomForest로 Feature Selection

# %%
rfc = RandomForestClassifier(random_state=SEED) # 특성 선택을 하기 위한 모델
model = LogisticRegression(random_state=SEED) # 학습용 모델

fs_rf = SelectFromModel(rfc) # 특성 선택에 사용하기 위한 모델 객체를 전달해줘야함.
x = fs_rf.fit_transform(train_ft, target) # 특성 선택이 완료된 입력 데이터가 ndarray 로 반환
scores = cross_val_score(model, x, target, cv=cv, scoring="f1_macro", n_jobs=-1)
scores.mean()
# Out:
# 0.7144958607740429

# %%
xgb_best_cols = fs_xgb.get_feature_names_out()
len(xgb_best_cols)
# Out:
# 565

# %%
rf_best_cols = fs_rf.get_feature_names_out()
len(rf_best_cols)
# Out:
# 359

# %% [markdown]
# ## Logistic Regression

# %% [markdown]
# ### XGB로 Feature Selection

# %%
def objective(trial):
    hp = {
        "C": trial.suggest_float("C", 1e-4, 10.0, log=True),  # 규제 강도
        "penalty": "l2",  # L2 규제로 고정
        "solver": trial.suggest_categorical("solver", ["lbfgs", "liblinear", "sag", "saga"]),
        "max_iter": trial.suggest_int("max_iter", 50, 500, step=50)  # 반복 횟수
    }
    model = LogisticRegression(**hp, random_state=SEED)
    score = cross_val_score(model, train_ft[xgb_best_cols], target, cv=cv, scoring="f1_macro", n_jobs=-1).mean()
    return score

sampler = optuna.samplers.TPESampler(seed=SEED) # 대체 모델 역할은 sampler 객체

# study 객체
study = optuna.create_study(
    direction="maximize",
    sampler = sampler
)

study.optimize(objective, n_trials=100)   # optimze 메서드에 콜백 함수(objective) 전달
# Out:
# [I 2024-11-14 00:16:29,217] A new study created in memory with name: no-name-acdfa85f-4c84-4b69-bcae-3e829652bc9e
# [I 2024-11-14 00:16:39,808] Trial 0 finished with value: 0.7196347947149497 and parameters: {'C': 0.0074593432857265485, 'solver': 'lbfgs', 'max_iter': 100}. Best is trial 0 with value: 0.7196347947149497.
# [I 2024-11-14 00:16:46,764] Trial 1 finished with value: 0.7084429380948787 and parameters: {'C': 0.00019517224641449495, 'solver': 'lbfgs', 'max_iter': 500}. Best is trial 0 with value: 0.7196347947149497.
# [I 2024-11-14 00:20:40,120] Trial 2 finished with value: 0.7152030049041113 and parameters: {'C': 1.452824663751602, 'solver': 'saga', 'max_iter': 300}. Best is trial 0 with value: 0.7196347947149497.
# [I 2024-11-14 00:21:00,520] Trial 3 finished with value: 0.7193503480369696 and parameters: {'C': 0.01444525102276306, 'solver': 'liblinear', 'max_iter': 200}. Best is trial 0 with value: 0.7196347947149497.
# [I 2024-11-14 00
 'solver': 'liblinear', 'max_iter': 150}. Best is trial 81 with value: 0.7269445777558114.
# [I 2024-11-14 00:48:11,611] Trial 85 finished with value: 0.7205083989066162 and parameters: {'C': 0.0009910901518953253, 'solver': 'lbfgs', 'max_iter': 50}. Best is trial 81 with value: 0.7269445777558114.
# [I 2024-11-14 00:48:20,381] Trial 86 finished with value: 0.7242048729460409 and parameters: {'C': 0.0017618851487058444, 'solver': 'liblinear', 'max_iter': 50}. Best is trial 81 with value: 0.7269445777558114.
# [I 2024-11-14 00:48:28,348] Trial 87 finished with value: 0.7232939355250023 and parameters: {'C': 0.002585422534643265, 'solver': 'liblinear', 'max_iter': 150}. Best is trial 81 with value: 0.7269445777558114.
# [I 2024-11-14 00:48:35,892] Trial 88 finished with value: 0.7254237360663475 and parameters: {'C': 0.00038406155196655644, 'solver': 'liblinear', 'max_iter': 50}. Best is trial 81 with value: 0.7269445777558114.
# [I 2024-11-14 00:48:42,436] Trial 89 finished with value: 0.7261410238967244 and parameters: {'C': 0.0007821360145327437, 'solver': 'liblinear', 'max_iter': 100}. Best is trial 81 with value: 0.7269445777558114.
# [I 2024-11-14 00:48:56,904] Trial 90 finished with value: 0.7193695572226624 and parameters: {'C': 0.012221511080885181, 'solver': 'liblinear', 'max_iter': 200}. Best is trial 81 with value: 0.7269445777558114.
# [I 2024-11-14 00:49:03,231] Trial 91 finished with value: 0.7264566062624744 and parameters: {'C': 0.0005217824435260075, 'solver': 'liblinear', 'max_iter': 100}. Best is trial 81 with value: 0.7269445777558114.
# [I 2024-11-14 00:49:10,523] Trial 92 finished with value: 0.7241334357249118 and parameters: {'C': 0.0002705440261817252, 'solver': 'liblinear', 'max_iter': 150}. Best is trial 81 with value: 0.7269445777558114.
# [I 2024-11-14 00:49:17,147] Trial 93 finished with value: 0.7269211215591544 and parameters: {'C': 0.0008930072692306488, 'solver': 'liblinear', 'max_iter': 100}. Best is trial 81 with value: 0.7269445777558114.
# [I 2024-11-14 00:49:25,693] Trial 94 finished with value: 0.7268790696989645 and parameters: {'C': 0.000867983523344578, 'solver': 'liblinear', 'max_iter': 50}. Best is trial 81 with value: 0.7269445777558114.
# [I 2024-11-14 00:49:32,709] Trial 95 finished with value: 0.7253706839204239 and parameters: {'C': 0.0013813702978813405, 'solver': 'liblinear', 'max_iter': 50}. Best is trial 81 with value: 0.7269445777558114.
# [I 2024-11-14 00:49:44,888] Trial 96 finished with value: 0.7209043307120917 and parameters: {'C': 0.003948068672013368, 'solver': 'liblinear', 'max_iter': 100}. Best is trial 81 with value: 0.7269445777558114.
# [I 2024-11-14 00:49:52,581] Trial 97 finished with value: 0.7268757759258564 and parameters: {'C': 0.0008865168097085265, 'solver': 'liblinear', 'max_iter': 50}. Best is trial 81 with value: 0.7269445777558114.
# [I 2024-11-14 00:50:01,595] Trial 98 finished with value: 0.7232563255929717 and parameters: {'C': 0.0026608608604339343, 'solver': 'liblinear', 'max_iter': 100}. Best is trial 81 with value: 0.7269445777558114.
# [I 2024-11-14 00:50:14,447] Trial 99 finished with value: 0.7201572689904548 and parameters: {'C': 0.0009167194419885809, 'solver': 'sag', 'max_iter': 250}. Best is trial 81 with value: 0.7269445777558114.

# %%
print("Best hyperparameters:", study.best_params)
print("Best F1 Score:", study.best_value)
# Out:
# Best hyperparameters: {'C': 0.0008541909431453405, 'solver': 'liblinear', 'max_iter': 100}
# Best F1 Score: 0.7269445777558114

# %%
log_xgb_params = {'C': 0.0008541909431453405, 'solver': 'liblinear', 'max_iter': 100}

# F1 매크로 스코어와 모델을 저장할 리스트
scores = []
models = []

# 교차 검증 루프
for tri, vai in cv.split(train_ft, target):
    # 학습 데이터와 검증 데이터 분리 (선택된 피처만 사용)
    x_train = train_ft.iloc[tri][xgb_best_cols]
    y_train = target.iloc[tri]
    x_valid = train_ft.iloc[vai][xgb_best_cols]
    y_valid = target.iloc[vai]

    # 모델 초기화 및 학습
    logistic_model_xgb = LogisticRegression(**log_xgb_params, random_state=SEED)
    logistic_model_xgb.fit(x_train, y_train)

    # 모델 저장
    models.append(logistic_model_xgb)

    # 예측 및 F1 매크로 스코어 계산
    pred = logistic_model_xgb.predict(x_valid)
    score = f1_score(y_valid, pred, average='macro')
    scores.append(score)

# F1 매크로 스코어의 평균 출력
print("Mean F1 Macro Score:", np.mean(scores))
# Out:
# Mean F1 Macro Score: 0.7269445777558114

# %%
logistic_model_xgb = LogisticRegression(**log_xgb_params)
logistic_model_xgb.fit(train_ft[xgb_best_cols],target)

proba = logistic_model_xgb.predict_proba(test_ft[xgb_best_cols])[:, 1]

submit["target"] = proba
submit.to_csv("비선형_fs_xgb_logistic.csv",index=False)

# %% [markdown]
# ### RandomForest로 Feature Selection

# %%
def objective(trial):
    hp = {
        "C": trial.suggest_float("C", 1e-4, 10.0, log=True),  # 규제 강도
        "penalty": "l2",  # L2 규제로 고정
        "solver": trial.suggest_categorical("solver", ["lbfgs", "liblinear", "sag", "saga"]),
        "max_iter": trial.suggest_int("max_iter", 50, 500, step=50)  # 반복 횟수
    }
    model = LogisticRegression(**hp, random_state=SEED)
    score = cross_val_score(model, train_ft[rf_best_cols], target, cv=cv, scoring="f1_macro", n_jobs=-1).mean()
    return score

sampler = optuna.samplers.TPESampler(seed=SEED) # 대체 모델 역할은 sampler 객체

# study 객체
study = optuna.create_study(
    direction="maximize",
    sampler = sampler
)

study.optimize(objective, n_trials=100)   # optimze 메서드에 콜백 함수(objective) 전달
# Out:
# [I 2024-11
predict(x_valid)
    score = f1_score(y_valid, pred, average='macro')
    scores.append(score)

# F1 매크로 스코어의 평균 출력
print("Mean F1 Macro Score:", np.mean(scores))
# Out:
# Mean F1 Macro Score: 0.7231951407689357

# %%
logistic_model_rf = LogisticRegression(**log_rf_params)
logistic_model_rf.fit(train_ft[rf_best_cols],target)

pred = logistic_model_rf.predict_proba(test_ft[rf_best_cols])[:, 1]

submit["target"] = pred
submit.to_csv("logistic_model_rf.csv",index=False)

# %% [markdown]
# ## LDA

# %% [markdown]
# ### XGB로 Feature Selection

# %%
def objective(trial):
    # Optuna가 선택할 수 있는 하이퍼파라미터 정의
    solver = trial.suggest_categorical('solver', ['svd', 'lsqr', 'eigen'])

    # 'lsqr'와 'eigen'에서만 shrinkage 하이퍼파라미터가 사용되므로 조건 추가
    if solver in ['lsqr', 'eigen']:
        shrinkage = trial.suggest_float('shrinkage', 0.0, 1.0)
    else:
        shrinkage = None

    # n_components 하이퍼파라미터: 차원 수를 1부터 X의 특성 개수까지
    n_components = trial.suggest_int('n_components', 1, min(train_ft[xgb_best_cols].shape[1], len(np.unique(target)) - 1))

    # LDA 모델 정의
    lda = LinearDiscriminantAnalysis(solver=solver, shrinkage=shrinkage, n_components=n_components)

    score = cross_val_score(lda, train_ft[xgb_best_cols], target, cv=cv, scoring="f1_macro", n_jobs=-1).mean()
    return score

# Optuna study 설정 및 최적화 실행
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=200)
# Out:
# [I 2024-11-14 01:48:00,056] A new study created in memory with name: no-name-dd240045-1785-4635-84c2-f18e5c08e8e2
# [I 2024-11-14 01:48:04,190] Trial 0 finished with value: 0.718338125457728 and parameters: {'solver': 'eigen', 'shrinkage': 0.7984532386917654, 'n_components': 1}. Best is trial 0 with value: 0.718338125457728.
# [I 2024-11-14 01:48:07,598] Trial 1 finished with value: 0.7212203016594261 and parameters: {'solver': 'lsqr', 'shrinkage': 0.13149245831097756, 'n_components': 1}. Best is trial 1 with value: 0.7212203016594261.
# [I 2024-11-14 01:48:18,344] Trial 2 finished with value: 0.7135873653162664 and parameters: {'solver': 'svd', 'n_components': 1}. Best is trial 1 with value: 0.7212203016594261.
# [I 2024-11-14 01:48:22,436] Trial 3 finished with value: 0.7225623912002644 and parameters: {'solver': 'eigen', 'shrinkage': 0.2116174177047112, 'n_components': 1}. Best is trial 3 with value: 0.7225623912002644.
# [I 2024-11-14 01:48:32,898] Trial 4 finished with value: 0.7135873653162664 and parameters: {'solver': 'svd', 'n_components': 1}. Best is trial 3 with value: 0.7225623912002644.
# [I 2024-11-14 01:48:36,247] Trial 5 finished with value: 0.721607488363295 and parameters: {'solver': 'lsqr', 'shrinkage': 0.13570583199945285, 'n_components': 1}. Best is trial 3 with value: 0.7225623912002644.
# [I 2024-11-14 01:48:39,729] Trial 6 finished with value: 0.7244944439463586 and parameters: {'solver': 'lsqr', 'shrinkage': 0.32036684587653486, 'n_components': 1}. Best is trial 6 with value: 0.7244944439463586.
# [I 2024-11-14 01:48:46,082] Trial 7 finished with value: 0.724745438371069 and parameters: {'solver': 'eigen', 'shrinkage': 0.550913375284628, 'n_components': 1}. Best is trial 7 with value: 0.724745438371069.
# [I 2024-11-14 01:48:50,215] Trial 8 finished with value: 0.7247053820155851 and parameters: {'solver': 'eigen', 'shrinkage': 0.532316077688265, 'n_components': 1}. Best is trial 7 with value: 0.724745438371069.
# [I 2024-11-14 01:48:53,584] Trial 9 finished with value: 0.7167539661559192 and parameters: {'solver': 'lsqr', 'shrinkage': 0.8100300204329024, 'n_components': 1}. Best is trial 7 with value: 0.724745438371069.
# [I 2024-11-14 01:48:58,804] Trial 10 finished with value: 0.7240954169039703 and parameters: {'solver': 'eigen', 'shrinkage': 0.5726418548046787, 'n_components': 1}. Best is trial 7 with value: 0.724745438371069.
# [I 2024-11-14 01:49
 'n_components': 1}. Best is trial 131 with value: 0.7255501185709449.
# [I 2024-11-14 02:02:28,978] Trial 182 finished with value: 0.7249678887371547 and parameters: {'solver': 'eigen', 'shrinkage': 0.47492534196915553, 'n_components': 1}. Best is trial 131 with value: 0.7255501185709449.
# [I 2024-11-14 02:02:33,631] Trial 183 finished with value: 0.7254479018570676 and parameters: {'solver': 'eigen', 'shrinkage': 0.5058228666484867, 'n_components': 1}. Best is trial 131 with value: 0.7255501185709449.
# [I 2024-11-14 02:02:37,779] Trial 184 finished with value: 0.7246675541874412 and parameters: {'solver': 'eigen', 'shrinkage': 0.5493601815909788, 'n_components': 1}. Best is trial 131 with value: 0.7255501185709449.
# [I 2024-11-14 02:02:42,709] Trial 185 finished with value: 0.7248130598142104 and parameters: {'solver': 'eigen', 'shrinkage': 0.5117868345677877, 'n_components': 1}. Best is trial 131 with value: 0.7255501185709449.
# [I 2024-11-14 02:02:48,118] Trial 186 finished with value: 0.7237858144202838 and parameters: {'solver': 'eigen', 'shrinkage': 0.4520489257372198, 'n_components': 1}. Best is trial 131 with value: 0.7255501185709449.
# [I 2024-11-14 02:02:52,227] Trial 187 finished with value: 0.7001090878748683 and parameters: {'solver': 'eigen', 'shrinkage': 0.8891584941995765, 'n_components': 1}. Best is trial 131 with value: 0.7255501185709449.
# [I 2024-11-14 02:02:56,484] Trial 188 finished with value: 0.7245577550280033 and parameters: {'solver': 'eigen', 'shrinkage': 0.5223891386258311, 'n_components': 1}. Best is trial 131 with value: 0.7255501185709449.
# [I 2024-11-14 02:03:02,810] Trial 189 finished with value: 0.7245306022541338 and parameters: {'solver': 'eigen', 'shrinkage': 0.4697746858551105, 'n_components': 1}. Best is trial 131 with value: 0.7255501185709449.
# [I 2024-11-14 02:03:11,308] Trial 190 finished with value: 0.7135873653162664 and parameters: {'solver': 'svd', 'n_components': 1}. Best is trial 131 with value: 0.7255501185709449.
# [I 2024-11-14 02:03:17,272] Trial 191 finished with value: 0.725377301334257 and parameters: {'solver': 'eigen', 'shrinkage': 0.49390273709896815, 'n_components': 1}. Best is trial 131 with value: 0.7255501185709449.
# [I 2024-11-14 02:03:21,543] Trial 192 finished with value: 0.7251258643091133 and parameters: {'solver': 'eigen', 'shrinkage': 0.4915548264807276, 'n_components': 1}. Best is trial 131 with value: 0.7255501185709449.
# [I 2024-11-14 02:03:25,684] Trial 193 finished with value: 0.7254479018570676 and parameters: {'solver': 'eigen', 'shrinkage': 0.5060072856642641, 'n_components': 1}. Best is trial 131 with value: 0.7255501185709449.
# [I 2024-11-14 02:03:31,170] Trial 194 finished with value: 0.7246433889615133 and parameters: {'solver': 'eigen', 'shrinkage': 0.5309737227868739, 'n_components': 1}. Best is trial 131 with value: 0.7255501185709449.
# [I 2024-11-14 02:03:36,147] Trial 195 finished with value: 0.7252903975412115 and parameters: {'solver': 'eigen', 'shrinkage': 0.5039012586677454, 'n_components': 1}. Best is trial 131 with value: 0.7255501185709449.
# [I 2024-11-14 02:03:40,288] Trial 196 finished with value: 0.7246714473411539 and parameters: {'solver': 'eigen', 'shrinkage': 0.4716113216455865, 'n_components': 1}. Best is trial 131 with value: 0.7255501185709449.
# [I 2024-11-14 02:03:44,918] Trial 197 finished with value: 0.7245745986303785 and parameters: {'solver': 'eigen', 'shrinkage': 0.5563577317770709, 'n_components': 1}. Best is trial 131 with value: 0.7255501185709449.
# [I 2024-11-14 02:03:50,852] Trial 198 finished with value: 0.7253862248408283 and parameters: {'solver': 'eigen', 'shrinkage': 0.5070398721770342, 'n_components': 1}. Best is trial 131 with value: 0.7255501185709449.
# [I 2024-11-14 02:03:54,944] Trial 199 finished with value: 0.7238784609595232 and parameters: {'solver': 'eigen', 'shrinkage': 0.4401684034099893, 'n_components': 1}. Best is trial 131 with value: 0.7255501185709449.

# %%
print("Best hyperparameters:", study.best_params)
print("Best F1 Score:", study.best_value)
# Out:
# Best hyperparameters: {'solver': 'eigen', 'shrinkage': 0.49858677421095554, 'n_components': 1}
# Best F1 Score: 0.7255501185709449

# %%
lda_xgb_params = {'solver': 'eigen', 'shrinkage': 0.49858677421095554, 'n_components': 1}

# F1 매크로 스코어와 모델을 저장할 리스트
scores = []
models = []

# 교차 검증 루프
for tri, vai in cv.split(train_ft, target):
    # 학습 데이터와 검증 데이터 분리 (선택된 피처만 사용)
    x_train = train_ft.iloc[tri][xgb_best_cols]
    y_train = target.iloc[tri]
    x_valid = train_ft.iloc[vai][xgb_best_cols]
    y_valid = target.iloc[vai]

    # 모델 초기화 및 학습
    lda_model_xgb = LinearDiscriminantAnalysis(**lda_xgb_params)
    lda_model_xgb.fit(x_train, y_train)

    # 모델 저장
    models.append(lda_model_xgb)

    # 예측 및 F1 매크로 스코어 계산
    pred = lda_model_xgb.predict(x_valid)
    score = f1_score(y_valid, pred, average='macro')
    scores.append(score)

# F1 매크로 스코어의 평균 출력
print("Mean F1 Macro Score:", np.mean(scores))
# Out:
# Mean F1 Macro Score: 0.7255501185709449

# %%
lda_model_xgb = LinearDiscriminantAnalysis(**lda_xgb_params)
lda_model_xgb.fit(train_ft[xgb_best_cols],target)

proba = lda_model_xgb.predict_proba(test_ft[xgb_best_cols])[:, 1]

submit["target"] = pred
submit.to_csv("fs_xgb_LDA.csv",index=False)

# %% [markdown]
# ### RandomForest로 Feature Selection

# %%
def objective(trial):
    # Optuna가 선택할 수 있는 하이퍼파라미터 정의
    solver = trial.suggest_categorical('solver', ['svd', 'lsqr', 'eigen'])

    # 'lsqr'와 'eigen'에서만 shrinkage 하이퍼파라미터가 사용되므로 조건 추가
    if solver in ['lsqr', 'eigen']:
        shrinkage = trial.suggest_float('shrinkage', 0.0, 1.0)
    else:
        shrinkage = None

    # n_components 하이퍼파라미터: 차원 수를 1부터 X의 특성 개수까지
    n_components = trial.suggest_int('n_components', 1, min(train_ft[rf_best_cols].shape[1], len(np.unique(target)) - 1))

    # LDA 모델 정의
    lda = LinearDiscriminantAnalysis(solver=solver, shrinkage=shrinkage, n_components=n_components)

    score = cross_val_score(lda, train_ft[rf_best_cols], target, cv=cv, scoring="f1_macro", n_jobs=-1).mean()
    return score

# Optuna study 설정 및 최적화 실행
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=200)
# Out:
# [I 2024-11-14 01:39:54,508] A new study created in memory with name: no-name-0f557ec0-fdc1-4267-a70b-980b9c5d3ad1
# [I 2024-11-14 01:39:56,759] Trial 0 finished with value: 0.719298614431015 and parameters: {'solver': 'eigen', 'shrinkage': 0.5643827666062647, 'n_components': 1}. Best is trial 0 with value: 0.719298614431015.
# [I 2024-11-14 01:39:58,781] Trial 1 finished with value: 0.7131223568203546 and parameters: {'solver': 'eigen', 'shrinkage': 0.8027910075070062, 'n_components': 1}. Best is trial 0 with value: 0.719298614431015.
# [I 2024-11-14 01:40:00,610] Trial 2 finished with value: 0.7147013496352463 and parameters: {'solver': 'lsqr', 'shrinkage': 0.7654009838947428, 'n_components': 1}. Best is trial 0 with value: 0.719298614431015.
# [I 2024-11-14 01:40:02,667] Trial 3 finished with value: 0.7081461958582442 and parameters: {'solver': 'eigen', 'shrinkage': 0.8471081617033561, 'n_components': 1}. Best is trial 0 with value: 0.719298614431015.
# [I 2024-11-14 01:40:07,852] Trial 4 finished with value: 0.7133751128677563 and parameters: {'solver': 'svd', 'n_components': 1}. Best is trial 0 with value: 0.719298614431015.
# [I 2024-11-14 01:40:10,490] Trial 5 finished with value: 0.7214313362293272 and parameters: {'solver': 'lsqr', 'shrinkage': 0.4382408555896713, 'n_components': 1}. Best is trial 5 with value: 0.7214313362293272.
# [I 2024-11-14 01:40:12,323] Trial 6 finished with value: 0.7032258227375747 and parameters: {'solver': 'lsqr', 'shrinkage': 0.8727802468551644, 'n_components': 1}. Best is trial 5 with value: 0.7214313362293272.
# [I 2024-11-14 01:40:14,014] Trial 7 finished with value: 0.7130873916271698 and parameters: {'solver': 'lsqr', 'shrinkage': 0.806769814894652, 'n_components': 1}. Best is trial 5 with value: 0.7214313362293272.
# [I 2024-11-14 01:40:16,068] Trial 8 finished with value: 0.7132109531718852 and parameters: {'solver': 'eigen', 'shrinkage': 0.7879601128138141, 'n_components': 1}. Best is trial 5 with value: 0.7214313362293272.
# [I 2024-11-14 01:40:18,087] Trial 9 finished with value: 0.7147298534353452 and parameters: {'solver': 'eigen', 'shrinkage': 0.7599109726789686, 'n_components': 1}. Best is trial 5 with value: 0.7214313362293272.
# [I 2024-11-14 01:40:22,754] Trial 10 finished with value: 0.7133751128677563 and parameters: {'solver': 'svd', 'n_components': 1}. Best is trial 5 with value: 0.7214313362293272.
# [I 2024-11-14 01:40:25,426] Trial 11 finished with value: 0.7209070177713954 and parameters: {'solver': 'lsqr', 'shrinkage': 0.29368002438541524, 'n_components': 1}. Best is trial 5 with value: 0.7214313362293272.
# [I 2024-11-14 01:40:27,573] Trial 12 finished with value: 0.7179472163522217 and parameters: {'solver': 'lsqr', 'shrinkage': 0.1439484550806972, 'n_components': 1}. Best is trial 5 with value: 0.7214313362293272.
# [I 2024-11-14 01:40:29,321] Trial 13 finished with value: 0.7202090659000604 and parameters: {'solver': 'lsqr', 'shrinkage': 0.25021384554768245, 'n_components': 1}. Best is trial 5 with value: 0.7214313362293272.
# [I 2024-11-14 01:40:31,029] Trial 14 finished with value: 0.7220217481086137 and parameters: {'solver': 'lsqr', 'shrinkage': 0.3936783741639418, 'n_components': 1}. Best is trial 14 with value: 0.7220217481086137.
# [I 2024-11-14 01:40:32,718] Trial 15 finished with value: 0.7196545896984357 and parameters: {'solver': 'lsqr', 'shrinkage': 0.481832805198421, 'n_components': 1}. Best is trial 14 with value: 0.7220217481086137.
# [I 2024-11-14 01:40
 'n_components': 1}. Best is trial 172 with value: 0.7224334253910599.
# [I 2024-11-14 01:47:14,844] Trial 192 finished with value: 0.7217737921182652 and parameters: {'solver': 'eigen', 'shrinkage': 0.36569052441921507, 'n_components': 1}. Best is trial 172 with value: 0.7224334253910599.
# [I 2024-11-14 01:47:18,008] Trial 193 finished with value: 0.7218734000773195 and parameters: {'solver': 'eigen', 'shrinkage': 0.411328346029493, 'n_components': 1}. Best is trial 172 with value: 0.7224334253910599.
# [I 2024-11-14 01:47:20,593] Trial 194 finished with value: 0.7218033334974574 and parameters: {'solver': 'eigen', 'shrinkage': 0.3790806065245821, 'n_components': 1}. Best is trial 172 with value: 0.7224334253910599.
# [I 2024-11-14 01:47:22,558] Trial 195 finished with value: 0.7223545828070038 and parameters: {'solver': 'eigen', 'shrinkage': 0.4025585417807634, 'n_components': 1}. Best is trial 172 with value: 0.7224334253910599.
# [I 2024-11-14 01:47:24,510] Trial 196 finished with value: 0.7213594809665985 and parameters: {'solver': 'eigen', 'shrinkage': 0.4302176256825168, 'n_components': 1}. Best is trial 172 with value: 0.7224334253910599.
# [I 2024-11-14 01:47:26,153] Trial 197 finished with value: 0.7213543446461887 and parameters: {'solver': 'lsqr', 'shrinkage': 0.4493125228764074, 'n_components': 1}. Best is trial 172 with value: 0.7224334253910599.
# [I 2024-11-14 01:47:28,119] Trial 198 finished with value: 0.7220205020915307 and parameters: {'solver': 'eigen', 'shrinkage': 0.40721179237544947, 'n_components': 1}. Best is trial 172 with value: 0.7224334253910599.
# [I 2024-11-14 01:47:29,925] Trial 199 finished with value: 0.72176024072026 and parameters: {'solver': 'lsqr', 'shrinkage': 0.3602952879889646, 'n_components': 1}. Best is trial 172 with value: 0.7224334253910599.

# %%
print("Best hyperparameters:", study.best_params)
print("Best F1 Score:", study.best_value)
# Out:
# Best hyperparameters: {'solver': 'lsqr', 'shrinkage': 0.40291758052927384, 'n_components': 1}
# Best F1 Score: 0.7224334253910599

# %%
lda_rf_params = {'solver': 'lsqr', 'shrinkage': 0.32247003082505904, 'n_components': 1}

# F1 매크로 스코어와 모델을 저장할 리스트
scores = []
models = []

# 교차 검증 루프
for tri, vai in cv.split(train_ft, target):
    # 학습 데이터와 검증 데이터 분리 (선택된 피처만 사용)
    x_train = train_ft.iloc[tri][rf_best_cols]
    y_train = target.iloc[tri]
    x_valid = train_ft.iloc[vai][rf_best_cols]
    y_valid = target.iloc[vai]

    # 모델 초기화 및 학습
    lda_model_rf = LinearDiscriminantAnalysis(**lda_rf_params)
    lda_model_rf.fit(x_train, y_train)

    # 모델 저장
    models.append(lda_model_rf)

    # 예측 및 F1 매크로 스코어 계산
    pred = lda_model_rf.predict(x_valid)
    score = f1_score(y_valid, pred, average='macro')
    scores.append(score)

# F1 매크로 스코어의 평균 출력
print("Mean F1 Macro Score:", np.mean(scores))
# Out:
# Mean F1 Macro Score: 0.7217555155064295

# %%
lda_model_rf = LinearDiscriminantAnalysis(**lda_rf_params)
lda_model_rf.fit(train_ft[rf_best_cols],target)

pred = lda_model_rf.predict_proba(test_ft[rf_best_cols])[:, 1]

submit["target"] = pred
submit.to_csv("lda_model_rf.csv",index=False)

# %% [markdown]
# ## XGBoost

# %% [markdown]
# ### XGB로 Feature Selection

# %%
def objective(trial):
    hp = {
        "n_estimators": trial.suggest_int("n_estimators", 100, 1000, step=100),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3, log=True),
        "max_depth": trial.suggest_int("max_depth", 3, 10),
        "min_child_weight": trial.suggest_int("min_child_weight", 1, 10),
        "subsample": trial.suggest_float("subsample", 0.5, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.5, 1.0),
        "gamma": trial.suggest_float("gamma", 0, 5)
    }

    model = XGBClassifier(**hp, random_state=SEED)
    score = cross_val_score(model, train_ft[xgb_best_cols], target, cv=cv, scoring="f1_macro", n_jobs=-1).mean()
    return score

sampler = optuna.samplers.TPESampler(seed=SEED) # 대체 모델 역할은 sampler 객체

# study 객체
study = optuna.create_study(
    direction="maximize",
    sampler = sampler
)

study.optimize(objective, n_trials=50)   # optimze 메서드에 콜백 함수(objective) 전달
# Out:
# [I 2024-11-14 02:04:41,257] A new study created in memory with name: no-name-df07c577-7bde-4a5e-8ef2-da6ea288d2f3
# [I 2024-11-14 02:06:52,051] Trial 0 finished with value: 0.6953607300466209 and parameters: {'n_estimators': 400, 'learning_rate': 0.2536999076681772, 'max_depth': 8, 'min_child_weight': 6, 'subsample': 0.5780093202212182, 'colsample_bytree': 0.5779972601681014, 'gamma': 0.2904180608409973}. Best is trial 0 with value: 0.6953607300466209.
# [I 2024-11-14 02:10:52,464] Trial 1 finished with value: 0.7154317344236184 and parameters: {'n_estimators': 900, 'learning_rate': 0.07725378389307355, 'max_depth': 8, 'min_child_weight': 1, 'subsample': 0.9849549260809971, 'colsample_bytree': 0.9162213204002109, 'gamma': 1.0616955533913808}. Best is trial 1 with value: 0.7154317344236184.
# [I 2024-11-14 02:11:55,363] Trial 2 finished with value: 0.7066844309805294 and parameters: {'n_estimators': 200, 'learning_rate': 0.018659959624904916, 'max_depth': 5, 'min_child_weight': 6, 'subsample': 0.7159725093210578, 'colsample_bytree': 0.645614570099021, 'gamma': 3.0592644736118975}. Best is trial 1 with value: 0.7154317344236184.
# [I 2024-11-14 02:12:56,061] Trial 3 finished with value: 0.7119352577052375 and parameters: {'n_estimators': 200, 'learning_rate': 0.027010527749605478, 'max_depth': 5, 'min_child_weight': 5, 'subsample': 0.8925879806965068, 'colsample_bytree': 0.5998368910791798, 
 'max_depth': 7, 'min_child_weight': 1, 'subsample': 0.8927334684269886, 'colsample_bytree': 0.8013773753448578, 'gamma': 0.9006284674061199}. Best is trial 43 with value: 0.7245634772612694.
# [I 2024-11-14 04:09:31,700] Trial 47 finished with value: 0.7201953742059837 and parameters: {'n_estimators': 500, 'learning_rate': 0.027207635687352964, 'max_depth': 8, 'min_child_weight': 6, 'subsample': 0.9364273235269315, 'colsample_bytree': 0.7002985833756914, 'gamma': 1.3549488877136}. Best is trial 43 with value: 0.7245634772612694.
# [I 2024-11-14 04:11:58,143] Trial 48 finished with value: 0.7205054797788648 and parameters: {'n_estimators': 700, 'learning_rate': 0.05856674654840735, 'max_depth': 5, 'min_child_weight': 7, 'subsample': 0.8274735903600633, 'colsample_bytree': 0.775166818126158, 'gamma': 1.6791644663778804}. Best is trial 43 with value: 0.7245634772612694.
# [I 2024-11-14 04:15:45,914] Trial 49 finished with value: 0.725324972881959 and parameters: {'n_estimators': 900, 'learning_rate': 0.03525364948006408, 'max_depth': 6, 'min_child_weight': 6, 'subsample': 0.9700861694708173, 'colsample_bytree': 0.7297941645661414, 'gamma': 0.6528144116808078}. Best is trial 49 with value: 0.725324972881959.

# %%
print("Best hyperparameters:", study.best_params)
print("Best F1 Score:", study.best_value)
# Out:
# Best hyperparameters: {'n_estimators': 900, 'learning_rate': 0.03525364948006408, 'max_depth': 6, 'min_child_weight': 6, 'subsample': 0.9700861694708173, 'colsample_bytree': 0.7297941645661414, 'gamma': 0.6528144116808078}
# Best F1 Score: 0.725324972881959

# %%
xgb_xgb_params = {'n_estimators': 900,
                   'learning_rate': 0.03525364948006408,
                   'max_depth': 6,
                   'min_child_weight': 6,
                   'subsample': 0.9700861694708173,
                   'colsample_bytree': 0.7297941645661414,
                   'gamma': 0.6528144116808078}

# F1 매크로 스코어와 모델을 저장할 리스트
scores = []
models = []

# 교차 검증 루프
for tri, vai in cv.split(train_ft, target):
    # 학습 데이터와 검증 데이터 분리 (선택된 피처만 사용)
    x_train = train_ft.iloc[tri][xgb_best_cols]
    y_train = target.iloc[tri]
    x_valid = train_ft.iloc[vai][xgb_best_cols]
    y_valid = target.iloc[vai]

    # 모델 초기화 및 학습
    xgb_model_xgb = XGBClassifier(**xgb_xgb_params, random_state=SEED)
    xgb_model_xgb.fit(x_train, y_train)

    # 모델 저장
    models.append(xgb_model_xgb)

    # 예측 및 F1 매크로 스코어 계산
    pred = xgb_model_xgb.predict(x_valid)
    score = f1_score(y_valid, pred, average='macro')
    scores.append(score)

# F1 매크로 스코어의 평균 출력
print("Mean F1 Macro Score:", np.mean(scores))
# Out:
# Mean F1 Macro Score: 0.725324972881959

# %%
xgb_model_xgb = XGBClassifier(**xgb_xgb_params)
xgb_model_xgb.fit(train_ft[xgb_best_cols],target)

pred = xgb_model_xgb.predict_proba(test_ft[xgb_best_cols])[:, 1]

submit["target"] = pred
submit.to_csv("fs_xgb_xgb.csv",index=False)

# %% [markdown]
# ### RandomForest로 Feature Selection

# %%
def objective(trial):
    hp = {
        "n_estimators": trial.suggest_int("n_estimators", 100, 1000, step=100),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3, log=True),
        "max_depth": trial.suggest_int("max_depth", 3, 10),
        "min_child_weight": trial.suggest_int("min_child_weight", 1, 10),
        "subsample": trial.suggest_float("subsample", 0.5, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.5, 1.0),
        "gamma": trial.suggest_float("gamma", 0, 5)
    }

    model = XGBClassifier(**hp, random_state=SEED)
    score = cross_val_score(model, train_ft[rf_best_cols], target, cv=cv, scoring="f1_macro", n_jobs=-1).mean()
    return score

sampler = optuna.samplers.TPESampler(seed=SEED) # 대체 모델 역할은 sampler 객체

# study 객체
study = optuna.create_study(
    direction="maximize",
    sampler = sampler
)

study.optimize(objective, n_trials=100)   # optimze 메서드에 콜백 함수(objective) 전달

# %%
print("Best hyperparameters:", study.best_params)
print("Best F1 Score:", study.best_value)

# %%
xgb_rf_params = {}

# F1 매크로 스코어와 모델을 저장할 리스트
scores = []
models = []

# 교차 검증 루프
for tri, vai in cv.split(train_ft, target):
    # 학습 데이터와 검증 데이터 분리 (선택된 피처만 사용)
    x_train = train_ft.iloc[tri][rf_best_cols]
    y_train = target.iloc[tri]
    x_valid = train_ft.iloc[vai][rf_best_cols]
    y_valid = target.iloc[vai]

    # 모델 초기화 및 학습
    xgb_model_rf = XGBClassifier(**lda_rf_params)
    xgb_model_rf.fit(x_train, y_train)

    # 모델 저장
    models.append(xgb_model_rf)

    # 예측 및 F1 매크로 스코어 계산
    pred = xgb_model_rf.predict(x_valid)
    score = f1_score(y_valid, pred, average='macro')
    scores.append(score)

# F1 매크로 스코어의 평균 출력
print("Mean F1 Macro Score:", np.mean(scores))

# %%
xgb_model_rf = XGBClassifier(**log_rf_params)
xgb_model_rf.fit(train_ft[rf_best_cols],target)

pred = xgb_model_rf.predict_proba(test_ft[rf_best_cols])[:, 1]

submit["target"] = pred
submit.to_csv("fs_rf_xgb.csv",index=False)

# %% [markdown]
# ## LGBM

# %% [markdown]
# ### XGB로 Feature Selection

# %%
def objective(trial):
    hp = {
        "num_leaves": trial.suggest_int("num_leaves", 20, 150),               # 리프 노드의 수
        "max_depth": trial.suggest_int("max_depth", 3, 15),                   # 최대 트리 깊이
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3, log=True),  # 학습률
        "n_estimators": trial.suggest_int("n_estimators", 100, 1000, step=100),      # 부스팅 단계 수
        "min_child_samples": trial.suggest_int("min_child_samples", 5, 100),  # 최소 데이터 수
        "subsample": trial.suggest_float("subsample", 0.6, 1.0, step=0.1),    # 샘플링 비율
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.6, 1.0, step=0.1),  # 피처 샘플링 비율
        "reg_alpha": trial.suggest_float("reg_alpha", 1e-8, 10.0, log=True),  # L1 규제
        "reg_lambda": trial.suggest_float("reg_lambda", 1e-8, 10.0, log=True) # L2 규제
    }

    model = LGBMClassifier(**hp, random_state=SEED)
    score = cross_val_score(model, train_ft[xgb_best_cols], target, cv=cv, scoring="f1_macro", n_jobs=-1).mean()
    return score

sampler = optuna.samplers.TPESampler(seed=SEED) # 대체 모델 역할은 sampler 객체

# study 객체
study = optuna.create_study(
    direction="maximize",
    sampler = sampler
)

study.optimize(objective, n_trials=50)   # optimze 메서드에 콜백 함수(objective) 전달
# Out:
# [I 2024-11-14 05:10:58,893] A new study created in memory with name: no-name-467a80f0-7f2c-4d8a-9b6d-ffadbe38b6c0
# [I 2024-11-14 05:13:53,463] Trial 0 finished with value: 0.7117188649601597 and parameters: {'num_leaves': 69, 'max_depth': 15, 'learning_rate': 0.1205712628744377, 'n_estimators': 600, 'min_child_samples': 19, 'subsample': 0.6, 'colsample_bytree': 0.6, 'reg_alpha': 0.6245760287469893, 'reg_lambda': 0.002570603566117598}. Best is trial 0 with value: 0.7117188649601597.
# [I 2024-11-14 05:14:54,541] Trial 1 finished with value: 0.7113114607818796 and parameters: {'num_leaves': 112, 'max_depth': 3, 'learning_rate': 0.2708160864249968, 'n_estimators': 900, 'min_child_samples': 25, 'subsample': 0.6, 'colsample_bytree': 0.6, 'reg_alpha': 5.472429642032198e-06, 'reg_lambda': 0.00052821153945323}. Best is trial 0 with value: 0.7117188649601597.
# [I 2024-11-14 05:15:30,787] Trial 2 finished with value: 0.7186803403563937 and parameters: {'num_leaves': 76, 'max_depth': 6, 'learning_rate': 0.08012737503998542, 'n_estimators': 200, 'min_child_samples': 33, 'subsample': 0.7, 'colsample_bytree': 0.8, 'reg_alpha': 0.1165691561324743, 'reg_lambda': 6.267062696005991e-07}. Best is trial 2 with value: 0.7186803403563937.

# %%
print("Best hyperparameters:", study.best_params)
print("Best F1 Score:", study.best_value)

# %%
xgb_lgbm_params = {}

# F1 매크로 스코어와 모델을 저장할 리스트
scores = []
models = []

# 교차 검증 루프
for tri, vai in cv.split(train_ft, target):
    # 학습 데이터와 검증 데이터 분리 (선택된 피처만 사용)
    x_train = train_ft.iloc[tri][xgb_best_cols]
    y_train = target.iloc[tri]
    x_valid = train_ft.iloc[vai][xgb_best_cols]
    y_valid = target.iloc[vai]

    # 모델 초기화 및 학습
    lgbm_model_xgb = LGBMClassifier(**xgb_lgbm_params, random_state=SEED)
    lgbm_model_xgb.fit(x_train, y_train)

    # 모델 저장
    models.append(lgbm_model_xgb)

    # 예측 및 F1 매크로 스코어 계산
    pred = lgbm_model_xgb.predict(x_valid)
    score = f1_score(y_valid, pred, average='macro')
    scores.append(score)

# F1 매크로 스코어의 평균 출력
print("Mean F1 Macro Score:", np.mean(scores))

# %%
lgbm_model_xgb = LGBMClassifier(**xgb_xgb_params, random_state=SEED)
lgbm_model_xgb.fit(train_ft[xgb_best_cols],target)

pred = lgbm_model_xgb.predict_proba(test_ft[xgb_best_cols])[:, 1]

submit["target"] = pred
submit.to_csv("fs_xgb_lgbm.csv",index=False)

# %% [markdown]
# ### RadomForest로 Feature Selection

# %%
def objective(trial):
    hp = {
        "num_leaves": trial.suggest_int("num_leaves", 20, 150),               # 리프 노드의 수
        "max_depth": trial.suggest_int("max_depth", 3, 15),                   # 최대 트리 깊이
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3, log=True),  # 학습률
        "n_estimators": trial.suggest_int("n_estimators", 100, 1000, step=100),      # 부스팅 단계 수
        "min_child_samples": trial.suggest_int("min_child_samples", 5, 100),  # 최소 데이터 수
        "subsample": trial.suggest_float("subsample", 0.6, 1.0, step=0.1),    # 샘플링 비율
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.6, 1.0, step=0.1),  # 피처 샘플링 비율
        "reg_alpha": trial.suggest_float("reg_alpha", 1e-8, 10.0, log=True),  # L1 규제
        "reg_lambda": trial.suggest_float("reg_lambda", 1e-8, 10.0, log=True) # L2 규제
    }

    model = LGBMClassifier(**hp, random_state=SEED)
    score = cross_val_score(model, train_ft[rf_best_cols], target, cv=cv, scoring="f1_macro", n_jobs=-1).mean()
    return score

sampler = optuna.samplers.TPESampler(seed=SEED) # 대체 모델 역할은 sampler 객체

# study 객체
study = optuna.create_study(
    direction="maximize",
    sampler = sampler
)

study.optimize(objective, n_trials=100)   # optimze 메서드에 콜백 함수(objective) 전달

# %%
print("Best hyperparameters:", study.best_params)
print("Best F1 Score:", study.best_value)

# %%
rf_lgbm_params = {}

# F1 매크로 스코어와 모델을 저장할 리스트
scores = []
models = []

# 교차 검증 루프
for tri, vai in cv.split(train_ft, target):
    # 학습 데이터와 검증 데이터 분리 (선택된 피처만 사용)
    x_train = train_ft.iloc[tri][rf_best_cols]
    y_train = target.iloc[tri]
    x_valid = train_ft.iloc[vai][rf_best_cols]
    y_valid = target.iloc[vai]

    # 모델 초기화 및 학습
    lgbm_model_rf = LGBMClassifier(**rf_lgbm_params, random_state=SEED)
    lgbm_model_rf.fit(x_train, y_train)

    # 모델 저장
    models.append(lgbm_model_rf)

    # 예측 및 F1 매크로 스코어 계산
    pred = lgbm_model_rf.predict(x_valid)
    score = f1_score(y_valid, pred, average='macro')
    scores.append(score)

# F1 매크로 스코어의 평균 출력
print("Mean F1 Macro Score:", np.mean(scores))

# %%
lgbm_model_rf = LGBMClassifier(**xgb_xgb_params, random_state=SEED)
lgbm_model_rf.fit(train_ft[rf_best_cols],target)

pred = lgbm_model_rf.predict_proba(test_ft[rf_best_cols])[:, 1]

submit["target"] = pred
submit.to_csv("fs_rf_lgbm.csv",index=False)
