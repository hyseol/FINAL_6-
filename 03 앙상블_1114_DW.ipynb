# %% [markdown]
# # 팀원들의 예측 파일을 평균 내는 등과 같이 앙상블을 할 경우
# - 팀원들에게 csv 파일 만들때 1에 대한 확률로 예측할 것을 요구해야 함

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
DATA_PATH = "/content/drive/MyDrive/멋쟁이사자처럼/Final_Project/dataset/"
PROBA_PATH = "/content/drive/MyDrive/멋쟁이사자처럼/Final_Project/proba/"
SEED = 42

# %%
import pandas as pd
import numpy as np

train_tr = pd.read_csv(f"{DATA_PATH}store_train_transactions.csv") # 학습용 구매기록 데이터
train_target = pd.read_csv(f"{DATA_PATH}store_train.csv") # 학습용 정답 데이터
test_tr = pd.read_csv(f"{DATA_PATH}store_test_transactions.csv") # 테스트용 구매기록 데이터
submit = pd.read_csv(f"{DATA_PATH}store_submission.csv") # 제출 양식 데이터

train_tr.shape , train_target.shape , test_tr.shape , submit.shape
# Out:
# ((523105, 7), (14940, 2), (441196, 7), (12225, 2))

# %%
train_ft = pd.read_csv(f"{DATA_PATH}train_common_v3.3_피처삭제X_1111.csv")
test_ft = pd.read_csv(f"{DATA_PATH}test_common_v3.3_피처삭제X_1111.csv")

train_ft.shape, test_ft.shape
# Out:
# ((14940, 1470), (12225, 1470))

# %%
target = train_target["target"]

# %%
PROBA_PATH = "/content/drive/MyDrive/멋쟁이사자처럼/Final_Project/proba/"

proba_1 = pd.read_csv(f"{DATA_PATH}multi_layer_ensemble_06_1112_proba.csv")         # 0.732630
proba_5 = pd.read_csv(f"{DATA_PATH}voting5_logiadd_fs_logi_proba_V3.3_1111.csv")    # 0.732346
proba_3 = pd.read_csv(f"{DATA_PATH}ensemble_07_proba.csv")                          # 0.735396

proba_5 = pd.read_csv(f"{DATA_PATH}voting10_mlpadd_fs_V3.3_proba_1113.csv")         # 0.729686
proba_3 = pd.read_csv(f"{DATA_PATH}voting2_V3.3_proba_1111.csv")                    # 0.728752(0.42)
proba_1 = pd.read_csv(f"{DATA_PATH}ens_voting_proba_1111.csv")                      # 0.728546(0.42)
proba_4 = pd.read_csv(f"{DATA_PATH}voting4_logiadd_fs_logi_proba_V3.3_1111.csv")    # 0.728035(0.42)

proba_2 = pd.read_csv(f"{DATA_PATH}ensemble_03_proba.csv")                          # 0.727173
    # proba_1 = pd.read_csv(f"{DATA_PATH}6조_v3.2_1108_cluster_O_proba.csv")  # 현설_ 군집_스케일링O (0.723658)
    # proba_2 = pd.read_csv(f"{DATA_PATH}v3.2_XGB_cluster_proba.csv")         # 현설_v3.2_optuna_XGB (0.724409)
    # proba_3 = pd.read_csv(f"{DATA_PATH}6조_v3.0_proba.csv")                 # 공통피처 v3.0 (0.725006)
    # proba_4 = pd.read_csv(f"{DATA_PATH}v3.0_XGB_cluster_proba.csv")         # 현설_v3.2_optuna_XGB (0.725341)
proba_8 = pd.read_csv(f"{DATA_PATH}ensemble_05_proba.csv")                          # 0.726927
    # proba_1 = pd.read_csv(f"{DATA_PATH}ens_voting_proba_1111.csv")                      # 0.728546
    # proba_2 = pd.read_csv(f"{DATA_PATH}ensemble_03_proba.csv")                          # 0.727173
    # proba_3 = pd.read_csv(f"{DATA_PATH}ensemble_04_proba.csv")                          # 0.725729
    # proba_4 = pd.read_csv(f"{DATA_PATH}v3.0_XGB_cluster_proba.csv")                     # 0.725341
    # proba_5 = pd.read_csv(f"{DATA_PATH}v3.2_XGB_cluster_proba.csv")                     # 0.724409
    # proba_6 = pd.read_csv(f"{DATA_PATH}voting2_V3.3_proba_1111.csv")                    # 0.728752
    # proba_7 = pd.read_csv(f"{DATA_PATH}voting4_logiadd_fs_logi_proba_V3.3_1111.csv")    # 0.728035
    # proba_8 = pd.read_csv(f"{DATA_PATH}voting5_logiadd_fs_logi_proba_V3.3_1111.csv")    # 0.732346
proba_3 = pd.read_csv(f"{DATA_PATH}ensemble_04_proba.csv")                          # 0.725729
    # proba_1 = pd.read_csv(f"{DATA_PATH}6조_v3.2_1108_cluster_O_proba.csv")  # 현설_ 군집_스케일링O (0.723658)
    # proba_2 = pd.read_csv(f"{DATA_PATH}6조_v3.2_1108_cluster_X_proba.csv")  # 현설_ 군집_스케일링X (0.723658)
    # proba_3 = pd.read_csv(f"{DATA_PATH}6조_v3.0_proba.csv")                 # 공통피처 v3.0 (0.725006)
    # proba_4 = pd.read_csv(f"{DATA_PATH}v3.2_XGB_cluster_proba.csv")         # 현설_v3.2_optuna_XGB (0.724409)
    # proba_5 = pd.read_csv(f"{DATA_PATH}v3.0_XGB_cluster_proba.csv")         # 현설_v3.2_optuna_XGB (0.725341)
    # proba_6 = pd.read_csv(f"{DATA_PATH}XGB_fs_proba_1108.csv")              # 서진_XGB (0.722212)
    # proba_7 = pd.read_csv(f"{DATA_PATH}LGBM_fs_logi_proba_1108.csv")        # 서진_LGBM_logi (0.717365)
    # proba_8 = pd.read_csv(f"{DATA_PATH}LGBM_fs_xgb_proba_1108.csv")         # 서진_LGBM_xgb (0.719888)
proba_4 = pd.read_csv(f"{DATA_PATH}v3.0_XGB_cluster_proba.csv")                     # 0.725341
proba_2 = pd.read_csv(f"{DATA_PATH}v3.2_XGB_cluster_proba.csv")                     # 0.724409


proba_1 = pd.read_csv(f"{DATA_PATH}fs_xgb_LDA.csv")                                 # 0.718366
proba_2 = pd.read_csv(f"{DATA_PATH}fs_xgb_logistic.csv")                            # 0.717932
proba_3 = pd.read_csv(f"{DATA_PATH}log_sqrt_LGBM.csv")                              # 0.723536



proba_3 = pd.read_csv(f"{DATA_PATH}voting6_logiadd_fs_logi_proba_V3.3_1113.csv")    # 0.722278
proba_4 = pd.read_csv(f"{DATA_PATH}voting7_logiadd_fs_logi_proba_log_1113.csv")     # 0.716628

# %% [markdown]
# # 01

# %%
DATA_PATH = "C:/Users/user/Desktop/데이터분석/05 Project_Final/Submit_csv/새 폴더/"

proba_1 = pd.read_csv(f"{DATA_PATH}multi_layer_ensemble_06_1112_proba.csv")         # 0.732630
proba_2 = pd.read_csv(f"{DATA_PATH}voting5_logiadd_fs_logi_proba_V3.3_1111.csv")    # 0.732346
# proba_3 = pd.read_csv(f"{DATA_PATH}ensemble_07_proba.csv")                          # 0.735396

proba_3 = pd.read_csv(f"{DATA_PATH}voting10_mlpadd_fs_V3.3_proba_1113.csv")         # 0.729686
proba_4 = pd.read_csv(f"{DATA_PATH}voting2_V3.3_proba_1111.csv")                    # 0.728752()
proba_5 = pd.read_csv(f"{DATA_PATH}ens_voting_proba_1111.csv")                      # 0.728546(0.42)
proba_6 = pd.read_csv(f"{DATA_PATH}voting4_logiadd_fs_logi_proba_V3.3_1111.csv")    # 0.728035()

# %%
pred = np.mean(
        [
            proba_1["target"].to_numpy(),
            proba_2["target"].to_numpy(),

        ],axis=0)

submit["target"] = pred
proba_ensemble = submit
proba_ensemble.shape
# Out:
# (12225, 2)

# %%
pred = np.mean(
        [
            proba_1["target"].to_numpy(),
            proba_2["target"].to_numpy(),
            proba_3["target"].to_numpy(),
            proba_4["target"].to_numpy(),
            proba_5["target"].to_numpy(),
            proba_6["target"].to_numpy(),
            proba_ensemble["target"].to_numpy(),

        ],axis=0)
pred.shape
# Out:
# (12225,)

# %%
pred = (pred >= 0.5).astype(int)
submit["target"] = pred
submit.head
# Out:
#                ID  target
# 0          test_0       0
# 1          test_1       0
# 2          test_2       0
# 3          test_3       1
# 4          test_4       1
# ...           ...     ...
# 12220  test_12220       1
# 12221  test_12221       0
# 12222  test_12222       0
# 12223  test_12223       0
# 12224  test_12224       0
#
# [12225 rows x 2 columns]

# %%
submit.to_csv(f"ensemble_01_1114.csv",index=False)

# %% [markdown]
# # 02

# %%
DATA_PATH = "C:/Users/user/Desktop/데이터분석/05 Project_Final/Submit_csv/새 폴더/"

proba_1 = pd.read_csv(f"{DATA_PATH}multi_layer_ensemble_06_1112_proba.csv")         # 0.732630
proba_2 = pd.read_csv(f"{DATA_PATH}voting5_logiadd_fs_logi_proba_V3.3_1111.csv")    # 0.732346
# proba_3 = pd.read_csv(f"{DATA_PATH}ensemble_07_proba.csv")                          # 0.735396

proba_3 = pd.read_csv(f"{DATA_PATH}voting10_mlpadd_fs_V3.3_proba_1113.csv")         # 0.729686

proba_4 = pd.read_csv(f"{DATA_PATH}voting2_V3.3_proba_1111.csv")                    # 0.728752(0.42)
proba_5 = pd.read_csv(f"{DATA_PATH}ens_voting_proba_1111.csv")                      # 0.728546(0.42)
proba_6 = pd.read_csv(f"{DATA_PATH}voting4_logiadd_fs_logi_proba_V3.3_1111.csv")    # 0.728035(0.42)

# %%
pred = np.mean(
        [
            proba_1["target"].to_numpy(),
            proba_2["target"].to_numpy(),

        ],axis=0)

submit["target"] = pred
proba_ensemble_1 = submit
proba_ensemble_1.shape
# Out:
# (12225, 2)

# %%
pred = np.mean(
        [
            proba_4["target"].to_numpy(),
            proba_5["target"].to_numpy(),
            proba_6["target"].to_numpy(),

        ],axis=0)

submit["target"] = (pred >= 0.42).astype(int)
proba_ensemble_2 = submit
proba_ensemble_2.shape
# Out:
# (12225, 2)

# %%
pred = np.mean(
        [
            # proba_1["target"].to_numpy(),
            # proba_2["target"].to_numpy(),
            proba_3["target"].to_numpy(),
            proba_ensemble_1["target"].to_numpy(),
            proba_ensemble_2["target"].to_numpy(),

        ],axis=0)
pred.shape
# Out:
# (12225,)

# %%
pred = (pred >= 0.5).astype(int)
submit["target"] = pred
submit
# Out:
#                ID  target
# 0          test_0       0
# 1          test_1       0
# 2          test_2       0
# 3          test_3       1
# 4          test_4       1
# ...           ...     ...
# 12220  test_12220       1
# 12221  test_12221       0
# 12222  test_12222       0
# 12223  test_12223       0
# 12224  test_12224       0
#
# [12225 rows x 2 columns]

# %%
submit.to_csv(f"ensemble_02_01_1114.csv",index=False)

# %% [markdown]
# # 03

# %%
import pandas as pd
import numpy as np
DATA_PATH = "C:/Users/user/Desktop/데이터분석/05 Project_Final/Submit_csv/"

proba_1 = pd.read_csv(f"{DATA_PATH}multi_layer_ensemble_06_1112_proba.csv")         # 0.732630
proba_2 = pd.read_csv(f"{DATA_PATH}voting5_logiadd_fs_logi_proba_V3.3_1111.csv")    # 0.732346
proba_3 = pd.read_csv(f"{DATA_PATH}ensemble_07_proba.csv")                          # 0.735396
proba_4 = pd.read_csv(f"{DATA_PATH}voting10_mlpadd_fs_V3.3_proba_1113.csv")         # 0.729686
proba_5 = pd.read_csv(f"{DATA_PATH}6조_v3.0_proba.csv")                             # 0.725006
proba_6 = pd.read_csv(f"{DATA_PATH}ensemble_05_proba.csv")                          # 0.726927

proba_7 = pd.read_csv(f"{DATA_PATH}voting2_V3.3_proba_1111.csv")                    # 0.728752(0.42)
proba_8 = pd.read_csv(f"{DATA_PATH}ens_voting_proba_1111.csv")                      # 0.728546(0.42)
proba_9 = pd.read_csv(f"{DATA_PATH}voting4_logiadd_fs_logi_proba_V3.3_1111.csv")    # 0.728035(0.42)

proba_10 = pd.read_csv(f"{DATA_PATH}ensemble_03_proba.csv")                          # 0.727173 -> 0.730261(0.41)
proba_11 = pd.read_csv(f"{DATA_PATH}v3.0_XGB_cluster_proba.csv")                     # 0.725341 -> 0.733584(0.41)
proba_12 = pd.read_csv(f"{DATA_PATH}v3.2_XGB_cluster_proba.csv")                     # 0.724409 -> 0.726053(0.41)
proba_13 = pd.read_csv(f"{DATA_PATH}ensemble_04_proba.csv")                          # 0.725729 -> 0.731468(0.41)

# %%
for i in range(1, 14):
    if 1 <= i <= 6:
        globals()[f"proba_{i}"]["target"] = (globals()[f"proba_{i}"]["target"] > 0.5).astype(int)
    elif 7 <= i <= 9:
        globals()[f"proba_{i}"]["target"] = (globals()[f"proba_{i}"]["target"] > 0.42).astype(int)
    else:
        globals()[f"proba_{i}"]["target"] = (globals()[f"proba_{i}"]["target"] > 0.41).astype(int)

# %%
for i in range(2, 14):
    globals()[f"proba_{i}"] = globals()[f"proba_{i}"].rename(columns= {"target" : f"target_{i}"})
    proba_1 = proba_1.merge(globals()[f"proba_{i}"], on= "ID", how= "left")

# %%
proba_1["voting"] = proba_1.mode(axis=1)

# %%
submit["target"] = proba_1["voting"]
submit
# Out:
#                ID  target
# 0          test_0       0
# 1          test_1       0
# 2          test_2       0
# 3          test_3       1
# 4          test_4       1
# ...           ...     ...
# 12220  test_12220       1
# 12221  test_12221       0
# 12222  test_12222       0
# 12223  test_12223       0
# 12224  test_12224       0
#
# [12225 rows x 2 columns]

# %%
submit.to_csv(f"ensemble_03_1114.csv",index=False)

# %% [markdown]
# # DaeWon

# %%
# 성능 점수 순서대로 프로바 변수 재설정

proba1 = pd.read_csv(f"{PROBA_PATH}ensemble_07_proba.csv")                           # 0.735396
proba2 = pd.read_csv(f"{PROBA_PATH}multi_layer_ensemble_06_1112_proba.csv")          # 0.732630
proba3 = pd.read_csv(f"{PROBA_PATH}voting5_logiadd_fs_logi_proba_V3.3_1111.csv")     # 0.732346

proba4 = pd.read_csv(f"{PROBA_PATH}voting10_mlpadd_fs_V3.3_proba_1113.csv")          # 0.729686
proba5 = pd.read_csv(f"{PROBA_PATH}voting2_V3.3_proba_1111.csv")                     # 0.728752(0.42)
proba6 = pd.read_csv(f"{PROBA_PATH}ens_voting_proba_1111.csv")                       # 0.728546(0.42)
proba7 = pd.read_csv(f"{PROBA_PATH}voting4_logiadd_fs_logi_proba_V3.3_1111.csv")     # 0.728035(0.42)
proba8 = pd.read_csv(f"{PROBA_PATH}ensemble_03_proba.csv")                           # 0.727173
proba9 = pd.read_csv(f"{PROBA_PATH}ensemble_05_proba.csv")                           # 0.726927

proba10 = pd.read_csv(f"{PROBA_PATH}ensemble_04_proba.csv")                          # 0.725729
proba11 = pd.read_csv(f"{PROBA_PATH}v3.0_XGB_cluster_proba.csv")                     # 0.725341 (현설_v3.2_optuna_XGB)
proba12 = pd.read_csv(f"{PROBA_PATH}6조_v3.0_proba.csv")                             # 0.725006 (공통피처 v3.0)

proba13 = pd.read_csv(f"{PROBA_PATH}voting6_logiadd_fs_logi_proba_V3.3_1113.csv")    # 0.722278
proba14 = pd.read_csv(f"{PROBA_PATH}6조_v3.2_1108_cluster_O_proba.csv")              # 0.723658 (현설_ 군집_스케일링O)
proba15 = pd.read_csv(f"{PROBA_PATH}v3.2_XGB_cluster_proba.csv")                     # 0.724409 (현설_v3.2_optuna_XGB)
proba16 = pd.read_csv(f"{PROBA_PATH}log_sqrt_LGBM.csv")                              # 0.723536
proba17 = pd.read_csv(f"{PROBA_PATH}XGB_fs_proba_1108.csv")                          # 0.722212 (서진_XGB)

proba18 = pd.read_csv(f"{PROBA_PATH}LGBM_fs_xgb_proba_1108.csv")                     # 0.719888 (서진_LGBM_xgb)
proba19 = pd.read_csv(f"{PROBA_PATH}LGBM_fs_logi_proba_1108.csv")                    # 0.717365 (서진_LGBM_logi)
proba20 = pd.read_csv(f"{PROBA_PATH}fs_xgb_LDA.csv")                                 # 0.718366
proba21 = pd.read_csv(f"{PROBA_PATH}fs_xgb_logistic.csv")                            # 0.717932
proba22 = pd.read_csv(f"{PROBA_PATH}voting7_logiadd_fs_logi_proba_log_1113.csv")     # 0.716628

# %% [markdown]
# ## Top4 + log_sqrt_LGBM + fs_xgb_LDA + fs_xgb_logistic

# %%
pred = np.mean(
        [
            proba16["target"].to_numpy(),   # log_sqrt_LGBM
            proba20["target"].to_numpy(),   # fs_xgb_LDA
            proba21["target"].to_numpy(),   # fs_xgb_logistic

        ],axis=0)

submit["target"] = pred
proba_ensemble = submit
proba_ensemble.shape
# Out:
# (12225, 2)

# %%
pred = np.mean(
        [
            proba1["target"].to_numpy(),
            proba2["target"].to_numpy(),
            proba3["target"].to_numpy(),
            proba4["target"].to_numpy(),
            proba_ensemble["target"].to_numpy(),

        ],axis=0)
pred.shape
# Out:
# (12225,)

# %%
pred = (pred >= 0.5).astype(int)
submit["target"] = pred
submit.head()
# Out:
#        ID  target
# 0  test_0       0
# 1  test_1       0
# 2  test_2       0
# 3  test_3       1
# 4  test_4       1

# %%
submit["target"].mean()
# Out:
# 0.3983640081799591

# %%
submit.to_csv(f"ensemble_top4+daewon3.csv",index=False)

# %% [markdown]
# ## Feature Selection 끼리

# %%
pred = np.mean(
        [
            proba4["target"].to_numpy(),
            proba7["target"].to_numpy(),
            proba13["target"].to_numpy(),
            proba17["target"].to_numpy(),
            proba18["target"].to_numpy(),
            proba19["target"].to_numpy(),
            proba20["target"].to_numpy(),
            proba21["target"].to_numpy(),
            proba22["target"].to_numpy(),


        ],axis=0)

pred = (pred >= 0.5).astype(int)
submit["target"] = pred
submit.head()
# Out:
#        ID  target
# 0  test_0       0
# 1  test_1       0
# 2  test_2       0
# 3  test_3       1
# 4  test_4       1

# %%
submit["target"].mean()
# Out:
# 0.3561554192229039
