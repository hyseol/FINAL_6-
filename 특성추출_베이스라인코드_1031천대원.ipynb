# %% [markdown]
# # 컴피티션 링크
# - https://www.kaggle.com/t/2e45abe9f1434b59a3358365432a48bb

# %% [markdown]
# # 고객별 백화점 구매기록 데이터셋
# - 미혼(1) or 기혼(0) 고객을 예측
# - 학습용 구매기록 데이터
#     - https://drive.google.com/file/d/1tg41qXu02FK55bFa8P1Gx2URhwPUCoQQ/view?usp=sharing
# - 학습용 정답 데이터
#     - https://drive.google.com/file/d/1-9AcU9nAoO4SzSmqdCOYTvWNpA5Pdt3q/view?usp=sharing
# - 테스트용 구매기록 데이터
#     - https://drive.google.com/file/d/1-AwDfGlHm9rNtpnHIWOK96jBJYy3f2SZ/view?usp=sharing
# - 제출 양식 데이터
#     - https://drive.google.com/file/d/1-Qv7SlsY5Eu3bRR7Z0IUJyLkOO1Fl3y6/view?usp=sharing

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# - 데이터 경로 변수

# %%
DATA_PATH = "/content/drive/MyDrive/멋쟁이사자처럼/data/"
DATA_PATH
# Out:
# '/content/drive/MyDrive/멋쟁이사자처럼/06. Machine Learning/data/'

# %% [markdown]
# - 데이터 불러오기

# %%
import pandas as pd
import numpy as np

train_tr = pd.read_csv(f"{DATA_PATH}store_train_transactions.csv") # 학습용 구매기록 데이터
train_target = pd.read_csv(f"{DATA_PATH}store_train.csv") # 학습용 정답 데이터
test_tr = pd.read_csv(f"{DATA_PATH}store_test_transactions.csv") # 테스트용 구매기록 데이터
submit = pd.read_csv(f"{DATA_PATH}store_submission.csv") # 제출 양식 데이터

train_tr.shape , train_target.shape , test_tr.shape , submit.shape
# Out:
# ((523105, 7), (14940, 2), (441196, 7), (12225, 2))

# %%
from IPython.display import display, HTML
br_html = HTML("<br><br>")
display(HTML("<h1>학습용 구매기록 데이터</h1>"), train_tr.head(), br_html)
display(HTML("<h1>학습용 정답 데이터</h1>"), train_target.head(), br_html)
display(HTML("<h1>테스트용 구매기록 데이터</h1>"), test_tr.head(), br_html)
display(HTML("<h1>제출 양식 데이터</h1>"), submit.head(), br_html)
# Out:
# <h1>학습용 구매기록 데이터</h1>
#             ID                 구매일시     지점코드     대분류      중분류  브랜드코드    구매가격
# 0  train_13219  2004-05-01 09:40:00  A144000   공산품파트       차류   5100   59700
# 1   train_5590  2004-05-01 09:40:00  A144000    잡화파트     화장잡화   5101   17000
# 2   train_7200  2004-05-01 10:20:00  A112000     공산품     용기보증   5100   34937
# 3   train_3010  2004-05-01 10:30:00  A373000  아동_스포츠      아동복   5105   19000
# 4  train_10851  2004-05-01 10:30:00  A112000    가정용품  전화기_카세트   5110  215000
# <br><br>
# <h1>학습용 정답 데이터</h1>
#         ID  target
# 0  train_0     1.0
# 1  train_1     1.0
# 2  train_2     0.0
# 3  train_3     0.0
# 4  train_4     0.0
# <br><br>
# <h1>테스트용 구매기록 데이터</h1>
#           ID                 구매일시     지점코드   대분류      중분류  브랜드코드    구매가격
# 0  test_3366  2004-05-01 10:20:00  A373000   생식품      건식품   5100    7000
# 1  test_9389  2004-05-01 10:23:00  A373000  명품잡화      스타킹   5104   46000
# 2  test_8190  2004-05-01 10:30:00  A144000  잡화파트  수입종합화장품   5106  260000
# 3  test_8835  2004-05-01 10:30:00  A144000  잡화파트      준보석   5107   17000
# 4  test_1167  2004-05-01 10:30:00  A373000  남성의류       셔츠   5108  138000
# <br><br>
# <h1>제출 양식 데이터</h1>
#        ID  target
# 0  test_0     0.5
# 1  test_1     0.5
# 2  test_2     0.5
# 3  test_3     0.5
# 4  test_4     0.5
# <br><br>

# %%
display(HTML("<h1>학습용 구매기록 데이터</h1>"))
display(train_tr.info(), br_html)

display(HTML("<h1>학습용 정답 데이터</h1>"))
display(train_target.info(), br_html)

display(HTML("<h1>테스트용 구매기록 데이터</h1>"))
display(test_tr.info(), br_html)

display(HTML("<h1>제출 양식 데이터</h1>"))
display(submit.info(), br_html)
# Out:
# <h1>학습용 구매기록 데이터</h1>
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 523105 entries, 0 to 523104
# Data columns (total 7 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      523105 non-null  object
#  1   구매일시    523105 non-null  object
#  2   지점코드    523105 non-null  object
#  3   대분류     523105 non-null  object
#  4   중분류     523105 non-null  object
#  5   브랜드코드   523105 non-null  int64
#  6   구매가격    523105 non-null  int64
# dtypes: int64(2), object(5)
# memory usage: 27.9+ MB
# None
# <br><br>
# <h1>학습용 정답 데이터</h1>
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14940 entries, 0 to 14939
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      14940 non-null  object
#  1   target  14940 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 233.6+ KB
# None
# <br><br>
# <h1>테스트용 구매기록 데이터</h1>
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 441196 entries, 0 to 441195
# Data columns (total 7 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      441196 non-null  object
#  1   구매일시    441196 non-null  object
#  2   지점코드    441196 non-null  object
#  3   대분류     441196 non-null  object
#  4   중분류     441196 non-null  object
#  5   브랜드코드   441196 non-null  int64
#  6   구매가격    441196 non-null  int64
# dtypes: int64(2), object(5)
# memory usage: 23.6+ MB
# None
# <br><br>
# <h1>제출 양식 데이터</h1>
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12225 entries, 0 to 12224
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      12225 non-null  object
#  1   target  12225 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 191.1+ KB
# None
# <br><br>

# %% [markdown]
# # 특성 공학(Feature Engineering)

# %% [markdown]
# ## 날짜 형식으로 변환

# %%
train_tr["구매일시"] = pd.to_datetime(train_tr["구매일시"])
test_tr["구매일시"] = pd.to_datetime(test_tr["구매일시"])

# %% [markdown]
# ## 새로 만든 feature와 병합할 고객ID로만 이루어진 데이터프레임 생성

# %%
train_ft = train_target[["ID"]]
test_ft = submit[["ID"]]

train_ft.shape, test_ft.shape
# Out:
# ((14940, 1), (12225, 1))

# %%
# 2004년 5월 ~ 2005년 4월 공휴일 리스트
holiday_2004 = ["2004-05-05", "2004-05-26", "2004-06-06",
                "2004-07-17", "2004-08-15", "2004-09-27",
                "2004-09-28", "2004-09-29", "2004-10-03", "2004-12-25"]

holiday_2005 = ["2005-01-01", "2005-02-08", "2005-02-09",
                "2005-02-10", "2005-03-01", "2005-04-05"]

holidays = pd.to_datetime(holiday_2004 + holiday_2005)

# %% [markdown]
# ## 구매일시를 이용한 특성생성 - 공휴일

# %%
agg_list = [
        ("공휴일_구매유무", lambda x: x.dt.date.isin(holidays.date).any().astype(int)),     # 공휴일 구매 유무(0과 1로 반환)
        ("공휴일_구매비율", lambda x: np.mean(x.dt.date.isin(holidays.date))),  # 공휴일 구매 비율
        ("여름휴가_구매비율", lambda x: np.mean(x.dt.month.isin([7,8]))),   # 방학,여름휴가(7,8월) 구매비율
        ("연말_구매비율", lambda x: np.mean(x.dt.month.isin([12,1,2]))),    # 연말(12월~2월) 구매비율
    ]

tmp = train_tr.groupby('ID')["구매일시"].agg(agg_list).reset_index()
train_ft = train_ft.merge(tmp, how='left',on="ID")
train_ft.head()
# Out:
#         ID  공휴일_구매유무  공휴일_구매비율  여름휴가_구매비율   연말_구매비율
# 0  train_0         0  0.000000   0.100000  0.300000
# 1  train_1         1  0.071429   0.142857  0.119048
# 2  train_2         1  0.078947   0.087719  0.219298
# 3  train_3         1  0.042654   0.104265  0.203791
# 4  train_4         1  0.209677   0.451613  0.064516

# %%
tmp = test_tr.groupby('ID')["구매일시"].agg(agg_list).reset_index()
test_ft = test_ft.merge(tmp, how='left',on="ID")
test_ft.head()
# Out:
#        ID  공휴일_구매유무  공휴일_구매비율  여름휴가_구매비율   연말_구매비율
# 0  test_0         0  0.000000   0.142857  0.000000
# 1  test_1         0  0.000000   0.000000  0.250000
# 2  test_2         0  0.000000   0.600000  0.000000
# 3  test_3         0  0.000000   0.468750  0.125000
# 4  test_4         1  0.238095   0.285714  0.095238

# %% [markdown]
# ## 공휴일별 대분류별 구매가격 및 구매횟수 - Pivot Table 사용

# %%
# 공휴일에 구매한 대분류별 가격 - train
holiday_data = train_tr[train_tr["구매일시"].dt.date.isin(holidays.date)]

holiday_sums = holiday_data.groupby(["ID", "대분류"])["구매가격"].sum().reset_index()

holiday_sums_pivot = holiday_sums.pivot_table(
    index="ID",
    columns="대분류",
    values="구매가격",
    fill_value=0
).reset_index()

# 컬럼명 변경
holiday_sums_pivot.columns = [
    f"공휴일_대분류_{col}_구매금액" if col != "ID" else col
    for col in holiday_sums_pivot.columns
]

train_ft = train_ft.merge(holiday_sums_pivot, how='left', on="ID")
train_ft.head()
# Out:
#         ID  공휴일_구매유무  공휴일_구매비율  여름휴가_구매비율   연말_구매비율  공휴일_대분류_가정용품_구매금액  \
# 0  train_0         0  0.000000   0.100000  0.300000                NaN
# 1  train_1         1  0.071429   0.142857  0.119048                0.0
# 2  train_2         1  0.078947   0.087719  0.219298                0.0
# 3  train_3         1  0.042654   0.104265  0.203791                0.0
# 4  train_4         1  0.209677   0.451613  0.064516                0.0
#
#    공휴일_대분류_가정용품파트_구매금액  공휴일_대분류_골프_유니캐쥬얼_구매금액  공휴일_대분류_공산품_구매금액  \
# 0                  NaN                    NaN               NaN
# 1                  0.0                    0.0               0.0
# 2                  0.0                82000.0               0.0
# 3                  0.0                    0.0               0.0
# 4                  0.0                    0.0               0.0
#
#    공휴일_대분류_공산품파트_구매금액  ...  공휴일_대분류_여성캐주얼_구매금액  공휴일_대분류_여성캐쥬얼_구매금액  \
# 0                 NaN  ...                 NaN                 NaN
# 1                 0.0  ...                 0.0                 0.0
# 2                 0.0  ...                 0.0                 0.0
# 3                 0.0  ...                 0.0                 0.0
# 4             24200.0  ...                 0.0                 0.0
#
#    공휴일_대분류_영라이브_구매금액  공휴일_대분류_영어덜트캐쥬얼_구매금액  공휴일_대분류_영캐릭터_구매금액  \
# 0                NaN                   NaN                NaN
# 1                0.0                   0.0                0.0
# 2                0.0                   0.0                0.0
# 3                0.0                   0.0                0.0
# 4                0.0                   0.0                0.0
#
#    공휴일_대분류_영플라자_구매금액  공휴일_대분류_잡화_구매금액  공휴일_대분류_잡화파트_구매금액  \
# 0                NaN              NaN                NaN
# 1            79000.0              0.0                0.0
# 2                0.0              0.0                0.0
# 3           258200.0              0.0                0.0
# 4                0.0              0.0           101000.0
#
#    공휴일_대분류_케주얼_구두_아동_구매금액  공휴일_대분류_패션잡화_구매금액
# 0                     NaN                NaN
# 1                     0.0           175000.0
# 2                     0.0                0.0
# 3                145000.0                0.0
# 4                160000.0                0.0
#
# [5 rows x 33 columns]

# %%
# 공휴일에 구매한 대분류별 가격 - test
holiday_data = test_tr[test_tr["구매일시"].dt.date.isin(holidays.date)]

holiday_sums = holiday_data.groupby(["ID", "대분류"])["구매가격"].sum().reset_index()

holiday_sums_pivot = holiday_sums.pivot_table(
    index="ID",
    columns="대분류",
    values="구매가격",
    fill_value=0
).reset_index()

# 컬럼명 변경
holiday_sums_pivot.columns = [
    f"공휴일_대분류_{col}_구매금액" if col != "ID" else col
    for col in holiday_sums_pivot.columns
]

test_ft = test_ft.merge(holiday_sums_pivot, how='left', on="ID")
test_ft.head()
# Out:
#        ID  공휴일_구매유무  공휴일_구매비율  여름휴가_구매비율   연말_구매비율  공휴일_대분류_가정용품_구매금액  \
# 0  test_0         0  0.000000   0.142857  0.000000                NaN
# 1  test_1         0  0.000000   0.000000  0.250000                NaN
# 2  test_2         0  0.000000   0.600000  0.000000                NaN
# 3  test_3         0  0.000000   0.468750  0.125000                NaN
# 4  test_4         1  0.238095   0.285714  0.095238                0.0
#
#    공휴일_대분류_가정용품파트_구매금액  공휴일_대분류_골프_유니캐쥬얼_구매금액  공휴일_대분류_공산품_구매금액  \
# 0                  NaN                    NaN               NaN
# 1                  NaN                    NaN               NaN
# 2                  NaN                    NaN               NaN
# 3                  NaN                    NaN               NaN
# 4                  0.0                    0.0           35790.0
#
#    공휴일_대분류_공산품파트_구매금액  ...  공휴일_대분류_여성캐주얼_구매금액  공휴일_대분류_여성캐쥬얼_구매금액  \
# 0                 NaN  ...                 NaN                 NaN
# 1                 NaN  ...                 NaN                 NaN
# 2                 NaN  ...                 NaN                 NaN
# 3                 NaN  ...                 NaN                 NaN
# 4                 0.0  ...            542100.0                 0.0
#
#    공휴일_대분류_영라이브_구매금액  공휴일_대분류_영어덜트캐쥬얼_구매금액  공휴일_대분류_영캐릭터_구매금액  \
# 0                NaN                   NaN                NaN
# 1                NaN                   NaN                NaN
# 2                NaN                   NaN                NaN
# 3                NaN                   NaN                NaN
# 4                0.0                   0.0                0.0
#
#    공휴일_대분류_영플라자_구매금액  공휴일_대분류_잡화_구매금액  공휴일_대분류_잡화파트_구매금액  \
# 0                NaN              NaN                NaN
# 1                NaN              NaN                NaN
# 2                NaN              NaN                NaN
# 3                NaN              NaN                NaN
# 4                0.0              0.0                0.0
#
#    공휴일_대분류_케주얼_구두_아동_구매금액  공휴일_대분류_패션잡화_구매금액
# 0                     NaN                NaN
# 1                     NaN                NaN
# 2                     NaN                NaN
# 3                     NaN                NaN
# 4                     0.0                0.0
#
# [5 rows x 33 columns]

# %%
# 공휴일에 구매한 대분류별 횟수 - train
holiday_data = train_tr[train_tr["구매일시"].dt.date.isin(holidays.date)]

holiday_purchase_counts = holiday_data.groupby(["ID", "대분류"]).size().reset_index(name="공휴일_대분류_구매횟수")

holiday_counts_pivot = holiday_purchase_counts.pivot_table(
    index="ID",
    columns="대분류",
    values="공휴일_대분류_구매횟수",
    fill_value=0  # 공휴일에 해당 대분류를 구매하지 않은 경우 0으로 표시
).reset_index()

# 컬럼명 변경
holiday_counts_pivot.columns = [
    f"공휴일_{col}_대분류_구매횟수" if col != "ID" else col
    for col in holiday_counts_pivot.columns
]

train_ft = train_ft.merge(holiday_counts_pivot, how='left', on="ID")
train_ft.head()
# Out:
#         ID  공휴일_구매유무  공휴일_구매비율  여름휴가_구매비율   연말_구매비율  공휴일_대분류_가정용품_구매금액  \
# 0  train_0         0  0.000000   0.100000  0.300000                NaN
# 1  train_1         1  0.071429   0.142857  0.119048                0.0
# 2  train_2         1  0.078947   0.087719  0.219298                0.0
# 3  train_3         1  0.042654   0.104265  0.203791                0.0
# 4  train_4         1  0.209677   0.451613  0.064516                0.0
#
#    공휴일_대분류_가정용품파트_구매금액  공휴일_대분류_골프_유니캐쥬얼_구매금액  공휴일_대분류_공산품_구매금액  \
# 0                  NaN                    NaN               NaN
# 1                  0.0                    0.0               0.0
# 2                  0.0                82000.0               0.0
# 3                  0.0                    0.0               0.0
# 4                  0.0                    0.0               0.0
#
#    공휴일_대분류_공산품파트_구매금액  ...  공휴일_여성캐주얼_대분류_구매횟수  공휴일_여성캐쥬얼_대분류_구매횟수  \
# 0                 NaN  ...                 NaN                 NaN
# 1                 0.0  ...                 0.0                 0.0
# 2                 0.0  ...                 0.0                 0.0
# 3                 0.0  ...                 0.0                 0.0
# 4             24200.0  ...                 0.0                 0.0
#
#    공휴일_영라이브_대분류_구매횟수  공휴일_영어덜트캐쥬얼_대분류_구매횟수  공휴일_영캐릭터_대분류_구매횟수  \
# 0                NaN                   NaN                NaN
# 1                0.0                   0.0                0.0
# 2                0.0                   0.0                0.0
# 3                0.0                   0.0                0.0
# 4                0.0                   0.0                0.0
#
#    공휴일_영플라자_대분류_구매횟수  공휴일_잡화_대분류_구매횟수  공휴일_잡화파트_대분류_구매횟수  \
# 0                NaN              NaN                NaN
# 1                1.0              0.0                0.0
# 2                0.0              0.0                0.0
# 3                4.0              0.0                0.0
# 4                0.0              0.0                3.0
#
#    공휴일_케주얼_구두_아동_대분류_구매횟수  공휴일_패션잡화_대분류_구매횟수
# 0                     NaN                NaN
# 1                     0.0                2.0
# 2                     0.0                0.0
# 3                     1.0                0.0
# 4                     3.0                0.0
#
# [5 rows x 61 columns]

# %%
# 공휴일에 구매한 대분류별 횟수 - test
holiday_data = test_tr[test_tr["구매일시"].dt.date.isin(holidays.date)]

holiday_purchase_counts = holiday_data.groupby(["ID", "대분류"]).size().reset_index(name="공휴일_대분류_구매횟수")

holiday_counts_pivot = holiday_purchase_counts.pivot_table(
    index="ID",
    columns="대분류",
    values="공휴일_대분류_구매횟수",
    fill_value=0  # 공휴일에 해당 대분류를 구매하지 않은 경우 0으로 표시
).reset_index()

# 컬럼명 변경
holiday_counts_pivot.columns = [
    f"공휴일_{col}_대분류_구매횟수" if col != "ID" else col
    for col in holiday_counts_pivot.columns
]

test_ft = test_ft.merge(holiday_counts_pivot, how='left', on="ID")
test_ft.head()
# Out:
#        ID  공휴일_구매유무  공휴일_구매비율  여름휴가_구매비율   연말_구매비율  공휴일_대분류_가정용품_구매금액  \
# 0  test_0         0  0.000000   0.142857  0.000000                NaN
# 1  test_1         0  0.000000   0.000000  0.250000                NaN
# 2  test_2         0  0.000000   0.600000  0.000000                NaN
# 3  test_3         0  0.000000   0.468750  0.125000                NaN
# 4  test_4         1  0.238095   0.285714  0.095238                0.0
#
#    공휴일_대분류_가정용품파트_구매금액  공휴일_대분류_골프_유니캐쥬얼_구매금액  공휴일_대분류_공산품_구매금액  \
# 0                  NaN                    NaN               NaN
# 1                  NaN                    NaN               NaN
# 2                  NaN                    NaN               NaN
# 3                  NaN                    NaN               NaN
# 4                  0.0                    0.0           35790.0
#
#    공휴일_대분류_공산품파트_구매금액  ...  공휴일_여성캐주얼_대분류_구매횟수  공휴일_여성캐쥬얼_대분류_구매횟수  \
# 0                 NaN  ...                 NaN                 NaN
# 1                 NaN  ...                 NaN                 NaN
# 2                 NaN  ...                 NaN                 NaN
# 3                 NaN  ...                 NaN                 NaN
# 4                 0.0  ...                 3.0                 0.0
#
#    공휴일_영라이브_대분류_구매횟수  공휴일_영어덜트캐쥬얼_대분류_구매횟수  공휴일_영캐릭터_대분류_구매횟수  \
# 0                NaN                   NaN                NaN
# 1                NaN                   NaN                NaN
# 2                NaN                   NaN                NaN
# 3                NaN                   NaN                NaN
# 4                0.0                   0.0                0.0
#
#    공휴일_영플라자_대분류_구매횟수  공휴일_잡화_대분류_구매횟수  공휴일_잡화파트_대분류_구매횟수  \
# 0                NaN              NaN                NaN
# 1                NaN              NaN                NaN
# 2                NaN              NaN                NaN
# 3                NaN              NaN                NaN
# 4                0.0              0.0                0.0
#
#    공휴일_케주얼_구두_아동_대분류_구매횟수  공휴일_패션잡화_대분류_구매횟수
# 0                     NaN                NaN
# 1                     NaN                NaN
# 2                     NaN                NaN
# 3                     NaN                NaN
# 4                     0.0                0.0
#
# [5 rows x 61 columns]

# %%
# 공휴일에 대한 구매기록이 없는 데이터는 0으로 대체
train_ft.fillna(0, inplace=True)
test_ft.fillna(0, inplace=True)

# %%
train_ft.isnull().sum().sum(), test_ft.isnull().sum().sum()
# Out:
# (0, 0)

# %%
train_ft.shape, test_ft.shape
# Out:
# ((14940, 61), (12225, 61))
