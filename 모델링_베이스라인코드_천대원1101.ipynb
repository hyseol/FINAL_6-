# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# - 데이터 경로 변수

# %%
DATA_PATH = "/content/drive/MyDrive/멋쟁이사자처럼/data/"
DATA_PATH
# Out:
# '/content/drive/MyDrive/멋쟁이사자처럼/data/'

# %% [markdown]
# - 시드값

# %%
SEED = 42

# %% [markdown]
# - 데이터 불러오기

# %%
import pandas as pd
import numpy as np

train_tr = pd.read_csv(f"{DATA_PATH}store_train_transactions.csv") # 학습용 구매기록 데이터
train_target = pd.read_csv(f"{DATA_PATH}store_train.csv") # 학습용 정답 데이터
test_tr = pd.read_csv(f"{DATA_PATH}store_test_transactions.csv") # 테스트용 구매기록 데이터
submit = pd.read_csv(f"{DATA_PATH}store_submission.csv") # 제출 양식 데이터

train_tr.shape , train_target.shape , test_tr.shape , submit.shape
# Out:
# ((523105, 7), (14940, 2), (441196, 7), (12225, 2))

# %% [markdown]
# - 공통 피처 파일 불러오기

# %%
train_ft = pd.read_csv(f"{DATA_PATH}train_common_v2.0_1101.csv") # 학습 데이터(피처)
test_ft = pd.read_csv(f"{DATA_PATH}test_common_v2.0_1101.csv") # 테스트 데이터(피처)

train_ft.shape , test_ft.shape
# Out:
# ((14940, 465), (12225, 465))

# %% [markdown]
# # 결측치 처리

# %%
mask = train_ft.isnull().sum() > 0
train_ft.isnull().sum()[mask]
# Out:
# Series([], dtype: int64)

# %%
mask = test_ft.isnull().sum() > 0
test_ft.isnull().sum()[mask]
# Out:
# Series([], dtype: int64)

# %%
train_ft["구매금액표준편차"] = train_ft["구매금액표준편차"].fillna(0)
test_ft["구매금액표준편차"] = test_ft["구매금액표준편차"].fillna(0)

# %% [markdown]
# # 특성 공학(Feature Engineering)

# %% [markdown]
# - ID 변수 제외

# %%
train_ft = train_ft.iloc[:,1:]
test_ft = test_ft.iloc[:,1:]
train_ft.shape, test_ft.shape
# Out:
# ((14940, 464), (12225, 464))

# %% [markdown]
# - 추가 피처 만들어 보기

# %%
cols = [ col for col in train_ft.columns if col.startswith("pivot_cnt_") ]

# %%
train_ft["중분류별_구매횟수_std"] = train_ft[cols].std(axis=1)
train_ft["중분류별_구매횟수_skew"] = train_ft[cols].skew(axis=1)
train_ft["중분류별_구매횟수_kurt"] = train_ft[cols].kurt(axis=1)

test_ft["중분류별_구매횟수_std"] = test_ft[cols].std(axis=1)
test_ft["중분류별_구매횟수_skew"] = test_ft[cols].skew(axis=1)
test_ft["중분류별_구매횟수_kurt"] = test_ft[cols].kurt(axis=1)

train_ft.shape, test_ft.shape

# %% [markdown]
# ## Feature Encoding

# %%
cols = train_ft.select_dtypes("object").columns.tolist()
train_ft[cols].nunique()
# Out:
# 주구매지점              4
# 주구매_중분류          246
# 주구매_대분류_수정         7
# 대분류_수정_평균금액최대      7
# dtype: int64

# %%
# %pip install category_encoders
# Out:
# Collecting category_encoders
#   Downloading category_encoders-2.6.4-py2.py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (1.26.4)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (1.5.2)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (1.13.1)
# Requirement already satisfied: statsmodels>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (0.14.4)
# Requirement already satisfied: pandas>=1.0.5 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (2.2.2)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (0.5.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.5->category_encoders) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.5->category_encoders) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.5->category_encoders) (2024.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.1->category_encoders) (1.16.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->category_encoders) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->category_encoders) (3.5.0)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.9.0->category_encoders) (24.1)
# Downloading category_encoders-2.6.4-py2.py3-none-any.whl (82 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.0/82.0 kB 2.0 MB/s eta 0:00:00
# Installing collected packages: category_encoders
# Successfully installed category_encoders-2.6.4

# %%
import category_encoders as ce

# %%
enc = ce.one_hot.OneHotEncoder()
tmp = enc.fit_transform(train_ft[["주구매지점","주구매_대분류_수정", "대분류_수정_평균금액최대"]])
train_ft = pd.concat([train_ft,tmp],axis =1)

tmp = enc.transform(test_ft[["주구매지점","주구매_대분류_수정", "대분류_수정_평균금액최대"]])
test_ft = pd.concat([test_ft,tmp],axis =1)

train_ft.shape, test_ft.shape
# Out:
# ((14940, 482), (12225, 482))

# %%
enc = ce.count.CountEncoder()
train_ft["주구매_중분류_cnt"] = enc.fit_transform(train_ft[["주구매_중분류"]])
test_ft["주구매_중분류_cnt"] = enc.transform(test_ft[["주구매_중분류"]])

train_ft.shape, test_ft.shape
# Out:
# ((14940, 483), (12225, 483))

# %% [markdown]
# - 문자열 피처 삭제

# %%
cols
# Out:
# ['주구매지점', '주구매_중분류', '주구매_대분류_수정', '대분류_수정_평균금액최대']

# %%
train_ft = train_ft.drop(columns=cols)
test_ft = test_ft.drop(columns=cols)
train_ft.shape, test_ft.shape
# Out:
# ((14940, 479), (12225, 479))

# %%
train_ft.select_dtypes("object").columns , test_ft.select_dtypes("object").columns
# Out:
# (Index([], dtype='object'), Index([], dtype='object'))

# %% [markdown]
# ## Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
train_ft[train_ft.columns] = scaler.fit_transform(train_ft)
test_ft[test_ft.columns] = scaler.transform(test_ft)
train_ft.head()
# Out:
#        내점일수      구매주기    주말방문비율    봄_구매비율   여름_구매비율   가을_구매비율   겨울_구매비율  \
# 0 -0.369867  0.002987  0.257728 -1.029777  0.001191  0.838272  0.338186
# 1  0.144110 -0.356452 -1.008554  0.323951 -0.390607  0.620171 -0.552996
# 2  1.943028 -0.869935  0.036742  0.798943 -0.514333 -0.304527 -0.059266
# 3  3.793345 -1.023980 -0.080558  0.420933 -0.327474  0.008592 -0.135636
# 4  0.452496 -0.613193  0.302875 -0.752532  1.707410 -0.130285 -0.821561
#
#       주구매요일  일별평균구매건수     거래개월수  ...  주구매_대분류_수정_6  주구매_대분류_수정_7  \
# 0  0.109631 -0.057297  0.017620  ...     -0.378716     -0.187997
# 1  0.109631  0.222706  1.176010  ...     -0.378716     -0.187997
# 2 -1.643370  0.277707  1.465608  ...     -0.378716     -0.187997
# 3  0.109631  0.674668  1.465608  ...     -0.378716     -0.187997
# 4  0.693965  0.679008  0.886413  ...     -0.378716     -0.187997
#
#    대분류_수정_평균금액최대_1  대분류_수정_평균금액최대_2  대분류_수정_평균금액최대_3  대분류_수정_평균금액최대_4  \
# 0         2.553208        -0.443004        -0.816155        -0.341822
# 1        -0.391664         2.257315        -0.816155        -0.341822
# 2        -0.391664         2.257315        -0.816155        -0.341822
# 3        -0.391664        -0.443004         1.225257        -0.341822
# 4        -0.391664         2.257315        -0.816155        -0.341822
#
#    대분류_수정_평균금액최대_5  대분류_수정_평균금액최대_6  대분류_수정_평균금액최대_7  주구매_중분류_cnt
# 0        -0.345596        -0.274521        -0.149122    -0.726970
# 1        -0.345596        -0.274521        -0.149122    -0.510078
# 2        -0.345596        -0.274521        -0.149122    -0.848408
# 3        -0.345596        -0.274521        -0.149122     1.523851
# 4        -0.345596        -0.274521        -0.149122    -0.833157
#
# [5 rows x 479 columns]

# %% [markdown]
# # 정답 데이터

# %%
target = train_target["target"]
target
# Out:
# 0        1.0
# 1        1.0
# 2        0.0
# 3        0.0
# 4        0.0
#         ...
# 14935    0.0
# 14936    0.0
# 14937    0.0
# 14938    1.0
# 14939    1.0
# Name: target, Length: 14940, dtype: float64

# %% [markdown]
# # cv 점수 확인해보기

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
cv = KFold(n_splits=5,shuffle=True, random_state=SEED)

# %%
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier(random_state=SEED)
scores = cross_val_score(model,train_ft,target,cv = cv ,scoring='f1_macro',n_jobs = -1)
np.mean(scores)
# Out:
# 0.6010876555456812

# %% [markdown]
# # 모델 학습

# %%
model = DecisionTreeClassifier(random_state=SEED)
model.fit(train_ft,target)
# Out:
# DecisionTreeClassifier(random_state=42)

# %% [markdown]
# # 테스트 데이터 예측

# %%
pred = model.predict(test_ft)
pred
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %% [markdown]
# # 평가를 위한 제출 파일 생성
# - 예측 결과를 target 컬럼에 넣어 csv 파일로 저장후에 제출한다.

# %%
submit
# Out:
#                ID  target
# 0          test_0     0.5
# 1          test_1     0.5
# 2          test_2     0.5
# 3          test_3     0.5
# 4          test_4     0.5
# ...           ...     ...
# 12220  test_12220     0.5
# 12221  test_12221     0.5
# 12222  test_12222     0.5
# 12223  test_12223     0.5
# 12224  test_12224     0.5
#
# [12225 rows x 2 columns]

# %%
submit["target"] = pred
submit
# Out:
#                ID  target
# 0          test_0     0.0
# 1          test_1     0.0
# 2          test_2     0.0
# 3          test_3     0.0
# 4          test_4     1.0
# ...           ...     ...
# 12220  test_12220     1.0
# 12221  test_12221     1.0
# 12222  test_12222     0.0
# 12223  test_12223     0.0
# 12224  test_12224     0.0
#
# [12225 rows x 2 columns]

# %% [markdown]
# - 예측 결과를 csv 파일로 저장하여 제출

# %%
submit.to_csv(f"{DATA_PATH}6_v2.0_DecisonTree.csv",index=False)

# %% [markdown]
# # optuna 로 파라미터 튜닝하기

# %%
# %pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-4.0.0-py3-none-any.whl.metadata (16 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.13.3-py3-none-any.whl.metadata (7.4 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (24.1)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.36)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.66.6)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.2)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.3.6-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (3.1.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.2)
# Downloading optuna-4.0.0-py3-none-any.whl (362 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 362.8/362.8 kB 7.5 MB/s eta 0:00:00
# Downloading alembic-1.13.3-py3-none-any.whl (233 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.2/233.2 kB 11.5 MB/s eta 0:00:00
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Downloading Mako-1.3.6-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 4.6 MB/s eta 0:00:00
# Installing collected packages: Mako, colorlog, alembic, optuna
# Successfully installed Mako-1.3.6 alembic-1.13.3 colorlog-6.9.0 optuna-4.0.0

# %%
import optuna

# %% [markdown]
# ## v2.0

# %%
def objective(trial):
    hp = {
        "criterion": trial.suggest_categorical("criterion", ["gini", "entropy"]),
        "max_depth": trial.suggest_int("max_depth", 5, 20),
        "min_samples_split": trial.suggest_int("min_samples_split", 2, 20),
        "min_samples_leaf": trial.suggest_int("min_samples_leaf", 1, 20),
        "max_features": trial.suggest_float("max_features", 0.6, 1.0, step=0.05)
    }
    cv = KFold(5, shuffle=True, random_state=SEED)
    model = DecisionTreeClassifier(**hp, random_state=SEED)
    score = cross_val_score(model, train_ft, target, cv=cv, scoring="f1_macro", n_jobs=-1).mean()
    return score

# %%
def objective(trial):
    hp = {
        "criterion": trial.suggest_categorical("criterion", ["gini", "entropy"]),
        "max_depth": trial.suggest_int("max_depth", 3, 15),
        "min_samples_split": trial.suggest_int("min_samples_split", 5, 20),
        "min_samples_leaf": trial.suggest_int("min_samples_leaf", 1, 10),
        "max_features": trial.suggest_float("max_features", 0.5, 1.0, step=0.05)
    }
    cv = KFold(5, shuffle=True, random_state=SEED)
    model = DecisionTreeClassifier(**hp, random_state=SEED)
    score = cross_val_score(model, train_ft, target, cv=cv, scoring="f1_macro", n_jobs=-1).mean()
    return score

# %%
sampler = optuna.samplers.TPESampler(seed=SEED) # 대체 모델 역할은 sampler 객체

# study 객체
study = optuna.create_study(
    direction="maximize",
    sampler = sampler
)

study.optimize(objective, n_trials=50)   # optimze 메서드에 콜백 함수(objective) 전달
# Out:
# [I 2024-11-01 07:16:46,044] A new study created in memory with name: no-name-4c0f451e-c731-4bb1-a6f1-0c9a888ffbd0
# [I 2024-11-01 07:16:52,711] Trial 0 finished with value: 0.6286692217541905 and parameters: {'criterion': 'entropy', 'max_depth': 16, 'min_samples_split': 13, 'min_samples_leaf': 4, 'max_features': 0.65}. Best is trial 0 with value: 0.6286692217541905.
# [I 2024-11-01 07:17:04,630] Trial 1 finished with value: 0.6301880329659696 and parameters: {'criterion': 'entropy', 'max_depth': 14, 'min_samples_split': 15, 'min_samples_leaf': 1, 'max_features': 1.0}. Best is trial 1 with value: 0.6301880329659696.
# [I 2024-11-01 07:17:08,951] Trial 2 finished with value: 0.6577122763612718 and parameters: {'criterion': 'gini', 'max_depth': 7, 'min_samples_split': 5, 'min_samples_leaf': 7, 'max_features': 0.8}. Best is trial 2 with value: 0.6577122763612718.
# [I 2024-11-01 07:17:18,044] Trial 3 finished with value: 0.6239749922016665 and parameters: {'criterion': 'gini', 'max_depth': 14, 'min_samples_split': 4, 'min_samples_leaf': 6, 'max_features': 0.75}. Best is trial 2 with value: 0.6577122763612718.
# [I 2024-11-01 07:17:22,337] Trial 4 finished with value: 0.653102987692727 and parameters: {'criterion': 'entropy', 'max_depth': 8, 'min_samples_split': 11, 'min_samples_leaf': 12, 'max_features': 0.6}. Best is trial 2 with value: 0.6577122763612718.
# [I 2024-11-01 07:17:26,784] Trial 5 finished with value: 0.6660752783825732 and parameters: {'criterion': 'gini', 'max_depth': 6, 'min_samples_split': 20, 'min_samples_leaf': 20, 'max_features': 0.95}. Best is trial 5 with value: 0.6660752783825732.
# [I 2024-11-01 07:17:36,228] Trial 6 finished with value: 0.6272610139160865 and parameters: {'criterion': 'gini', 'max_depth': 15, 'min_samples_split': 10, 'min_samples_leaf': 3, 'max_features': 0.8}. Best is trial 5 with value: 0.6660752783825732.
# [I 2024-11-01 07:17:41,931] Trial 7 finished with value: 0.6587580621188304 and parameters: {'criterion': 'entropy', 'max_depth': 9, 'min_samples_split': 14, 'min_samples_leaf': 7, 'max_features': 0.8}. Best is trial 5 with value: 0.6660752783825732.
# [I 2024-11-01 07:17:51,943] Trial 8 finished with value: 0.6303188174546677 and parameters: {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 16, 'min_samples_leaf': 19, 'max_features': 1.0}. Best is trial 5 with value: 0.6660752783825732.
# [I 2024-11-01 07:17:55,877] Trial 9 finished with value: 0.6670990992471454 and parameters: {'criterion': 'entropy', 'max_depth': 6, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': 0.7}. Best is trial 9 with value: 0.6670990992471454.
# [I 2024-11-01 07:18:02,950] Trial 10 finished with value: 0.6454629952959806 and parameters: {'criterion': 'entropy', 'max_depth': 11, 'min_samples_split': 7, 'min_samples_leaf': 13, 'max_features': 0.7}. Best is trial 9 with value: 0.6670990992471454.
# [I 2024-11-01 07:18:07,797] Trial 11 finished with value: 0.6638237309181572 and parameters: {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 20, 'min_samples_leaf': 20, 'max_features': 0.9}. Best is trial 9 with value: 0.6670990992471454.
# [I 2024-11-01 07:18:11,761] Trial 12 finished with value: 0.6637222520680481 and parameters: {'criterion': 'entropy', 'max_depth': 5, 'min_samples_split': 19, 'min_samples_leaf': 16, 'max_features': 0.9}. Best is trial 9 with value: 0.6670990992471454.
# [I 2024-11-01 07:18:19,350] Trial 13 finished with value: 0.6370564121076218 and parameters: {'criterion': 'gini', 'max_depth': 11, 'min_samples_split': 2, 'min_samples_leaf': 10, 'max_features': 0.9}. Best is trial 9 with value: 0.6670990992471454.
# [I 2024-11-01 07:18:24,010] Trial 14 finished with value: 0.6637675960522863 and parameters: {'criterion': 'gini', 'max_depth': 6, 'min_samples_split': 8, 'min_samples_leaf': 16, 'max_features': 0.65}. Best is trial 9 with value: 0.6670990992471454.
# [I 2024-11-01 07:18:30,345] Trial 15 finished with value: 0.6542483990159658 and parameters: {'criterion': 'entropy', 'max_depth': 9, 'min_samples_split': 17, 'min_samples_leaf': 17, 'max_features': 0.95}. Best is trial 9 with value: 0.6670990992471454.
# [I 2024-11-01 07:18:38,662] Trial 16 finished with value: 0.6471774163565046 and parameters: {'criterion': 'entropy', 'max_depth': 11, 'min_samples_split': 9, 'min_samples_leaf': 9, 'max_features': 0.7}. Best is trial 9 with value: 0.6670990992471454.
# [I 2024-11-01 07:18:47,054] Trial 17 finished with value: 0.6146482959459055 and parameters: {'criterion': 'gini', 'max_depth': 18, 'min_samples_split': 6, 'min_samples_leaf': 1, 'max_features': 0.85}. Best is trial 9 with value: 0.6670990992471454.
# [I 2024-11-01 07:18:53,365] Trial 18 finished with value: 0.6658700531686907 and parameters: {'criterion': 'entropy', 'max_depth': 7, 'min_samples_split': 12, 'min_samples_leaf': 13, 'max_features': 0.75}. Best is trial 9 with value: 0.6670990992471454.
# [I 2024-11-01 07:18:58,047] Trial 19 finished with value: 0.6535161339719833 and parameters: {'criterion': 'gini', 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 18, 'max_features': 0.6}. Best is trial 9 with value: 0.6670990992471454.
# [I 2024-11-01 07:19:05,015] Trial 20 finished with value: 0.645855533401898 and parameters: {'criterion': 'entropy', 'max_depth': 12, 'min_samples_split': 17, 'min_samples_leaf': 15, 'max_features': 0.85}. Best is trial 9 with value: 0.6670990992471454.
# [I 2024-11-01 07:19:12,218] Trial 21 finished with value: 0.6658700531686907 and parameters: {'criterion': 'entropy', 'max_depth': 7, 'min_samples_split': 12, 'min_samples_leaf': 13, 'max_features': 0.75}. Best is trial 9 with value: 0.6670990992471454.
# [I 2024-11-01 07:19:16,735] Trial 22 finished with value: 0.6653542945644826 and parameters: {'criterion': 'entropy', 'max_depth': 7, 'min_samples_split': 18, 'min_samples_leaf': 14, 'max_features': 0.75}. Best is trial 9 with value: 0.6670990992471454.
# [I 2024-11-01 07:19:20,124] Trial 23 finished with value: 0.6742165742275343 and parameters: {'criterion': 'entropy', 'max_depth': 5, 'min_samples_split': 10, 'min_samples_leaf': 11, 'max_features': 0.7}. Best is trial 23 with value: 0.6742165742275343.
# [I 2024-11-01 07:19:24,823] Trial 24 finished with value: 0.6742165742275343 and parameters: {'criterion': 'entropy', 'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 11, 'max_features': 0.7}. Best is trial 23 with value: 0.6742165742275343.
# [I 2024-11-01 07:19:29,654] Trial 25 finished with value: 0.670485096515941 and parameters: {'criterion': 'entropy', 'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 9, 'max_features': 0.7}. Best is trial 23 with value: 0.6742165742275343.
# [I 2024-11-01 07:19:32,990] Trial 26 finished with value: 0.6614613196278083 and parameters: {'criterion': 'entropy', 'max_depth': 5, 'min_samples_split': 3, 'min_samples_leaf': 9, 'max_features': 0.65}. Best is trial 23 with value: 0.6742165742275343.
# [I 2024-11-01 07:19:37,721] Trial 27 finished with value: 0.6615660859522239 and parameters: {'criterion': 'entropy', 'max_depth': 8, 'min_samples_split': 7, 'min_samples_leaf': 11, 'max_features': 0.7}. Best is trial 23 with value: 0.6742165742275343.
# [I 2024-11-01 07:19:42,866] Trial 28 finished with value: 0.6614613196278083 and parameters: {'criterion': 'entropy', 'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 9, 'max_features': 0.65}. Best is trial 23 with value: 0.6742165742275343.
# [I 2024-11-01 07:19:49,732] Trial 29 finished with value: 0.6113988780203994 and parameters: {'criterion': 'entropy', 'max_depth': 17, 'min_samples_split': 9, 'min_samples_leaf': 5, 'max_features': 0.6}. Best is trial 23 with value: 0.6742165742275343.
# [I 2024-11-01 07:19:54,554] Trial 30 finished with value: 0.6615660859522239 and parameters: {'criterion': 'entropy', 'max_depth': 8, 'min_samples_split': 6, 'min_samples_leaf': 11, 'max_features': 0.7}. Best is trial 23 with value: 0.6742165742275343.
# [I 2024-11-01 07:20:00,815] Trial 31 finished with value: 0.6670916555124187 and parameters: {'criterion': 'entropy', 'max_depth': 6, 'min_samples_split': 4, 'min_samples_leaf': 4, 'max_features': 0.7}. Best is trial 23 with value: 0.6742165742275343.
# [I 2024-11-01 07:20:04,675] Trial 32 finished with value: 0.6691925363304113 and parameters: {'criterion': 'entropy', 'max_depth': 6, 'min_samples_split': 5, 'min_samples_leaf': 8, 'max_features': 0.65}. Best is trial 23 with value: 0.6742165742275343.
# [I 2024-11-01 07:20:07,988] Trial 33 finished with value: 0.6614613196278083 and parameters: {'criterion': 'entropy', 'max_depth': 5, 'min_samples_split': 3, 'min_samples_leaf': 8, 'max_features': 0.65}. Best is trial 23 with value: 0.6742165742275343.
# [I 2024-11-01 07:20:12,533] Trial 34 finished with value: 0.6653455157447559 and parameters: {'criterion': 'entropy', 'max_depth': 6, 'min_samples_split': 6, 'min_samples_leaf': 7, 'max_features': 0.75}. Best is trial 23 with value: 0.6742165742275343.
# [I 2024-11-01 07:20:19,538] Trial 35 finished with value: 0.6491161395098288 and parameters: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_split': 5, 'min_samples_leaf': 10, 'max_features': 0.6}. Best is trial 23 with value: 0.6742165742275343.
# [I 2024-11-01 07:20:23,627] Trial 36 finished with value: 0.6625800250227568 and parameters: {'criterion': 'entropy', 'max_depth': 7, 'min_samples_split': 3, 'min_samples_leaf': 12, 'max_features': 0.65}. Best is trial 23 with value: 0.6742165742275343.
# [I 2024-11-01 07:20:28,993] Trial 37 finished with value: 0.6658286021292662 and parameters: {'criterion': 'entropy', 'max_depth': 8, 'min_samples_split': 8, 'min_samples_leaf': 6, 'max_features': 0.75}. Best is trial 23 with value: 0.6742165742275343.
# [I 2024-11-01 07:20:34,851] Trial 38 finished with value: 0.6534547643409153 and parameters: {'criterion': 'entropy', 'max_depth': 6, 'min_samples_split': 10, 'min_samples_leaf': 8, 'max_features': 0.6}. Best is trial 23 with value: 0.6742165742275343.
# [I 2024-11-01 07:20:40,980] Trial 39 finished with value: 0.6345361135113408 and parameters: {'criterion': 'entropy', 'max_depth': 13, 'min_samples_split': 14, 'min_samples_leaf': 12, 'max_features': 0.7}. Best is trial 23 with value: 0.6742165742275343.
# [I 2024-11-01 07:20:44,916] Trial 40 finished with value: 0.6602786429685511 and parameters: {'criterion': 'entropy', 'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 8, 'max_features': 0.8}. Best is trial 23 with value: 0.6742165742275343.
# [I 2024-11-01 07:20:51,295] Trial 41 finished with value: 0.6670916555124187 and parameters: {'criterion': 'entropy', 'max_depth': 6, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': 0.7}. Best is trial 23 with value: 0.6742165742275343.
# [I 2024-11-01 07:20:55,516] Trial 42 finished with value: 0.6610679156776033 and parameters: {'criterion': 'entropy', 'max_depth': 7, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 0.65}. Best is trial 23 with value: 0.6742165742275343.
# [I 2024-11-01 07:20:59,247] Trial 43 finished with value: 0.6679548083868566 and parameters: {'criterion': 'entropy', 'max_depth': 6, 'min_samples_split': 7, 'min_samples_leaf': 6, 'max_features': 0.65}. Best is trial 23 with value: 0.6742165742275343.
# [I 2024-11-01 07:21:03,634] Trial 44 finished with value: 0.6613934442272639 and parameters: {'criterion': 'entropy', 'max_depth': 5, 'min_samples_split': 7, 'min_samples_leaf': 6, 'max_features': 0.65}. Best is trial 23 with value: 0.6742165742275343.
# [I 2024-11-01 07:21:09,814] Trial 45 finished with value: 0.6497364305561398 and parameters: {'criterion': 'entropy', 'max_depth': 8, 'min_samples_split': 8, 'min_samples_leaf': 10, 'max_features': 0.6}. Best is trial 23 with value: 0.6742165742275343.
# [I 2024-11-01 07:21:13,738] Trial 46 finished with value: 0.6653468710455963 and parameters: {'criterion': 'entropy', 'max_depth': 6, 'min_samples_split': 10, 'min_samples_leaf': 5, 'max_features': 0.7}. Best is trial 23 with value: 0.6742165742275343.
# [I 2024-11-01 07:21:17,016] Trial 47 finished with value: 0.6637435209098881 and parameters: {'criterion': 'entropy', 'max_depth': 5, 'min_samples_split': 6, 'min_samples_leaf': 11, 'max_features': 0.65}. Best is trial 23 with value: 0.6742165742275343.
# [I 2024-11-01 07:21:24,035] Trial 48 finished with value: 0.6599942351146978 and parameters: {'criterion': 'entropy', 'max_depth': 7, 'min_samples_split': 2, 'min_samples_leaf': 6, 'max_features': 0.75}. Best is trial 23 with value: 0.6742165742275343.
# [I 2024-11-01 07:21:30,182] Trial 49 finished with value: 0.6210692314792646 and parameters: {'criterion': 'gini', 'max_depth': 15, 'min_samples_split': 4, 'min_samples_leaf': 7, 'max_features': 0.7}. Best is trial 23 with value: 0.6742165742275343.

# %%
study.best_trial.params  # 최적의 하이퍼파라미터
# Out:
# {'criterion': 'entropy',
#  'max_depth': 5,
#  'min_samples_split': 10,
#  'min_samples_leaf': 11,
#  'max_features': 0.7}

# %%
study.best_value    # 최적의 하이퍼파라미터의 검증 점수
# Out:
# 0.6742165742275343

# %%
# 모델 학습
model = DecisionTreeClassifier(random_state=SEED, **study.best_params)
model.fit(train_ft,target)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=5, max_features=0.7,
#                        min_samples_leaf=11, min_samples_split=10,
#                        random_state=42)

# %%
# 테스트 데이터 예측
pred = model.predict(test_ft)
pred
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
# 예측 결과 저장
submit["target"] = pred
submit.to_csv(f"{DATA_PATH}6_v2.0_DecisonTree.csv",index=False)

# %% [markdown]
# ## v2.1

# %% [markdown]
# - 1차 하이퍼파라미터 수정

# %%
def objective(trial):
    hp = {
        "criterion": trial.suggest_categorical("criterion", ["gini", "entropy"]),
        "max_depth": trial.suggest_int("max_depth", 3, 15),
        "min_samples_split": trial.suggest_int("min_samples_split", 5, 20),
        "min_samples_leaf": trial.suggest_int("min_samples_leaf", 1, 10),
        "max_features": trial.suggest_float("max_features", 0.5, 1.0, step=0.05)
    }
    cv = KFold(5, shuffle=True, random_state=SEED)
    model = DecisionTreeClassifier(**hp, random_state=SEED)
    score = cross_val_score(model, train_ft, target, cv=cv, scoring="f1_macro", n_jobs=-1).mean()
    return score

# %%
sampler = optuna.samplers.TPESampler(seed=SEED) # 대체 모델 역할은 sampler 객체

# study 객체
study = optuna.create_study(
    direction="maximize",
    sampler = sampler
)

study.optimize(objective, n_trials=50)   # optimze 메서드에 콜백 함수(objective) 전달
# Out:
# [I 2024-11-01 07:27:42,304] A new study created in memory with name: no-name-8ddd735a-86c3-4834-a15b-063dd9fbdaf3
# [I 2024-11-01 07:27:55,758] Trial 0 finished with value: 0.638145934912522 and parameters: {'criterion': 'entropy', 'max_depth': 12, 'min_samples_split': 14, 'min_samples_leaf': 2, 'max_features': 0
and parameters: {'criterion': 'entropy', 'max_depth': 6, 'min_samples_split': 10, 'min_samples_leaf': 7, 'max_features': 0.55}. Best is trial 25 with value: 0.6699855238056662.
# [I 2024-11-01 07:32:28,848] Trial 42 finished with value: 0.6615201705242088 and parameters: {'criterion': 'entropy', 'max_depth': 7, 'min_samples_split': 8, 'min_samples_leaf': 7, 'max_features': 0.6}. Best is trial 25 with value: 0.6699855238056662.
# [I 2024-11-01 07:32:32,066] Trial 43 finished with value: 0.6602417393996118 and parameters: {'criterion': 'entropy', 'max_depth': 6, 'min_samples_split': 8, 'min_samples_leaf': 6, 'max_features': 0.5}. Best is trial 25 with value: 0.6699855238056662.
# [I 2024-11-01 07:32:35,726] Trial 44 finished with value: 0.6627696709481802 and parameters: {'criterion': 'entropy', 'max_depth': 7, 'min_samples_split': 5, 'min_samples_leaf': 8, 'max_features': 0.55}. Best is trial 25 with value: 0.6699855238056662.
# [I 2024-11-01 07:32:39,706] Trial 45 finished with value: 0.6614345358043034 and parameters: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_split': 9, 'min_samples_leaf': 7, 'max_features': 0.7}. Best is trial 25 with value: 0.6699855238056662.
# [I 2024-11-01 07:32:46,230] Trial 46 finished with value: 0.6523037907289803 and parameters: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_split': 7, 'min_samples_leaf': 3, 'max_features': 0.6}. Best is trial 25 with value: 0.6699855238056662.
# [I 2024-11-01 07:32:49,908] Trial 47 finished with value: 0.6692234157736427 and parameters: {'criterion': 'entropy', 'max_depth': 6, 'min_samples_split': 6, 'min_samples_leaf': 5, 'max_features': 0.65}. Best is trial 25 with value: 0.6699855238056662.
# [I 2024-11-01 07:32:52,593] Trial 48 finished with value: 0.6544649822204824 and parameters: {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 11, 'min_samples_leaf': 6, 'max_features': 0.5}. Best is trial 25 with value: 0.6699855238056662.
# [I 2024-11-01 07:32:58,030] Trial 49 finished with value: 0.6599567302800197 and parameters: {'criterion': 'entropy', 'max_depth': 7, 'min_samples_split': 8, 'min_samples_leaf': 7, 'max_features': 0.55}. Best is trial 25 with value: 0.6699855238056662.

# %%
study.best_trial.params  # 최적의 하이퍼파라미터
# Out:
# {'criterion': 'entropy',
#  'max_depth': 6,
#  'min_samples_split': 9,
#  'min_samples_leaf': 9,
#  'max_features': 0.55}

# %%
study.best_value    # 최적의 하이퍼파라미터의 검증 점수
# Out:
# 0.6699855238056662

# %%
# 모델 학습
model = DecisionTreeClassifier(random_state=SEED, **study.best_params)
model.fit(train_ft,target)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=6, max_features=0.55,
#                        min_samples_leaf=9, min_samples_split=9,
#                        random_state=42)

# %%
# 테스트 데이터 예측
pred = model.predict(test_ft)
pred
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
# 예측 결과 저장
submit["target"] = pred
submit.to_csv(f"{DATA_PATH}6_v2.1_DecisonTree.csv",index=False)

# %% [markdown]
# ## v2.2

# %% [markdown]
# - 2차 하이퍼파라미터 수정 > 지니계수

# %%
def objective(trial):
    hp = {
        "criterion": trial.suggest_categorical("criterion", ["gini"]),
        "max_depth": trial.suggest_int("max_depth", 3, 15),
        "min_samples_split": trial.suggest_int("min_samples_split", 5, 20),
        "min_samples_leaf": trial.suggest_int("min_samples_leaf", 1, 10),
        "max_features": trial.suggest_float("max_features", 0.5, 1.0, step=0.05)
    }
    cv = KFold(5, shuffle=True, random_state=SEED)
    model = DecisionTreeClassifier(**hp, random_state=SEED)
    score = cross_val_score(model, train_ft, target, cv=cv, scoring="f1_macro", n_jobs=-1).mean()
    return score

# %%
sampler = optuna.samplers.TPESampler(seed=SEED) # 대체 모델 역할은 sampler 객체

# study 객체
study = optuna.create_study(
    direction="maximize",
    sampler = sampler
)

study.optimize(objective, n_trials=50)   # optimze 메서드에 콜백 함수(objective) 전달
# Out:
# [I 2024-11-01 08:50:05,710] A new study created in memory with name: no-name-0584e957-a8f7-49fd-bd17-784192a540cf
# [I 2024-11-01 08:50:11,445] Trial 0 finished with value: 0.6591900374567821 and parameters: {'criterion': 'gini', 'max_depth': 7, 'min_samples_split': 20, 'min_samples_leaf': 8, 'max_features': 0.8}. Best is trial 0 with value: 0.6591900374567821.
# [I 2024-11-01 08:50:15,177] Trial 1 finished with value: 0.6663940794593122 and parameters: {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 7, 'min_samples_leaf': 1, 'max_features': 0.95}. Best is trial 1 with value: 0.6663940794593122.
# [I 2024-11-01 08:50:23,730] Trial 2 finished with value: 0.6404990819798537 and parameters: {'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 16, 'min_samples_leaf': 1, 'max_features': 1.0}. Best is trial 1 with value: 0.6663940794593122.
# [I 2024-11-01 08:50:29,894] Trial 3 finished with value: 0.6413421537719733 and parameters: {'criterion': 'gini', 'max_depth': 13, 'min_samples_split': 8, 'min_samples_leaf': 2, 'max_features': 0.6}. Best is trial 1 with value: 0.6663940794593122.
# [I 2024-11-01 08:50:33,291] Trial 4 finished with value: 0.6586155460620661 and parameters: {'criterion': 'gini', 'max_depth': 6, 'min_samples_split': 13, 'min_samples_leaf': 5, 'max_features': 0.65}. Best is trial 1 with value: 0.6663940794593122.
# [I 2024-11-01 08:50:40,035] Trial 5 finished with value: 0.646365281029741 and parameters: {'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 7, 'min_samples_leaf': 3, 'max_features': 0.7}. Best is trial 1 with value: 0.6663940794593122.
# [I 2024-11-01 08:50:45,353] Trial 6 finished with value: 0.6566570397650144 and parameters: {'criterion': 'gini', 'max_depth': 8, 'min_samples_split': 17, 'min_samples_leaf': 2, 'max_features': 0.75}. Best is trial 1 with value: 0.6663940794593122.
# [I 2024-11-01 08:50:49,645] Trial 7 finished with value: 0.6429349104398547 and parameters: {'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 5, 'min_samples_leaf': 7, 'max_features': 0.55}. Best is trial 1 with value: 0.6663940794593122.
# [I 2024-11-01 08:50:52,542] Trial 8 finished with value: 0.6268784030567804 and parameters: {'criterion': 'gini', 'max_depth': 3, 'min_samples_split': 20, 'min_samples_leaf': 10, 'max_features': 0.9}. Best is trial 1 with value: 0.6663940794593122.
# [I 2024-11-01 08:50:58,664] Trial 9 finished with value: 0.6648385707592376 and parameters: {'criterion': 'gini', 'max_depth': 6, 'min_samples_split': 6, 'min_samples_leaf': 7, 'max_features': 0.7}. Best is trial 1 with value: 0.6663940794593122.
# [I 2024-11-01 08:51:01,462] Trial 10 finished with value: 0.6268784030567804 and parameters: {'criterion': 'gini', 'max_depth': 3, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_features': 1.0}. Best is trial 1 with value: 0.6663940794593122.
# [I 2024-11-01 08:51:05,025] Trial 11 finished with value: 0.6574645669220346 and parameters: {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 5, 'min_samples_leaf': 7, 'max_features': 0.8500000000000001}. Best is trial 1 with value: 0.6663940794593122.
# [I 2024-11-01 08:51:07,750] Trial 12 finished with value: 0.6548713146430455 and parameters: {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 10, 'min_samples_leaf': 9, 'max_features': 0.5}. Best is trial 1 with value: 0.6663940794593122.
# [I 2024-11-01 08:51:18,814] Trial 13 finished with value: 0.6237439977068997 and parameters: {'criterion': 'gini', 'max_depth': 13, 'min_samples_split': 8, 'min_samples_leaf': 5, 'max_features': 0.9}. Best is trial 1 with value: 0.6663940794593122.
# [I 2024-11-01 08:51:23,684] Trial 14 finished with value: 0.666672802150346 and parameters: {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 12, 'min_samples_leaf': 6, 'max_features': 0.7}. Best is trial 14 with value: 0.666672802150346.
# [I 2024-11-01 08:51:30,275] Trial 15 finished with value: 0.6583209634523044 and parameters: {'criterion': 'gini', 'max_depth': 4, 'min_samples_split': 13, 'min_samples_leaf': 4, 'max_features': 0.8}. Best is trial 14 with value: 0.666672802150346.
# [I 2024-11-01 08:51:37,258] Trial 16 finished with value: 0.6524790142903972 and parameters: {'criterion': 'gini', 'max_depth': 8, 'min_samples_split': 11, 'min_samples_leaf': 6, 'max_features': 0.95}. Best is trial 14 with value: 0.666672802150346.
# [I 2024-11-01 08:51:47,157] Trial 17 finished with value: 0.6221434528820736 and parameters: {'criterion': 'gini', 'max_depth': 15, 'min_samples_split': 15, 'min_samples_leaf': 1, 'max_features': 0.65}. Best is trial 14 with value: 0.666672802150346.
# [I 2024-11-01 08:51:52,509] Trial 18 finished with value: 0.6671204548182056 and parameters: {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 11, 'min_samples_leaf': 4, 'max_features': 0.8}. Best is trial 18 with value: 0.6671204548182056.
# [I 2024-11-01 08:51:58,637] Trial 19 finished with value: 0.6552204529004644 and parameters: {'criterion': 'gini', 'max_depth': 8, 'min_samples_split': 11, 'min_samples_leaf': 4, 'max_features': 0.75}. Best is trial 18 with value: 0.6671204548182056.
# [I 2024-11-01 08:52:04,321] Trial 20 finished with value: 0.6233911426809773 and parameters: {'criterion': 'gini', 'max_depth': 3, 'min_samples_split': 14, 'min_samples_leaf': 6, 'max_features': 0.8}. Best is trial 18 with value: 0.6671204548182056.
# [I 2024-11-01 08:52:09,445] Trial 21 finished with value: 0.6637387056879911 and parameters: {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 9, 'min_samples_leaf': 3, 'max_features': 0.9}. Best is trial 18 with value: 0.6671204548182056.
# [I 2024-11-01 08:52:16,189] Trial 22 finished with value: 0.6677739286713253 and parameters: {'criterion': 'gini', 'max_depth': 6, 'min_samples_split': 12, 'min_samples_leaf': 3, 'max_features': 0.8500000000000001}. Best is trial 22 with value: 0.6677739286713253.
# [I 2024-11-01 08:52:26,185] Trial 23 finished with value: 0.6620088274584005 and parameters: {'criterion': 'gini', 'max_depth': 7, 'min_samples_split': 12, 'min_samples_leaf': 3, 'max_features': 0.8500000000000001}. Best is trial 22 with value: 0.6677739286713253.
# [I 2024-11-01 08:52:30,471] Trial 24 finished with value: 0.663880202653296 and parameters: {'criterion': 'gini', 'max_depth': 4, 'min_samples_split': 12, 'min_samples_leaf': 5, 'max_features': 0.7}. Best is trial 22 with value: 0.6677739286713253.
# [I 2024-11-01 08:52:41,320] Trial 25 finished with value: 0.6671593457576112 and parameters: {'criterion': 'gini', 'max_depth': 6, 'min_samples_split': 14, 'min_samples_leaf': 4, 'max_features': 0.8500000000000001}. Best is trial 22 with value: 0.6677739286713253.
# [I 2024-11-01 08:52:46,517] Trial 26 finished with value: 0.6628027742379362 and parameters: {'criterion': 'gini', 'max_depth': 7, 'min_samples_split': 18, 'min_samples_leaf': 2, 'max_features': 0.8500000000000001}. Best is trial 22 with value: 0.6677739286713253.
# [I 2024-11-01 08:52:51,313] Trial 27 finished with value: 0.6647828319047157 and parameters: {'criterion': 'gini', 'max_depth': 6, 'min_samples_split': 14, 'min_samples_leaf': 4, 'max_features': 0.75}. Best is trial 22 with value: 0.6677739286713253.
# [I 2024-11-01 08:53:01,434] Trial 28 finished with value: 0.6522835890001364 and parameters: {'criterion': 'gini', 'max_depth': 9, 'min_samples_split': 15, 'min_samples_leaf': 3, 'max_features': 0.8500000000000001}. Best is trial 22 with value: 0.6677739286713253.
# [I 2024-11-01 08:53:06,315] Trial 29 finished with value: 0.6583209634523044 and parameters: {'criterion': 'gini', 'max_depth': 4, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_features': 0.8}. Best is trial 22 with value: 0.6677739286713253.
# [I 2024-11-01 08:53:17,585] Trial 30 finished with value: 0.6606610582840852 and parameters: {'criterion': 'gini', 'max_depth': 7, 'min_samples_split': 14, 'min_samples_leaf': 5, 'max_features': 0.8}. Best is trial 22 with value: 0.6677739286713253.
# [I 2024-11-01 08:53:23,009] Trial 31 finished with value: 0.6612771927846823 and parameters: {'criterion': 'gini', 'max_depth': 6, 'min_samples_split': 11, 'min_samples_leaf': 6, 'max_features': 0.8}. Best is trial 22 with value: 0.6677739286713253.
# [I 2024-11-01 08:53:31,466] Trial 32 finished with value: 0.6665986838101436 and parameters: {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 12, 'min_samples_leaf': 3, 'max_features': 0.95}. Best is trial 22 with value: 0.6677739286713253.
# [I 2024-11-01 08:53:35,352] Trial 33 finished with value: 0.6592944937354606 and parameters: {'criterion': 'gini', 'max_depth': 4, 'min_samples_split': 13, 'min_samples_leaf': 8, 'max_features': 0.65}. Best is trial 22 with value: 0.6677739286713253.
# [I 2024-11-01 08:53:40,550] Trial 34 finished with value: 0.6652693825621645 and parameters: {'criterion': 'gini', 'max_depth': 6, 'min_samples_split': 16, 'min_samples_leaf': 2, 'max_features': 0.75}. Best is trial 22 with value: 0.6677739286713253.
# [I 2024-11-01 08:53:49,768] Trial 35 finished with value: 0.6512685264978494 and parameters: {'criterion': 'gini', 'max_depth': 9, 'min_samples_split': 9, 'min_samples_leaf': 5, 'max_features': 0.9}. Best is trial 22 with value: 0.6677739286713253.
# [I 2024-11-01 08:53:56,222] Trial 36 finished with value: 0.6342572487215936 and parameters: {'criterion': 'gini', 'max_depth': 12, 'min_samples_split': 15, 'min_samples_leaf': 6, 'max_features': 0.8500000000000001}. Best is trial 22 with value: 0.6677739286713253.
# [I 2024-11-01 08:54:00,915] Trial 37 finished with value: 0.6606169133760231 and parameters: {'criterion': 'gini', 'max_depth': 6, 'min_samples_split': 11, 'min_samples_leaf': 4, 'max_features': 0.6}. Best is trial 22 with value: 0.6677739286713253.
# [I 2024-11-01 08:54:06,623] Trial 38 finished with value: 0.6568745188915897 and parameters: {'criterion': 'gini', 'max_depth': 8, 'min_samples_split': 13, 'min_samples_leaf': 1, 'max_features': 0.7}. Best is trial 22 with value: 0.6677739286713253.
# [I 2024-11-01 08:54:10,700] Trial 39 finished with value: 0.6641171430170904 and parameters: {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 17, 'min_samples_leaf': 8, 'max_features': 0.95}. Best is trial 22 with value: 0.6677739286713253.
# [I 2024-11-01 08:54:14,825] Trial 40 finished with value: 0.659778042129205 and parameters: {'criterion': 'gini', 'max_depth': 7, 'min_samples_split': 9, 'min_samples_leaf': 3, 'max_features': 0.65}. Best is trial 22 with value: 0.6677739286713253.
# [I 2024-11-01 08:54:20,531] Trial 41 finished with value: 0.6593250430009775 and parameters: {'criterion': 'gini', 'max_depth': 4, 'min_samples_split': 12, 'min_samples_leaf': 3, 'max_features': 1.0}. Best is trial 22 with value: 0.6677739286713253.
# [I 2024-11-01 08:54:24,278] Trial 42 finished with value: 0.6664533570114904 and parameters: {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 12, 'min_samples_leaf': 2, 'max_features': 0.95}. Best is trial 22 with value: 0.6677739286713253.
# [I 2024-11-01 08:54:27,982] Trial 43 finished with value: 0.6637387056879911 and parameters: {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 14, 'min_samples_leaf': 3, 'max_features': 0.9}. Best is trial 22 with value: 0.6677739286713253.
# [I 2024-11-01 08:54:31,123] Trial 44 finished with value: 0.6254568748030079 and parameters: {'criterion': 'gini', 'max_depth': 3, 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_features': 0.95}. Best is trial 22 with value: 0.6677739286713253.
# [I 2024-11-01 08:54:37,800] Trial 45 finished with value: 0.6666647400685832 and parameters: {'criterion': 'gini', 'max_depth': 6, 'min_samples_split': 12, 'min_samples_leaf': 5, 'max_features': 0.8500000000000001}. Best is trial 22 with value: 0.6677739286713253.
# [I 2024-11-01 08:54:42,111] Trial 46 finished with value: 0.6608625403058103 and parameters: {'criterion': 'gini', 'max_depth': 7, 'min_samples_split': 13, 'min_samples_leaf': 5, 'max_features': 0.8}. Best is trial 22 with value: 0.6677739286713253.
# [I 2024-11-01 08:54:48,819] Trial 47 finished with value: 0.6442078663433001 and parameters: {'criterion': 'gini', 'max_depth': 11, 'min_samples_split': 11, 'min_samples_leaf': 7, 'max_features': 0.8500000000000001}. Best is trial 22 with value: 0.6677739286713253.
# [I 2024-11-01 08:54:54,762] Trial 48 finished with value: 0.6634007269037479 and parameters: {'criterion': 'gini', 'max_depth': 6, 'min_samples_split': 8, 'min_samples_leaf': 4, 'max_features': 0.75}. Best is trial 22 with value: 0.6677739286713253.
# [I 2024-11-01 08:54:59,564] Trial 49 finished with value: 0.6541581191803767 and parameters: {'criterion': 'gini', 'max_depth': 9, 'min_samples_split': 13, 'min_samples_leaf': 5, 'max_features': 0.7}. Best is trial 22 with value: 0.6677739286713253.

# %%
study.best_trial.params  # 최적의 하이퍼파라미터
# Out:
# {'criterion': 'gini',
#  'max_depth': 6,
#  'min_samples_split': 12,
#  'min_samples_leaf': 3,
#  'max_features': 0.8500000000000001}

# %%
study.best_value    # 최적의 하이퍼파라미터의 검증 점수
# Out:
# 0.6677739286713253

# %%
# 모델 학습
model = DecisionTreeClassifier(random_state=SEED, **study.best_params)
model.fit(train_ft,target)
# Out:
# DecisionTreeClassifier(max_depth=6, max_features=0.8500000000000001,
#                        min_samples_leaf=3, min_samples_split=12,
#                        random_state=42)

# %%
# 테스트 데이터 예측
pred = model.predict(test_ft)
pred
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
#
and parameters: {'criterion': 'entropy', 'max_depth': 9, 'min_samples_split': 16, 'min_samples_leaf': 7, 'max_features': 1.0}. Best is trial 33 with value: 0.6713718072695801.
# [I 2024-11-01 08:58:43,400] Trial 35 finished with value: 0.6717780633636928 and parameters: {'criterion': 'entropy', 'max_depth': 6, 'min_samples_split': 15, 'min_samples_leaf': 4, 'max_features': 0.95}. Best is trial 35 with value: 0.6717780633636928.
# [I 2024-11-01 08:58:51,370] Trial 36 finished with value: 0.6598733107929773 and parameters: {'criterion': 'entropy', 'max_depth': 7, 'min_samples_split': 15, 'min_samples_leaf': 4, 'max_features': 0.95}. Best is trial 35 with value: 0.6717780633636928.
# [I 2024-11-01 08:58:57,506] Trial 37 finished with value: 0.6544357325208834 and parameters: {'criterion': 'entropy', 'max_depth': 8, 'min_samples_split': 17, 'min_samples_leaf': 5, 'max_features': 0.95}. Best is trial 35 with value: 0.6717780633636928.
# [I 2024-11-01 08:59:03,310] Trial 38 finished with value: 0.6692166233306799 and parameters: {'criterion': 'entropy', 'max_depth': 6, 'min_samples_split': 19, 'min_samples_leaf': 6, 'max_features': 1.0}. Best is trial 35 with value: 0.6717780633636928.
# [I 2024-11-01 08:59:08,969] Trial 39 finished with value: 0.6609077529210665 and parameters: {'criterion': 'entropy', 'max_depth': 7, 'min_samples_split': 17, 'min_samples_leaf': 4, 'max_features': 0.6}. Best is trial 35 with value: 0.6717780633636928.
# [I 2024-11-01 08:59:14,926] Trial 40 finished with value: 0.6501528279305361 and parameters: {'criterion': 'entropy', 'max_depth': 11, 'min_samples_split': 15, 'min_samples_leaf': 5, 'max_features': 0.7}. Best is trial 35 with value: 0.6717780633636928.
# [I 2024-11-01 08:59:21,482] Trial 41 finished with value: 0.6693829255172117 and parameters: {'criterion': 'entropy', 'max_depth': 6, 'min_samples_split': 20, 'min_samples_leaf': 6, 'max_features': 1.0}. Best is trial 35 with value: 0.6717780633636928.
# [I 2024-11-01 08:59:27,510] Trial 42 finished with value: 0.6697025906424704 and parameters: {'criterion': 'entropy', 'max_depth': 6, 'min_samples_split': 20, 'min_samples_leaf': 7, 'max_features': 1.0}. Best is trial 35 with value: 0.6717780633636928.
# [I 2024-11-01 08:59:33,624] Trial 43 finished with value: 0.6555757589235691 and parameters: {'criterion': 'entropy', 'max_depth': 8, 'min_samples_split': 18, 'min_samples_leaf': 7, 'max_features': 0.95}. Best is trial 35 with value: 0.6717780633636928.
# [I 2024-11-01 08:59:40,014] Trial 44 finished with value: 0.6646425992470038 and parameters: {'criterion': 'entropy', 'max_depth': 5, 'min_samples_split': 14, 'min_samples_leaf': 9, 'max_features': 0.9}. Best is trial 35 with value: 0.6717780633636928.
# [I 2024-11-01 08:59:44,698] Trial 45 finished with value: 0.6650982820468204 and parameters: {'criterion': 'entropy', 'max_depth': 6, 'min_samples_split': 12, 'min_samples_leaf': 7, 'max_features': 0.8}. Best is trial 35 with value: 0.6717780633636928.
# [I 2024-11-01 08:59:58,785] Trial 46 finished with value: 0.6317842975148469 and parameters: {'criterion': 'entropy', 'max_depth': 14, 'min_samples_split': 16, 'min_samples_leaf': 5, 'max_features': 0.95}. Best is trial 35 with value: 0.6717780633636928.
# [I 2024-11-01 09:00:04,034] Trial 47 finished with value: 0.6617794381045055 and parameters: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_split': 19, 'min_samples_leaf': 4, 'max_features': 1.0}. Best is trial 35 with value: 0.6717780633636928.
# [I 2024-11-01 09:00:14,065] Trial 48 finished with value: 0.6561525907133723 and parameters: {'criterion': 'entropy', 'max_depth': 9, 'min_samples_split': 16, 'min_samples_leaf': 6, 'max_features': 0.7}. Best is trial 35 with value: 0.6717780633636928.
# [I 2024-11-01 09:00:21,796] Trial 49 finished with value: 0.6629021341362888 and parameters: {'criterion': 'entropy', 'max_depth': 7, 'min_samples_split': 14, 'min_samples_leaf': 3, 'max_features': 0.9}. Best is trial 35 with value: 0.6717780633636928.

# %%
study.best_trial.params  # 최적의 하이퍼파라미터
# Out:
# {'criterion': 'entropy',
#  'max_depth': 6,
#  'min_samples_split': 15,
#  'min_samples_leaf': 4,
#  'max_features': 0.95}

# %%
study.best_value    # 최적의 하이퍼파라미터의 검증 점수
# Out:
# 0.6717780633636928

# %%
# 모델 학습
model = DecisionTreeClassifier(random_state=SEED, **study.best_params)
model.fit(train_ft,target)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=6, max_features=0.95,
#                        min_samples_leaf=4, min_samples_split=15,
#                        random_state=42)

# %%
# 테스트 데이터 예측
pred = model.predict(test_ft)
pred
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
# 예측 결과 저장
submit["target"] = pred
submit.to_csv(f"{DATA_PATH}6_v2.3_DecisonTree.csv",index=False)

# %% [markdown]
# ## 심심해서한 LGBM

# %% [markdown]
# - LGBM도 궁금한데

# %%
from lightgbm import LGBMClassifier

def objective(trial):
    hp = {
        "num_leaves": trial.suggest_int("num_leaves", 20, 150),               # 리프 노드의 수
        "max_depth": trial.suggest_int("max_depth", 3, 15),                   # 최대 트리 깊이
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3, log=True),  # 학습률
        "n_estimators": trial.suggest_int("n_estimators", 100, 1000, step=100),      # 부스팅 단계 수
        "min_child_samples": trial.suggest_int("min_child_samples", 5, 100),  # 최소 데이터 수
        "subsample": trial.suggest_float("subsample", 0.6, 1.0, step=0.1),    # 샘플링 비율
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.6, 1.0, step=0.1),  # 피처 샘플링 비율
        "reg_alpha": trial.suggest_float("reg_alpha", 1e-8, 10.0, log=True),  # L1 규제
        "reg_lambda": trial.suggest_float("reg_lambda", 1e-8, 10.0, log=True) # L2 규제
    }
    cv = KFold(5, shuffle=True, random_state=SEED)
    model = LGBMClassifier(**hp, random_state=SEED)
    score = cross_val_score(model, train_ft, target, cv=cv, scoring="f1_macro", n_jobs=-1).mean()
    return score
# Out:
# /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)

# %%
sampler = optuna.samplers.TPESampler(seed=SEED) # 대체 모델 역할은 sampler 객체

# study 객체
study = optuna.create_study(
    direction="maximize",
    sampler = sampler
)

study.optimize(objective, n_trials=50)   # optimze 메서드에 콜백 함수(objective) 전달
# Out:
# [I 2024-11-01 07:34:28,742] A new study created in memory with name: no-name-e3820db8-e3e8-4104-ad1d-63b3f4170e41
# [I 2024-11-01 07:36:06,721] Trial 0 finished with value: 0.7090306219145696 and parameters: {'num_leaves': 69, 'max_depth': 15, 'learning_rate': 0.1205712628744377, 'n_estimators': 600, 'min_child_samples': 19, 'subsample': 0.6, 'colsample_bytree': 0.6, 'reg_alpha':
. Best is trial 26 with value: 0.7193445377868238.
# [I 2024-11-01 08:41:52,756] Trial 44 finished with value: 0.705699230533232 and parameters: {'num_leaves': 77, 'max_depth': 3, 'learning_rate': 0.012276269009612853, 'n_estimators': 900, 'min_child_samples': 90, 'subsample': 1.0, 'colsample_bytree': 0.9, 'reg_alpha': 2.2229954089373947, 'reg_lambda': 4.906293662777419e-05}. Best is trial 26 with value: 0.7193445377868238.
# [I 2024-11-01 08:43:37,386] Trial 45 finished with value: 0.7049219420429204 and parameters: {'num_leaves': 36, 'max_depth': 7, 'learning_rate': 0.2934226784039561, 'n_estimators': 1000, 'min_child_samples': 97, 'subsample': 0.9, 'colsample_bytree': 1.0, 'reg_alpha': 0.07889644736826718, 'reg_lambda': 0.00015019581826339164}. Best is trial 26 with value: 0.7193445377868238.
# [I 2024-11-01 08:45:03,450] Trial 46 finished with value: 0.7153303659911402 and parameters: {'num_leaves': 48, 'max_depth': 11, 'learning_rate': 0.03230846294347209, 'n_estimators': 800, 'min_child_samples': 87, 'subsample': 1.0, 'colsample_bytree': 0.6, 'reg_alpha': 6.527889713581135e-07, 'reg_lambda': 1.4170600213016624e-06}. Best is trial 26 with value: 0.7193445377868238.
# [I 2024-11-01 08:46:28,227] Trial 47 finished with value: 0.718322141193593 and parameters: {'num_leaves': 26, 'max_depth': 13, 'learning_rate': 0.023536093826546412, 'n_estimators': 1000, 'min_child_samples': 83, 'subsample': 0.9, 'colsample_bytree': 0.7, 'reg_alpha': 0.04017492723805609, 'reg_lambda': 0.0011707334486319256}. Best is trial 26 with value: 0.7193445377868238.
# [I 2024-11-01 08:47:51,228] Trial 48 finished with value: 0.7189984210601177 and parameters: {'num_leaves': 24, 'max_depth': 13, 'learning_rate': 0.024958479671909305, 'n_estimators': 1000, 'min_child_samples': 54, 'subsample': 0.8, 'colsample_bytree': 0.7, 'reg_alpha': 0.8731131714674436, 'reg_lambda': 0.008167992030135546}. Best is trial 26 with value: 0.7193445377868238.
# [I 2024-11-01 08:49:04,410] Trial 49 finished with value: 0.7210577559661056 and parameters: {'num_leaves': 20, 'max_depth': 14, 'learning_rate': 0.027906527991630778, 'n_estimators': 1000, 'min_child_samples': 58, 'subsample': 0.8, 'colsample_bytree': 0.7, 'reg_alpha': 0.7747077190206921, 'reg_lambda': 0.00961644947537403}. Best is trial 49 with value: 0.7210577559661056.

# %%
study.best_trial.params  # 최적의 하이퍼파라미터
# Out:
# {'num_leaves': 20,
#  'max_depth': 14,
#  'learning_rate': 0.027906527991630778,
#  'n_estimators': 1000,
#  'min_child_samples': 58,
#  'subsample': 0.8,
#  'colsample_bytree': 0.7,
#  'reg_alpha': 0.7747077190206921,
#  'reg_lambda': 0.00961644947537403}

# %%
study.best_value    # 최적의 하이퍼파라미터의 검증 점수 -> 기존 0.7209보다 유의미한 증가???
# Out:
# 0.7210577559661056

# %%
# 모델 학습
model = LGBMClassifier(random_state=SEED, **study.best_params)
model.fit(train_ft,target)
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 5874, number of negative: 9066
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.099463 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 27368
# [LightGBM] [Info] Number of data points in the train set: 14940, number of used features: 434
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.393173 -> initscore=-0.433995
# [LightGBM] [Info] Start training from score -0.433995
# LGBMClassifier(colsample_bytree=0.7, learning_rate=0.027906527991630778,
#                max_depth=14, min_child_samples=58, n_estimators=1000,
#                num_leaves=20, random_state=42, reg_alpha=0.7747077190206921,
#                reg_lambda=0.00961644947537403, subsample=0.8)

# %%
# 테스트 데이터 예측
pred = model.predict(test_ft)
pred
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
# 예측 결과 저장
submit["target"] = pred
submit.to_csv(f"{DATA_PATH}6_v2.0_LGBM.csv",index=False)

# %% [markdown]
# # AutoML
